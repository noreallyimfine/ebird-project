# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\ajaco\\Desktop\\repos\\noreallyimfine\\ebird-project\\data\\labelled_bird_sample.csv")

print(df.shape)

df.head()
# Out:
# (103992, 16)
#                   name  observ_count        country     state county  \
# 0     Magnolia Warbler             2  United States  Illinois   Cook
# 1     Great Blue Heron             2  United States  Illinois   Cook
# 2        Purple Martin             6  United States  Illinois   Cook
# 3  Common Yellowthroat             3  United States  Illinois   Cook
# 4       Eastern Towhee             3  United States  Illinois   Cook
#
#     latitude  longitude observ_date  month  season   county_state     State  \
# 0  41.775629 -87.583273  1995-08-27      8  Summer  Cook,Illinois  Illinois
# 1  41.956746 -87.913027  1999-07-24      7  Summer  Cook,Illinois  Illinois
# 2  41.707907 -87.886848  1965-06-19      6  Summer  Cook,Illinois  Illinois
# 3  41.707907 -87.886848  1965-06-19      6  Summer  Cook,Illinois  Illinois
# 4  41.707907 -87.886848  1965-06-19      6  Summer  Cook,Illinois  Illinois
#
#   CountyName       region seas_reg_rare  target
# ...

# %%
c2r = df[['county_state', 'region']]

# %%
c2r
# Out:
#               county_state       region
# 0            Cook,Illinois  Great Lakes
# 1            Cook,Illinois  Great Lakes
# 2            Cook,Illinois  Great Lakes
# 3            Cook,Illinois  Great Lakes
# 4            Cook,Illinois  Great Lakes
# ...                    ...          ...
# 103987     Murray,Oklahoma   Appohzarka
# 103988     Murray,Oklahoma   Appohzarka
# 103989        Long,Georgia   Deep South
# 103990     Giles,Tennessee   Appohzarka
# 103991  Kemper,Mississippi   Deep South
#
# [103992 rows x 2 columns]

# %%
c2r = c2r.drop_duplicates(subset=['county_state'])

# %%
cs_to_region = {}
for idx, row in c2r.iterrows():
    cs = row['county_state']
    region = row['region']
    cs_to_region[cs] = region

# %%
cs_to_region
# Out:
# {'Cook,Illinois': 'Great Lakes',
#  'Aransas,Texas': 'Gulf Coast',
#  'Cochise,Arizona': 'Southwest',
#  'Ada,Idaho': 'Mountain West',
#  'Jasper,Iowa': 'Heartland',
#  'Charlotte,Florida': 'Southern Florida',
#  'Monroe,Georgia': 'Deep South',
#  'Van Zandt,Texas': 'Deep South',
#  'Jasper,Indiana': 'Great Lakes',
#  'Sequoyah,Oklahoma': 'Appohzarka',
#  'Carroll,Maryland': 'Mid-Atlantic North',
#  'Hidalgo,New Mexico': 'Southwest',
#  'Pueblo,Colorado': 'Great Plains',
#  'Ohio,Kentucky': 'Appohzarka',
#  'Sonoma,California': 'Northwest',
#  'Orange,California': 'West Coast',
#  'Allen,Indiana': 'Great Lakes',
#  'Lake,Ohio': 'Great Lakes',
#  'Sussex,New Jersey': 'Mid-Atlantic North',
#  'Shelby,Tennessee': 'Deep South',
#  'Ellis,Texas': 'Great Plains',
#  'Chaves,New Mexico': 'Great Plains',
#  'Rockingham,New Hampshire': 'Northeast',
#  'Collier,Florida': 'Southern Florida',
#  'Lake,Illinois': 'Great Lakes',
#  'Grand Forks,North Dakota': 'Heartland',
# ...
