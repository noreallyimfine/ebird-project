# %%
from ebird import db

# %%
from ebird.models import Bird, County, State, Season, Region

# %%
Bird.query.all()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\envs\flask-kernel\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1276                 if not evt_handled:
# -> 1277                     self.dialect.do_execute(
#    1278                         cursor, statement, parameters, context
#
# ~\anaconda3\envs\flask-kernel\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#
# OperationalError: no such table: bird
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-4-574cbd27d121> in <module>
# ----> 1 Bird.query.all()
#
# ~\anaconda3\envs\flask-kernel\lib\site-packages\sqlalchemy\orm\query.py in all(self)
#    3339                 :ref:`faq_query_deduplicating`
#    3340         """
# -> 3341         return list(self)
#    3342
#    3343     @_generative(_no_clauseelement_condition)
#
# ~\anaconda3\envs\flask-kernel\lib\site-packages\sqlalchemy\orm\query.py in __iter__(self)
#    3501         if self._autoflush and not self._populate_existing:
#    3502             self.session._autoflush()
# -> 3503         return self._execute_and_instances(context)
#    3504
#    3505     def __str__(self):
#
# ~\anaconda3\envs\flask-kernel\lib\site-packages\sqlalchemy\orm\query.py in _execute_and_instances(self, querycontext)
#    3526         )
#    3527
# -> 3528         result = conn.execute(querycontext.statement, self._params)
#    3529         return loading.instances(querycontext.query, result, querycontext)
#    3530
#
# ~\anaconda3\envs\flask-kernel\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1012             )
#    1013         else:
# -> 1014             return meth(self, multiparams, params)
#    1015
#    1016     def _execute_function(self, func, multiparams, params):
#
# ~\anaconda3\envs\flask-kernel\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~\anaconda3\envs\flask-kernel\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1125             )
#    1126
# -> 1127         ret = self._execute_context(
#    1128             dialect,
#    1129             dialect.execution_ctx_cls._init_compiled,
#
# ~\anaconda3\envs\flask-kernel\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1315
#    1316         except BaseException as e:
# -> 1317             self._handle_dbapi_exception(
#    1318                 e, statement, parameters, cursor, context
#    1319             )
#
# ~\anaconda3\envs\flask-kernel\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1509                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1510             elif should_wrap:
# -> 1511                 util.raise_(
#    1512                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1513                 )
#
# ~\anaconda3\envs\flask-kernel\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\anaconda3\envs\flask-kernel\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1275                             break
#    1276                 if not evt_handled:
# -> 1277                     self.dialect.do_execute(
#    1278                         cursor, statement, parameters, context
#    1279                     )
#
# ~\anaconda3\envs\flask-kernel\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     591
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#     595     def do_execute_no_params(self, cursor, statement, context=None):
#
# OperationalError: (sqlite3.OperationalError) no such table: bird
# [SQL: SELECT bird.id AS bird_id, bird.name AS bird_name
# FROM bird]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
db.drop_all()
db.create_all()

# %%
import pandas as pd
birds = pd.read_csv('C:/Users/jayja/Desktop/bird.csv')

# %%
for bird in birds['0']:
    input = Bird(name=bird)
    db.session.add(input)

db.session.commit()

# %%
birds = Bird.query.all()

for bird in birds:
    print(bird.id, bird.name)
# Out:
# 1 Abert's Towhee
# 2 Acadian Flycatcher
# 3 Acorn Woodpecker
# 4 African Silverbill
# 5 Akiapolaau
# 6 Alder Flycatcher
# 7 Aleutian Tern
# 8 Allen's Hummingbird
# 9 Altamira Oriole
# 10 American Avocet
# 11 American Bittern
# 12 American Black Duck
# 13 American Coot
# 14 American Crow
# 15 American Dipper
# 16 American Golden-Plover
# 17 American Goldfinch
# 18 American Kestrel
# 19 American Oystercatcher
# 20 American Pipit
# 21 American Redstart
# 22 American Robin
# 23 American Three-toed Woodpecker
# 24 American Tree Sparrow
# 25 American White Pelican
# 26 American Wigeon
# 27 American Woodcock
# 28 Ancient Murrelet
# 29 Anhinga
# 30 Anianiau
# 31 Anna's Hummingbird
# 32 Antillean Nighthawk
# 33 Apapane
# 34 Aplomado Falcon
# 35 Arctic Loon
# 36 Arctic Tern
# 37 Arctic Warbler
# 38 Arizona Woodpecker
# 39 Ash-throated Flycatcher
# 40 Ashy Storm-Petrel
# 41 Atlantic Puffin
# 42 Audubon's Oriole
# 43 Audubon's Shearwater
# 44 Azure Gallinule
# 45 Bachman's Sparrow
# 46 Baird's Sandpiper
# 47 Baird's Sparrow
# 48 Bald Eagle
# 49 Baltimore Oriole
# 50 Band-rumped Storm-Petrel
# 51 Band-tailed Pigeon
# 52 Bank Swallow
# 53 Bar-tailed Godwit
# 54 Barn Owl
# 55 Barn Swallow
# 56 Barnacle Goose
# 57 Barred Owl
# 58 Barrow's Goldeneye
# 59 Bay-breasted Warbler
# 60 Bell's Sparrow
# 61 Bell's Vireo
# 62 Belted Kingfisher
# 63 Bendire's Thrasher
# 64 Bewick's Wren
# 65 Bicknell's Thrush
# 66 Black Francolin
# 67 Black Guillemot
# 68 Black Noddy
# 69 Black Oystercatcher
# 70 Black Phoebe
# 71 Black Rosy-Finch
# 72 Black Scoter
# 73 Black Skimmer
# 74 Black Storm-Petrel
# 75 Black Swift
# 76 Black Tern
# 77 Black Turnstone
# 78 Black Vulture
# 79 Black-and-white Warbler
# 80 Black-backed Woodpecker
# 81 Black-bellied Plover
# 82 Black-bellied Whistling-Duck
# 83 Black-billed Cuckoo
# 84 Black-billed Magpie
# 85 Black-capped Chickadee
# 86 Black-capped Petrel
# 87 Black-capped Vireo
# 88 Black-chinned Hummingbird
# 89 Black-chinned Sparrow
# 90 Black-crested Titmouse
# 91 Black-crowned Night-Heron
# 92 Black-footed Albatross
# 93 Black-headed Grosbeak
# 94 Black-headed Gull
# 95 Black-legged Kittiwake
# 96 Black-necked Stilt
# 97 Black-tailed Gnatcatcher
# 98 Black-tailed Godwit
# 99 Black-throated Blue Warbler
# 100 Black-throated Gray Warbler
# 101 Black-throated Green Warbler
# 102 Black-throated Sparrow
# 103 Black-vented Oriole
# 104 Black-vented Shearwater
# 105 Black-whiskered Vireo
# 106 Blackburnian Warbler
# 107 Blackpoll Warbler
# 108 Blue Grosbeak
# 109 Blue Jay
# 110 Blue-footed Booby
# 111 Blue-gray Gnatcatcher
# 112 Blue-headed Vireo
# 113 Blue-throated Mountain-gem
# 114 Blue-winged Teal
# 115 Blue-winged Warbler
# 116 Bluethroat
# 117 Boat-tailed Grackle
# 118 Bobolink
# 119 Bohemian Waxwing
# 120 Bonaparte's Gull
# 121 Boreal Chickadee
# 122 Boreal Owl
# 123 Botteri's Sparrow
# 124 Brambling
# 125 Brandt's Cormorant
# 126 Brant
# 127 Brewer's Blackbird
# 128 Brewer's Sparrow
# 129 Bridled Tern
# 130 Bridled Titmouse
# 131 Bristle-thighed Curlew
# 132 Broad-billed Hummingbird
# 133 Broad-tailed Hummingbird
# 134 Broad-winged Hawk
# 135 Bronzed Cowbird
# 136 Brown Booby
# 137 Brown Creeper
# 138 Brown Jay
# 139 Brown Noddy
# 140 Brown Pelican
# 141 Brown Shrike
# 142 Brown Thrasher
# 143 Brown-capped Rosy-Finch
# 144 Brown-crested Flycatcher
# 145 Brown-headed Cowbird
# 146 Brown-headed Nuthatch
# 147 Buff-bellied Hummingbird
# 148 Buff-breasted Flycatcher
# 149 Buff-breasted Sandpiper
# 150 Bufflehead
# 151 Buller's Shearwater
# 152 Bullock's Oriole
# 153 Bulwer's Petrel
# 154 Burrowing Owl
# 155 Bushtit
# 156 Cackling Goose
# 157 Cactus Wren
# 158 California Condor
# 159 California Gnatcatcher
# 160 California Gull
# 161 California Quail
# 162 California Scrub-Jay
# 163 California Thrasher
# 164 California Towhee
# 165 Calliope Hummingbird
# 166 Canada Goose
# 167 Canada Jay
# 168 Canada Warbler
# 169 Canvasback
# 170 Canyon Towhee
# 171 Canyon Wren
# 172 Cape May Warbler
# 173 Carolina Chickadee
# 174 Carolina Wren
# 175 Caspian Tern
# 176 Cassin's Auklet
# 177 Cassin's Finch
# 178 Cassin's Kingbird
# 179 Cassin's Sparrow
# 180 Cassin's Vireo
# 181 Cattle Egret
# 182 Cave Swallow
# 183 Cedar Waxwing
# 184 Cerulean Warbler
# 185 Chestnut Munia
# 186 Chestnut-backed Chickadee
# 187 Chestnut-collared Longspur
# 188 Chestnut-sided Warbler
# 189 Chihuahuan Raven
# 190 Chimney Swift
# 191 Chinese Hwamei
# 192 Chipping Sparrow
# 193 Chuck-will's-widow
# 194 Chukar
# 195 Cinnamon Teal
# 196 Clapper Rail
# 197 Clark's Grebe
# 198 Clark's Nutcracker
# 199 Clay-colored Sparrow
# 200 Clay-colored Thrush
# 201 Cliff Swallow
# 202 Colima Warbler
# 203 Common Black Hawk
# 204 Common Crane
# 205 Common Eider
# 206 Common Gallinule
# 207 Common Goldeneye
# 208 Common Grackle
# 209 Common Greenshank
# 210 Common Ground Dove
# 211 Common Hill Myna
# 212 Common Loon
# 213 Common Merganser
# 214 Common Murre
# 215 Common Myna
# 216 Common Nighthawk
# 217 Common Pauraque
# 218 Common Poorwill
# 219 Common Raven
# 220 Common Redpoll
# 221 Common Ringed Plover
# 222 Common Sandpiper
# 223 Common Snipe
# 224 Common Tern
# 225 Common Yellowthroat
# 226 Connecticut Warbler
# 227 Cooper's Hawk
# 228 Cordilleran Flycatcher
# 229 Corn Crake
# 230 Cory's Shearwater
# 231 Costa's Hummingbird
# 232 Couch's Kingbird
# 233 Craveri's Murrelet
# 234 Crested Auklet
# 235 Crested Caracara
# 236 Crissal Thrasher
# 237 Curlew Sandpiper
# 238 Curve-billed Thrasher
# 239 Dark-eyed Junco
# 240 Dickcissel
# 241 Double-crested Cormorant
# 242 Dovekie
# 243 Downy Woodpecker
# 244 Dunlin
# 245 Dusky Flycatcher
# 246 Dusky Grouse
# 247 Dusky Warbler
# 248 Dusky-capped Flycatcher
# 249 Eared Grebe
# 250 Eastern Bluebird
# 251 Eastern Kingbird
# 252 Eastern Meadowlark
# 253 Eastern Phoebe
# 254 Eastern Screech-Owl
# 255 Eastern Towhee
# 256 Eastern Whip-poor-will
# 257 Eastern Wood-Pewee
# 258 Eastern Yellow Wagtail
# 259 Elegant Tern
# 260 Elegant Trogon
# 261 Elf Owl
# 262 Emperor Goose
# 263 Erckel's Francolin
# 264 Eurasian Collared-Dove
# 265 Eurasian Dotterel
# 266 Eurasian Hobby
# 267 Eurasian Skylark
# 268 Eurasian Tree Sparrow
# 269 Eurasian Wigeon
# 270 European Goldfinch
# 271 European Starling
# 272 Evening Grosbeak
# 273 Eyebrowed Thrush
# 274 Ferruginous Hawk
# 275 Field Sparrow
# 276 Fish Crow
# 277 Five-striped Sparrow
# 278 Flammulated Owl
# 279 Flesh-footed Shearwater
# 280 Florida Scrub-Jay
# 281 Fork-tailed Flycatcher
# 282 Fork-tailed Storm-Petrel
# 283 Forster's Tern
# 284 Fox Sparrow
# 285 Franklin's Gull
# 286 Fulvous Whistling-Duck
# 287 Gadwall
# 288 Gambel's Quail
# 289 Garganey
# 290 Gila Woodpecker
# 291 Gilded Flicker
# 292 Glaucous Gull
# 293 Glaucous-winged Gull
# 294 Glossy Ibis
# 295 Golden Eagle
# 296 Golden-cheeked Warbler
# 297 Golden-crowned Kinglet
# 298 Golden-crowned Sparrow
# 299 Golden-fronted Woodpecker
# 300 Golden-winged Warbler
# 301 Grace's Warbler
# 302 Grasshopper Sparrow
# 303 Gray Catbird
# 304 Gray Flycatcher
# 305 Gray Francolin
# 306 Gray Hawk
# 307 Gray Kingbird
# 308 Gray Partridge
# 309 Gray Silky-flycatcher
# 310 Gray Vireo
# 311 Gray Wagtail
# 312 Gray-cheeked Thrush
# 313 Gray-crowned Rosy-Finch
# 314 Gray-streaked Flycatcher
# 315 Gray-tailed Tattler
# 316 Great Black-backed Gull
# 317 Great Blue Heron
# 318 Great Cormorant
# 319 Great Crested Flycatcher
# 320 Great Egret
# 321 Great Frigatebird
# 322 Great Horned Owl
# 323 Great Kiskadee
# 324 Great Shearwater
# 325 Great Skua
# 326 Great-tailed Grackle
# 327 Greater Pewee
# 328 Greater Prairie-Chicken
# 329 Greater Roadrunner
# 330 Greater Sage-Grouse
# 331 Greater Scaup
# 332 Greater White-fronted Goose
# 333 Greater Yellowlegs
# 334 Green Heron
# 335 Green Jay
# 336 Green Kingfisher
# 337 Green Parakeet
# 338 Green-tailed Towhee
# 339 Green-winged Teal
# 340 Groove-billed Ani
# 341 Guadalupe Murrelet
# 342 Gull-billed Tern
# 343 Hairy Woodpecker
# 344 Hammond's Flycatcher
# 345 Harlequin Duck
# 346 Harris's Hawk
# 347 Harris's Sparrow
# 348 Hawaii Akepa
# 349 Hawaii Amakihi
# 350 Hawaii Elepaio
# 351 Hawaiian Coot
# 352 Hawaiian Duck
# 353 Hawaiian Goose
# 354 Hawaiian Hawk
# 355 Hawaiian Petrel
# 356 Hawfinch
# 357 Heermann's Gull
# 358 Henslow's Sparrow
# 359 Hepatic Tanager
# 360 Hermit Thrush
# 361 Hermit Warbler
# 362 Herring Gull
# 363 Hoary Redpoll
# 364 Hooded Merganser
# 365 Hooded Oriole
# 366 Hooded Warbler
# 367 Hook-billed Kite
# 368 Horned Grebe
# 369 Horned Lark
# 370 Horned Puffin
# 371 House Finch
# 372 House Sparrow
# 373 House Wren
# 374 Hudsonian Godwit
# 375 Hutton's Vireo
# 376 Iceland Gull
# 377 Iiwi
# 378 Inca Dove
# 379 Indian Peafowl
# 380 Indigo Bunting
# 381 Island Scrub-Jay
# 382 Ivory Gull
# 383 Java Sparrow
# 384 Juniper Titmouse
# 385 Kalij Pheasant
# 386 Kauai Amakihi
# 387 Kauai Elepaio
# 388 Kentucky Warbler
# 389 Killdeer
# 390 King Eider
# 391 King Rail
# 392 Kirtland's Warbler
# 393 Kittlitz's Murrelet
# 394 Ladder-backed Woodpecker
# 395 Lapland Longspur
# 396 Lark Bunting
# 397 Lark Sparrow
# 398 Laughing Gull
# 399 Lawrence's Goldfinch
# 400 Laysan Albatross
# 401 Lazuli Bunting
# 402 LeConte's Sparrow
# 403 LeConte's Thrasher
# 404 Leach's Storm-Petrel
# 405 Least Auklet
# 406 Least Bittern
# 407 Least Flycatcher
# 408 Least Grebe
# 409 Least Sandpiper
# 410 Least Tern
# 411 Lesser Black-backed Gull
# 412 Lesser Goldfinch
# 413 Lesser Nighthawk
# 414 Lesser Sand-Plover
# 415 Lesser Scaup
# 416 Lesser White-fronted Goose
# 417 Lesser Yellowlegs
# 418 Lewis's Woodpecker
# 419 Limpkin
# 420 Lincoln's Sparrow
# 421 Little Blue Heron
# 422 Little Curlew
# 423 Little Egret
# 424 Little Gull
# 425 Loggerhead Shrike
# 426 Long-billed Curlew
# 427 Long-billed Dowitcher
# 428 Long-billed Thrasher
# 429 Long-eared Owl
# 430 Long-tailed Duck
# 431 Long-tailed Jaeger
# 432 Long-toed Stint
# 433 Louisiana Waterthrush
# 434 Lucifer Hummingbird
# 435 Lucy's Warbler
# 436 MacGillivray's Warbler
# 437 Magnificent Frigatebird
# 438 Magnolia Warbler
# 439 Mallard
# 440 Mangrove Cuckoo
# 441 Manx Shearwater
# 442 Marbled Godwit
# 443 Marbled Murrelet
# 444 Marsh Wren
# 445 Masked Booby
# 446 Masked Duck
# 447 Maui Alauahio
# 448 McCown's Longspur
# 449 McKay's Bunting
# 450 Merlin
# 451 Mew Gull
# 452 Mexican Chickadee
# 453 Mexican Duck
# 454 Mexican Jay
# 455 Mexican Violetear
# 456 Mexican Whip-poor-will
# 457 Mississippi Kite
# 458 Mitred Parakeet
# 459 Monk Parakeet
# 460 Montezuma Quail
# 461 Morelet's Seedeater
# 462 Mottled Duck
# 463 Mountain Bluebird
# 464 Mountain Chickadee
# 465 Mountain Plover
# 466 Mountain Quail
# 467 Mourning Dove
# 468 Mourning Warbler
# 469 Muscovy Duck
# 470 Mute Swan
# 471 Nanday Parakeet
# 472 Nashville Warbler
# 473 Nelson's Sparrow
# 474 Neotropic Cormorant
# 475 Northern Beardless-Tyrannulet
# 476 Northern Bobwhite
# 477 Northern Cardinal
# 478 Northern Flicker
# 479 Northern Fulmar
# 480 Northern Gannet
# 481 Northern Goshawk
# 482 Northern Harrier
# 483 Northern Jacana
# 484 Northern Mockingbird
# 485 Northern Parula
# 486 Northern Pintail
# 487 Northern Pygmy-Owl
# 488 Northern Red Bishop
# 489 Northern Rough-winged Swallow
# 490 Northern Saw-whet Owl
# 491 Northern Shoveler
# 492 Northern Shrike
# 493 Northern Waterthrush
# 494 Northern Wheatear
# 495 Northwestern Crow
# 496 Nuttall's Woodpecker
# 497 Oahu Elepaio
# 498 Oak Titmouse
# 499 Olive Sparrow
# 500 Olive Warbler
# 501 Olive-sided Flycatcher
# 502 Omao
# 503 Orange-crowned Warbler
# 504 Orchard Oriole
# 505 Oriental Greenfinch
# 506 Osprey
# 507 Ovenbird
# 508 Pacific Golden-Plover
# 509 Pacific Loon
# 510 Pacific Wren
# 511 Pacific-slope Flycatcher
# 512 Painted Bunting
# 513 Painted Redstart
# 514 Palm Warbler
# 515 Parakeet Auklet
# 516 Parasitic Jaeger
# 517 Passenger Pigeon
# 518 Pechora Pipit
# 519 Pectoral Sandpiper
# 520 Pelagic Cormorant
# 521 Peregrine Falcon
# 522 Phainopepla
# 523 Philadelphia Vireo
# 524 Pied-billed Grebe
# 525 Pigeon Guillemot
# 526 Pileated Woodpecker
# 527 Pine Grosbeak
# 528 Pine Siskin
# 529 Pine Warbler
# 530 Pink-footed Shearwater
# 531 Pinyon Jay
# 532 Piping Plover
# 533 Plain Chachalaca
# 534 Plumbeous Vireo
# 535 Pomarine Jaeger
# 536 Prairie Falcon
# 537 Prairie Warbler
# 538 Prothonotary Warbler
# 539 Purple Finch
# 540 Purple Gallinule
# 541 Purple Martin
# 542 Purple Sandpiper
# 543 Pygmy Nuthatch
# 544 Pyrrhuloxia
# 545 Razorbill
# 546 Red Crossbill
# 547 Red Junglefowl
# 548 Red Knot
# 549 Red Phalarope
# 550 Red-bellied Woodpecker
# 551 Red-billed Leiothrix
# 552 Red-billed Pigeon
# 553 Red-breasted Merganser
# 554 Red-breasted Nuthatch
# 555 Red-breasted Sapsucker
# 556 Red-cockaded Woodpecker
# 557 Red-crested Cardinal
# 558 Red-crowned Parrot
# 559 Red-eyed Vireo
# 560 Red-faced Cormorant
# 561 Red-faced Warbler
# 562 Red-flanked Bluetail
# 563 Red-footed Booby
# 564 Red-headed Woodpecker
# 565 Red-legged Kittiwake
# 566 Red-masked Parakeet
# 567 Red-naped Sapsucker
# 568 Red-necked Grebe
# 569 Red-necked Phalarope
# 570 Red-necked Stint
# 571 Red-shouldered Hawk
# 572 Red-tailed Hawk
# 573 Red-throated Loon
# 574 Red-throated Pipit
# 575 Red-vented Bulbul
# 576 Red-whiskered Bulbul
# 577 Red-winged Blackbird
# 578 Reddish Egret
# 579 Redhead
# 580 Rhinoceros Auklet
# 581 Ridgway's Rail
# 582 Ring-billed Gull
# 583 Ring-necked Duck
# 584 Ring-necked Pheasant
# 585 Ringed Kingfisher
# 586 Rivoli's Hummingbird
# 587 Rock Pigeon
# 588 Rock Ptarmigan
# 589 Rock Sandpiper
# 590 Rock Wren
# 591 Rose-breasted Grosbeak
# 592 Rose-ringed Parakeet
# 593 Roseate Spoonbill
# 594 Roseate Tern
# 595 Ross's Goose
# 596 Ross's Gull
# 597 Rosy-billed Pochard
# 598 Rosy-faced Lovebird
# 599 Rough-legged Hawk
# 600 Royal Tern
# 601 Ruby-crowned Kinglet
# 602 Ruby-throated Hummingbird
# 603 Ruddy Duck
# 604 Ruddy Ground Dove
# 605 Ruddy Turnstone
# 606 Ruff
# 607 Ruffed Grouse
# 608 Rufous Hummingbird
# 609 Rufous-backed Robin
# 610 Rufous-capped Warbler
# 611 Rufous-crowned Sparrow
# 612 Rufous-winged Sparrow
# 613 Rustic Bunting
# 614 Rusty Blackbird
# 615 Sabine's Gull
# 616 Saffron Finch
# 617 Sage Thrasher
# 618 Sagebrush Sparrow
# 619 Saltmarsh Sparrow
# 620 Sanderling
# 621 Sandhill Crane
# 622 Sandwich Tern
# 623 Savannah Sparrow
# 624 Say's Phoebe
# 625 Scaled Quail
# 626 Scaly-breasted Munia
# 627 Scarlet Tanager
# 628 Scissor-tailed Flycatcher
# 629 Scott's Oriole
# 630 Scripps's Murrelet
# 631 Seaside Sparrow
# 632 Sedge Wren
# 633 Semipalmated Plover
# 634 Semipalmated Sandpiper
# 635 Sharp-shinned Hawk
# 636 Sharp-tailed Grouse
# 637 Sharp-tailed Sandpiper
# 638 Shiny Cowbird
# 639 Short-billed Dowitcher
# 640 Short-eared Owl
# 641 Short-tailed Hawk
# 642 Short-tailed Shearwater
# 643 Siberian Accentor
# 644 Slaty-backed Gull
# 645 Smew
# 646 Smith's Longspur
# 647 Smooth-billed Ani
# 648 Snail Kite
# 649 Snow Bunting
# 650 Snow Goose
# 651 Snowy Egret
# 652 Snowy Owl
# 653 Snowy Plover
# 654 Solitary Sandpiper
# 655 Song Sparrow
# 656 Sooty Grouse
# 657 Sooty Shearwater
# 658 Sooty Tern
# 659 Sora
# 660 South Polar Skua
# 661 Spectacled Eider
# 662 Spot-breasted Oriole
# 663 Spotted Dove
# 664 Spotted Sandpiper
# 665 Spotted Towhee
# 666 Sprague's Pipit
# 667 Spruce Grouse
# 668 Steller's Eider
# 669 Steller's Jay
# 670 Stilt Sandpiper
# 671 Sulphur-bellied Flycatcher
# 672 Summer Tanager
# 673 Surf Scoter
# 674 Surfbird
# 675 Swainson's Hawk
# 676 Swainson's Thrush
# 677 Swainson's Warbler
# 678 Swallow-tailed Kite
# 679 Swamp Sparrow
# 680 Temminck's Stint
# 681 Tennessee Warbler
# 682 Terek Sandpiper
# 683 Thick-billed Kingbird
# 684 Thick-billed Murre
# 685 Townsend's Solitaire
# 686 Townsend's Warbler
# 687 Tree Swallow
# 688 Tricolored Blackbird
# 689 Tricolored Heron
# 690 Trindade Petrel
# 691 Tropical Kingbird
# 692 Trumpeter Swan
# 693 Tufted Duck
# 694 Tufted Puffin
# 695 Tufted Titmouse
# 696 Tundra Swan
# 697 Turkey Vulture
# 698 Upland Sandpiper
# 699 Varied Bunting
# 700 Varied Thrush
# 701 Vaux's Swift
# 702 Veery
# 703 Verdin
# 704 Vermilion Flycatcher
# 705 Vesper Sparrow
# 706 Violet-crowned Hummingbird
# 707 Violet-green Swallow
# 708 Virginia Rail
# 709 Virginia's Warbler
# 710 Wandering Albatross
# 711 Wandering Tattler
# 712 Warbling Vireo
# 713 Warbling White-eye
# 714 Wedge-tailed Shearwater
# 715 Western Bluebird
# 716 Western Grebe
# 717 Western Gull
# 718 Western Kingbird
# 719 Western Meadowlark
# 720 Western Sandpiper
# 721 Western Screech-Owl
# 722 Western Tanager
# 723 Western Wood-Pewee
# 724 Whimbrel
# 725 Whiskered Screech-Owl
# 726 White Ibis
# 727 White Tern
# 728 White Wagtail
# 729 White-breasted Nuthatch
# 730 White-cheeked Pintail
# 731 White-crowned Pigeon
# 732 White-crowned Sparrow
# 733 White-eyed Vireo
# 734 White-faced Ibis
# 735 White-faced Storm-Petrel
# 736 White-headed Woodpecker
# 737 White-rumped Sandpiper
# 738 White-rumped Shama
# 739 White-tailed Eagle
# 740 White-tailed Hawk
# 741 White-tailed Kite
# 742 White-tailed Ptarmigan
# 743 White-tailed Tropicbird
# 744 White-throated Sparrow
# 745 White-throated Swift
# 746 White-tipped Dove
# 747 White-winged Crossbill
# 748 White-winged Dove
# 749 White-winged Parakeet
# 750 White-winged Scoter
# 751 Whooping Crane
# 752 Wild Turkey
# 753 Willet
# 754 Williamson's Sapsucker
# 755 Willow Flycatcher
# 756 Willow Ptarmigan
# 757 Wilson's Phalarope
# 758 Wilson's Plover
# 759 Wilson's Snipe
# 760 Wilson's Storm-Petrel
# 761 Wilson's Warbler
# 762 Winter Wren
# 763 Wood Duck
# 764 Wood Sandpiper
# 765 Wood Stork
# 766 Wood Thrush
# 767 Woodhouse's Scrub-Jay
# 768 Worm-eating Warbler
# 769 Wrentit
# 770 Xantus's Hummingbird
# 771 Yellow Rail
# 772 Yellow Warbler
# 773 Yellow-bellied Flycatcher
# 774 Yellow-bellied Sapsucker
# 775 Yellow-billed Cuckoo
# 776 Yellow-billed Loon
# 777 Yellow-billed Magpie
# 778 Yellow-breasted Chat
# 779 Yellow-chevroned Parakeet
# 780 Yellow-crowned Night-Heron
# 781 Yellow-eyed Junco
# 782 Yellow-footed Gull
# 783 Yellow-fronted Canary
# 784 Yellow-green Vireo
# 785 Yellow-headed Blackbird
# 786 Yellow-rumped Warbler
# 787 Yellow-throated Vireo
# 788 Yellow-throated Warbler
# 789 Zebra Dove
# 790 Zone-tailed Hawk

# %%
from joblib import load

# %%
county_state = load('C:/Users/jayja/Desktop/old-ebird/bird_app/utils/county_state.joblib')

# %%
county_state = [cs.split(',') for cs in county_state]
county_state
# Out:
# [['Cook', 'Illinois'],
#  ['Aransas', 'Texas'],
#  ['Cochise', 'Arizona'],
#  ['Ada', 'Idaho'],
#  ['Jasper', 'Iowa'],
#  ['Charlotte', 'Florida'],
#  ['Monroe', 'Georgia'],
#  ['Van Zandt', 'Texas'],
#  ['Jasper', 'Indiana'],
#  ['Sequoyah', 'Oklahoma'],
#  ['Carroll', 'Maryland'],
#  ['Hidalgo', 'New Mexico'],
#  ['Pueblo', 'Colorado'],
#  ['Ohio', 'Kentucky'],
#  ['Sonoma', 'California'],
#  ['Orange', 'California'],
#  ['Allen', 'Indiana'],
#  ['Lake', 'Ohio'],
#  ['Sussex', 'New Jersey'],
#  ['Shelby', 'Tennessee'],
#  ['Ellis', 'Texas'],
#  ['Chaves', 'New Mexico'],
#  ['Rockingham', 'New Hampshire'],
#  ['Collier', 'Florida'],
#  ['Lake', 'Illinois'],
#  ['Grand Forks', 'North Dakota'],
#  ['Hampshire', 'Massachusetts'],
#  ['Comanche', 'Oklahoma'],
#  ['Glynn', 'Georgia'],
#  ['Ventura', 'California'],
#  ['Aleutians West', 'Alaska'],
#  ['Bay', 'Michigan'],
#  ['La Crosse', 'Wisconsin'],
#  ['Allegheny', 'Pennsylvania'],
#  ['Indiana', 'Pennsylvania'],
#  ['Malheur', 'Oregon'],
#  ['Will', 'Illinois'],
#  ['Imperial', 'California'],
#  ['Tarrant', 'Texas'],
#  ['Volusia', 'Florida'],
#  ['Botetourt', 'Virginia'],
#  ['DuPage', 'Illinois'],
#  ['Horry', 'South Carolina'],
#  ['Chester', 'Pennsylvania'],
#  ['Orange', 'Florida'],
#  ['Snohomish', 'Washington'],
#  ['Dorchester', 'Maryland'],
#  ['Starr', 'Texas'],
#  ['Sierra', 'California'],
#  ['Rich', 'Utah'],
#  ['Sutter', 'California'],
#  ['Knox', 'Tennessee'],
#  ['Humboldt', 'California'],
#  ['Ottawa', 'Oklahoma'],
#  ['Van Buren', 'Michigan'],
#  ['Thurston', 'Washington'],
#  ['Jones', 'Texas'],
#  ['Erie', 'Ohio'],
#  ['Polk', 'Minnesota'],
#  ['Caroline', 'Maryland'],
#  ['Washburn', 'Wisconsin'],
#  ['Cameron', 'Louisiana'],
#  ['Santa Cruz', 'California'],
#  ['Washoe', 'Nevada'],
#  ['Forrest', 'Mississippi'],
#  ['Pierce', 'Washington'],
#  ['Douglas', 'Oregon'],
#  ['New Castle', 'Delaware'],
#  ['Centre', 'Pennsylvania'],
#  ['Middlesex', 'Connecticut'],
#  ['Yakima', 'Washington'],
#  ['Nevada', 'California'],
#  ['Essex', 'Massachusetts'],
#  ['Isabella', 'Michigan'],
#  ['Whiteside', 'Illinois'],
#  ['Jackson', 'Illinois'],
#  ['Little River', 'Arkansas'],
#  ['Riley', 'Kansas'],
#  ['Jackson', 'South Dakota'],
#  ['Merrimack', 'New Hampshire'],
#  ['Hancock', 'Maine'],
#  ['Pima', 'Arizona'],
#  ['Boone', 'Missouri'],
#  ['Kern', 'California'],
#  ['Coos', 'New Hampshire'],
#  ['Canyon', 'Idaho'],
#  ["St. Mary's", 'Maryland'],
#  ['Dallas', 'Missouri'],
#  ['Pipestone', 'Minnesota'],
#  ['Okanogan', 'Washington'],
#  ['Phillips', 'Montana'],
#  ['Riverside', 'California'],
#  ['Kleberg', 'Texas'],
#  ['Merced', 'California'],
#  ['Plumas', 'California'],
#  ['Grant', 'Washington'],
#  ['Schoolcraft', 'Michigan'],
#  ['Charleston', 'South Carolina'],
#  ['Del Norte', 'California'],
#  ['Rutherford', 'Tennessee'],
#  ['Cuyahoga', 'Ohio'],
#  ['Arapahoe', 'Colorado'],
#  ['Douglas', 'Colorado'],
#  ['Marinette', 'Wisconsin'],
#  ['Jefferson', 'Nebraska'],
#  ['Mercer', 'New Jersey'],
#  ['Dyer', 'Tennessee'],
#  ['Monroe', 'Florida'],
#  ['Chelan', 'Washington'],
#  ['Marion', 'Oregon'],
#  ['Russell', 'Kentucky'],
#  ['Fairfax', 'Virginia'],
#  ['Santa Barbara', 'California'],
#  ['Ocean', 'New Jersey'],
#  ['San Diego', 'California'],
#  ['Williamson', 'Tennessee'],
#  ['Suffolk', 'New York'],
#  ['San Mateo', 'California'],
#  ['Middlesex', 'Massachusetts'],
#  ['Richmond', 'New York'],
#  ['Grays Harbor', 'Washington'],
#  ['Accomack', 'Virginia'],
#  ['Travis', 'Texas'],
#  ['Carroll', 'New Hampshire'],
#  ['Alameda', 'California'],
#  ['Maricopa', 'Arizona'],
#  ['Lane', 'Oregon'],
#  ['Hidalgo', 'Texas'],
#  ['McHenry', 'Illinois'],
#  ['Polk', 'Oregon'],
#  ['Panola', 'Texas'],
#  ['Los Angeles', 'California'],
#  ['Franklin', 'Massachusetts'],
#  ['Josephine', 'Oregon'],
#  ['Knox', 'Maine'],
#  ['Plymouth', 'Massachusetts'],
#  ['Otsego', 'Michigan'],
#  ['Park', 'Wyoming'],
#  ['Caddo', 'Louisiana'],
#  ['Orleans', 'Louisiana'],
#  ['Galveston', 'Texas'],
#  ['Gallatin', 'Montana'],
#  ['Warren', 'New Jersey'],
#  ['Wakulla', 'Florida'],
#  ['Blount', 'Tennessee'],
#  ['Davidson', 'Tennessee'],
#  ['Oakland', 'Michigan'],
#  ['Worcester', 'Maryland'],
#  ['Jefferson', 'Texas'],
#  ['Livingston', 'Michigan'],
#  ['Ingham', 'Michigan'],
#  ['Dutchess', 'New York'],
#  ['Marin', 'California'],
#  ['Yankton', 'South Dakota'],
#  ['El Paso', 'Texas'],
#  ['Sevier', 'Tennessee'],
#  ['Morris', 'New Jersey'],
#  ['Wasco', 'Oregon'],
#  ['Cameron', 'Texas'],
#  ['Chatham', 'Georgia'],
#  ['Oswego', 'New York'],
#  ['Sawyer', 'Wisconsin'],
#  ['Island', 'Washington'],
#  ['Brazoria', 'Texas'],
#  ['Rusk', 'Wisconsin'],
#  ['Vilas', 'Wisconsin'],
#  ['Howard', 'Maryland'],
#  ['Highlands', 'Florida'],
#  ['Bonneville', 'Idaho'],
#  ['Marion', 'Alabama'],
#  ['Onslow', 'North Carolina'],
#  ['Placer', 'California'],
#  ['Potter', 'Texas'],
#  ['Cache', 'Utah'],
#  ['Suffolk', 'Massachusetts'],
#  ['Flathead', 'Montana'],
#  ['Washtenaw', 'Michigan'],
#  ['Contra Costa', 'California'],
#  ['Baltimore', 'Maryland'],
#  ['Fresno', 'California'],
#  ['Pulaski', 'Arkansas'],
#  ['Tazewell', 'Illinois'],
#  ['Huntingdon', 'Pennsylvania'],
#  ['Skagway-Hoonah-Angoon', 'Alaska'],
#  ['Lake', 'Colorado'],
#  ['Lincoln', 'Wyoming'],
#  ['Santa Clara', 'California'],
#  ['San Joaquin', 'California'],
#  ['Washington', 'Oregon'],
#  ['Rio Arriba', 'New Mexico'],
#  ['Wood', 'Ohio'],
#  ['Susquehanna', 'Pennsylvania'],
#  ['Union', 'Oregon'],
#  ['Wayne', 'North Carolina'],
#  ['Montgomery', 'Ohio'],
#  ['Washington', 'Arkansas'],
#  ['Cape May', 'New Jersey'],
#  ['Delaware', 'Pennsylvania'],
#  ['Shiawassee', 'Michigan'],
#  ['Lake', 'Montana'],
#  ['Cook', 'Minnesota'],
#  ['Mariposa', 'California'],
#  ['Pike', 'Pennsylvania'],
#  ['San Bernardino', 'California'],
#  ['Harris', 'Texas'],
#  ['Dallas', 'Texas'],
#  ['Milwaukee', 'Wisconsin'],
#  ['Ontario', 'New York'],
#  ['San Luis Obispo', 'California'],
#  ['Ozaukee', 'Wisconsin'],
#  ['DeKalb', 'Illinois'],
#  ['Pointe Coupee', 'Louisiana'],
#  ['Chouteau', 'Montana'],
#  ['Washington', 'Maine'],
#  ['Monroe', 'New York'],
#  ['Delaware', 'Ohio'],
#  ['Greene', 'New York'],
#  ['Chippewa', 'Michigan'],
#  ['York', 'Pennsylvania'],
#  ['Henry', 'Illinois'],
#  ['Oneida', 'Wisconsin'],
#  ['Kane', 'Illinois'],
#  ['Gunnison', 'Colorado'],
#  ['Larimer', 'Colorado'],
#  ['Pinal', 'Arizona'],
#  ['Jackson', 'Oregon'],
#  ['Washington', 'Pennsylvania'],
#  ['Franklin', 'Georgia'],
#  ['Lee', 'Florida'],
#  ['Lincoln', 'Oregon'],
#  ['Franklin', 'Missouri'],
#  ['Utah', 'Utah'],
#  ['Cumberland', 'Maine'],
#  ['Wayne', 'Michigan'],
#  ['LaPorte', 'Indiana'],
#  ['San Juan', 'New Mexico'],
#  ['Dodge', 'Wisconsin'],
#  ['Green Lake', 'Wisconsin'],
#  ['Brown', 'Wisconsin'],
#  ['Prowers', 'Colorado'],
#  ['Owyhee', 'Idaho'],
#  ['Lubbock', 'Texas'],
#  ['Lucas', 'Ohio'],
#  ['Dane', 'Wisconsin'],
#  ['Sacramento', 'California'],
#  ['Chenango', 'New York'],
#  ['Macomb', 'Michigan'],
#  ['Menard', 'Illinois'],
#  ['Saguache', 'Colorado'],
#  ['Scott', 'Arkansas'],
#  ['Putnam', 'West Virginia'],
#  ['Porter', 'Indiana'],
#  ['Durham', 'North Carolina'],
#  ['Bladen', 'North Carolina'],
#  ['Orange', 'New York'],
#  ['Apache', 'Arizona'],
#  ['Sullivan', 'Tennessee'],
#  ['Queens', 'New York'],
#  ['Navajo', 'Arizona'],
#  ['St. Johns', 'Florida'],
#  ['Brewster', 'Texas'],
#  ['Portage', 'Wisconsin'],
#  ['Sandoval', 'New Mexico'],
#  ['Dare', 'North Carolina'],
#  ['Tippecanoe', 'Indiana'],
#  ['Fall River', 'South Dakota'],
#  ['Miami-Dade', 'Florida'],
#  ['Hamilton', 'Tennessee'],
#  ["Prince George's", 'Maryland'],
#  ['Harvey', 'Kansas'],
#  ['Madison', 'Tennessee'],
#  ['Pike', 'Arkansas'],
#  ['Nome', 'Alaska'],
#  ['Manitowoc', 'Wisconsin'],
#  ['Lawrence', 'Ohio'],
#  ['Whatcom', 'Washington'],
#  ['Bossier', 'Louisiana'],
#  ['Grafton', 'New Hampshire'],
#  ['Linn', 'Oregon'],
#  ['Atlantic', 'New Jersey'],
#  ['Addison', 'Vermont'],
#  ['Mohave', 'Arizona'],
#  ['Halifax', 'Virginia'],
#  ['Dauphin', 'Pennsylvania'],
#  ['Cimarron', 'Oklahoma'],
#  ['Garfield', 'Utah'],
#  ['King', 'Washington'],
#  ['Roscommon', 'Michigan'],
#  ['Belknap', 'New Hampshire'],
#  ['Windsor', 'Vermont'],
#  ['Cabell', 'West Virginia'],
#  ['El Paso', 'Colorado'],
#  ['Hawaii', 'Hawaii'],
#  ['Woodson', 'Kansas'],
#  ['Jefferson', 'Arkansas'],
#  ['Stevens', 'Washington'],
#  ['Roseau', 'Minnesota'],
#  ['San Francisco', 'California'],
#  ['Merrick', 'Nebraska'],
#  ['Elko', 'Nevada'],
#  ['Buffalo', 'Wisconsin'],
#  ['Box Elder', 'Utah'],
#  ['Freestone', 'Texas'],
#  ['Penobscot', 'Maine'],
#  ['Sedgwick', 'Kansas'],
#  ['Anoka', 'Minnesota'],
#  ['Worcester', 'Massachusetts'],
#  ['Kenedy', 'Texas'],
#  ['Hudson', 'New Jersey'],
#  ['Surry', 'North Carolina'],
#  ['Butte', 'California'],
#  ['Wells', 'North Dakota'],
#  ['Yuma', 'Colorado'],
#  ['Chittenden', 'Vermont'],
#  ['Brown', 'Ohio'],
#  ['Chatham', 'North Carolina'],
#  ['Lake', 'Minnesota'],
#  ['Campbell', 'Tennessee'],
#  ['Crittenden', 'Arkansas'],
#  ['Coos', 'Oregon'],
#  ['Hillsborough', 'Florida'],
#  ['Coconino', 'Arizona'],
#  ['Genesee', 'Michigan'],
#  ['New Hanover', 'North Carolina'],
#  ['Alfalfa', 'Oklahoma'],
#  ['Klamath', 'Oregon'],
#  ['Transylvania', 'North Carolina'],
#  ['Nueces', 'Texas'],
#  ['Tompkins', 'New York'],
#  ['Forsyth', 'Georgia'],
#  ['Green', 'Wisconsin'],
#  ['Wabash', 'Indiana'],
#  ['Georgetown', 'South Carolina'],
#  ['Brevard', 'Florida'],
#  ['Boulder', 'Colorado'],
#  ['Hamilton', 'Indiana'],
#  ['Franklin', 'Vermont'],
#  ['Allegany', 'Maryland'],
#  ['Terrell', 'Texas'],
#  ['Clallam', 'Washington'],
#  ['Palm Beach', 'Florida'],
#  ['Jackson', 'Colorado'],
#  ['Benton', 'Washington'],
#  ['Rio Blanco', 'Colorado'],
#  ['Frederick', 'Maryland'],
#  ['Barnstable', 'Massachusetts'],
#  ['Crook', 'Oregon'],
#  ['Oneida', 'New York'],
#  ['Red River', 'Louisiana'],
#  ['Burleson', 'Texas'],
#  ['Monterey', 'California'],
#  ['Denton', 'Texas'],
#  ['Santa Fe', 'New Mexico'],
#  ['Grant', 'New Mexico'],
#  ['Racine', 'Wisconsin'],
#  ['Tuolumne', 'California'],
#  ['Schenectady', 'New York'],
#  ['Maui', 'Hawaii'],
#  ['Hampton', 'South Carolina'],
#  ['Benton', 'Oregon'],
#  ['Middlesex', 'New Jersey'],
#  ['Fulton', 'Arkansas'],
#  ['Cattaraugus', 'New York'],
#  ['Garland', 'Arkansas'],
#  ['Tillamook', 'Oregon'],
#  ['Montgomery', 'Kansas'],
#  ['Barry', 'Michigan'],
#  ['Somerset', 'Maryland'],
#  ['Floyd', 'Georgia'],
#  ['Douglas', 'Wisconsin'],
#  ['Berkshire', 'Massachusetts'],
#  ['Forest', 'Wisconsin'],
#  ['Thomas', 'Nebraska'],
#  ['Stanislaus', 'California'],
#  ['District of Columbia', 'District of Columbia'],
#  ['Kittitas', 'Washington'],
#  ['DeSoto', 'Mississippi'],
#  ['Pulaski', 'Kentucky'],
#  ['Sanders', 'Montana'],
#  ['Washington', 'Texas'],
#  ['Salt Lake', 'Utah'],
#  ['Rock', 'Wisconsin'],
#  ['Lake', 'Oregon'],
#  ['Hale', 'Alabama'],
#  ['Broward', 'Florida'],
#  ['Randolph', 'Georgia'],
#  ['Iberia', 'Louisiana'],
#  ['Giles', 'Virginia'],
#  ['Jefferson', 'Colorado'],
#  ['Colusa', 'California'],
#  ['DeKalb', 'Alabama'],
#  ['Seneca', 'New York'],
#  ['El Dorado', 'California'],
#  ['Calhoun', 'Texas'],
#  ['Carroll', 'Illinois'],
#  ['Craighead', 'Arkansas'],
#  ['Oscoda', 'Michigan'],
#  ['Fayette', 'Pennsylvania'],
#  ['Teton', 'Wyoming'],
#  ['Santa Cruz', 'Arizona'],
#  ['Mendocino', 'California'],
#  ['Lincoln', 'Maine'],
#  ['Gloucester', 'New Jersey'],
#  ['Lake', 'Tennessee'],
#  ['Champaign', 'Illinois'],
#  ['Ketchikan Gateway', 'Alaska'],
#  ['Monmouth', 'New Jersey'],
#  ['Shenandoah', 'Virginia'],
#  ['Indian River', 'Florida'],
#  ['Monroe', 'Illinois'],
#  ['Trinity', 'California'],
#  ['Litchfield', 'Connecticut'],
#  ['Colfax', 'New Mexico'],
#  ['Johnson', 'Kansas'],
#  ['Eddy', 'New Mexico'],
#  ['Hillsborough', 'New Hampshire'],
#  ['Oconto', 'Wisconsin'],
#  ['Stoddard', 'Missouri'],
#  ['Stark', 'North Dakota'],
#  ['Alger', 'Michigan'],
#  ['East Baton Rouge', 'Louisiana'],
#  ['Watauga', 'North Carolina'],
#  ['Chambers', 'Texas'],
#  ['Honolulu', 'Hawaii'],
#  ['Huntington', 'Indiana'],
#  ['Wallowa', 'Oregon'],
#  ['Story', 'Iowa'],
#  ['Armstrong', 'Texas'],
#  ['Weber', 'Utah'],
#  ['Niagara', 'New York'],
#  ['Clatsop', 'Oregon'],
#  ['Deschutes', 'Oregon'],
#  ['Hancock', 'Ohio'],
#  ['Orange', 'North Carolina'],
#  ['Elkhart', 'Indiana'],
#  ['Bradley', 'Arkansas'],
#  ['Bexar', 'Texas'],
#  ['Siskiyou', 'California'],
#  ['Erie', 'New York'],
#  ['Madison', 'North Carolina'],
#  ['Lafayette', 'Wisconsin'],
#  ['Walla Walla', 'Washington'],
#  ['Bergen', 'New Jersey'],
#  ['Curry', 'Oregon'],
#  ['Kingsbury', 'South Dakota'],
#  ['Clarendon', 'South Carolina'],
#  ['Fond du Lac', 'Wisconsin'],
#  ['Juneau', 'Wisconsin'],
#  ['Clearwater', 'Idaho'],
#  ['Vernon', 'Missouri'],
#  ['Morgan', 'Alabama'],
#  ['Sagadahoc', 'Maine'],
#  ['Otero', 'New Mexico'],
#  ['Putnam', 'Florida'],
#  ['Yamhill', 'Oregon'],
#  ['Putnam', 'New York'],
#  ['Glades', 'Florida'],
#  ['Kenai Peninsula', 'Alaska'],
#  ['Iron', 'Utah'],
#  ['Yavapai', 'Arizona'],
#  ['Cheshire', 'New Hampshire'],
#  ['Vernon', 'Wisconsin'],
#  ['Glacier', 'Montana'],
#  ['Shasta', 'California'],
#  ['Carter', 'Montana'],
#  ['Morgan', 'Missouri'],
#  ['Shawano', 'Wisconsin'],
#  ['Denali', 'Alaska'],
#  ['Erie', 'Pennsylvania'],
#  ['Wabasha', 'Minnesota'],
#  ['Lee', 'Alabama'],
#  ['Sierra', 'New Mexico'],
#  ['Sevier', 'Utah'],
#  ['Kent', 'Delaware'],
#  ['Oklahoma', 'Oklahoma'],
#  ['Bristol', 'Massachusetts'],
#  ['Midland', 'Michigan'],
#  ['Independence', 'Arkansas'],
#  ['Rowan', 'North Carolina'],
#  ['Hardin', 'Tennessee'],
#  ['Fremont', 'Wyoming'],
#  ['Bureau', 'Illinois'],
#  ['Bent', 'Colorado'],
#  ['Stark', 'Ohio'],
#  ['Anchorage', 'Alaska'],
#  ['Kings', 'New York'],
#  ['Crawford', 'Arkansas'],
#  ['Somerset', 'New Jersey'],
#  ['Orleans', 'Vermont'],
#  ['Wayne', 'New York'],
#  ['Fairfield', 'Connecticut'],
#  ['Hampden', 'Massachusetts'],
#  ['Norfolk', 'Massachusetts'],
#  ['Warren', 'Ohio'],
#  ['Winnebago', 'Wisconsin'],
#  ['St. Martin', 'Louisiana'],
#  ['Menard', 'Texas'],
#  ['Catron', 'New Mexico'],
#  ['Barron', 'Wisconsin'],
#  ['Wichita', 'Texas'],
#  ['Door', 'Wisconsin'],
#  ['McKenzie', 'North Dakota'],
#  ['Skagit', 'Washington'],
#  ['Polk', 'Arkansas'],
#  ['Grand Traverse', 'Michigan'],
#  ['Columbia', 'New York'],
#  ['Franklin', 'North Carolina'],
#  ['Obion', 'Tennessee'],
#  ['Marshall', 'Alabama'],
#  ['Taney', 'Missouri'],
#  ['Richmond City', 'Virginia'],
#  ['Douglas', 'Nebraska'],
#  ['Mercer', 'Pennsylvania'],
#  ['Phillips', 'Arkansas'],
#  ['Perry', 'Alabama'],
#  ['Crawford', 'Michigan'],
#  ['Catoosa', 'Georgia'],
#  ['New Haven', 'Connecticut'],
#  ['Hennepin', 'Minnesota'],
#  ['Burnet', 'Texas'],
#  ['Kodiak Island', 'Alaska'],
#  ['Tulare', 'California'],
#  ['Colleton', 'South Carolina'],
#  ['Newton', 'Arkansas'],
#  ['Cumberland', 'Pennsylvania'],
#  ['Morton', 'Kansas'],
#  ['Missoula', 'Montana'],
#  ['Lake', 'South Dakota'],
#  ['Montgomery', 'Virginia'],
#  ['Lorain', 'Ohio'],
#  ['Hays', 'Texas'],
#  ['Hernando', 'Florida'],
#  ['Cassia', 'Idaho'],
#  ['Washington', 'Rhode Island'],
#  ['Fairbanks North Star', 'Alaska'],
#  ['Rabun', 'Georgia'],
#  ['Holt', 'Missouri'],
#  ['Manistee', 'Michigan'],
#  ['Valdez-Cordova', 'Alaska'],
#  ['St. Charles', 'Louisiana'],
#  ['Lincoln', 'Montana'],
#  ['Greene', 'Ohio'],
#  ['Tipton', 'Tennessee'],
#  ['Cleveland', 'Oklahoma'],
#  ['Anson', 'North Carolina'],
#  ['Habersham', 'Georgia'],
#  ['Cass', 'Missouri'],
#  ['Carteret', 'North Carolina'],
#  ['Amador', 'California'],
#  ['Carter', 'Tennessee'],
#  ['Trigg', 'Kentucky'],
#  ['Socorro', 'New Mexico'],
#  ['McKinley', 'New Mexico'],
#  ['Rice', 'Minnesota'],
#  ['Jackson', 'Iowa'],
#  ['Beaufort', 'South Carolina'],
#  ['Lincoln', 'New Mexico'],
#  ['Oneida', 'Idaho'],
#  ['St. Clair', 'Michigan'],
#  ['Pocahontas', 'West Virginia'],
#  ['Harford', 'Maryland'],
#  ['Lynn', 'Texas'],
#  ['Newton', 'Indiana'],
#  ['Macon', 'Georgia'],
#  ['Jackson', 'Missouri'],
#  ['Dillingham', 'Alaska'],
#  ['Broome', 'New York'],
#  ['Daviess', 'Indiana'],
#  ['Hunterdon', 'New Jersey'],
#  ['Nassau', 'New York'],
#  ['Waukesha', 'Wisconsin'],
#  ['Berkeley', 'West Virginia'],
#  ['Sullivan', 'Pennsylvania'],
#  ['Waushara', 'Wisconsin'],
#  ['Dunn', 'North Dakota'],
#  ['Windham', 'Vermont'],
#  ['Hill', 'Montana'],
#  ['Mono', 'California'],
#  ['Tom Green', 'Texas'],
#  ['Kosciusko', 'Indiana'],
#  ['Nelson', 'Virginia'],
#  ['Warren', 'Pennsylvania'],
#  ['Clark', 'Ohio'],
#  ['Benewah', 'Idaho'],
#  ['Mason', 'Illinois'],
#  ['Madison', 'Indiana'],
#  ['Herkimer', 'New York'],
#  ['Jefferson', 'Wisconsin'],
#  ['Haines', 'Alaska'],
#  ['Windham', 'Connecticut'],
#  ['Ogemaw', 'Michigan'],
#  ['Aiken', 'South Carolina'],
#  ['Onondaga', 'New York'],
#  ['Cleburne', 'Arkansas'],
#  ['Hood River', 'Oregon'],
#  ['Dorchester', 'South Carolina'],
#  ['Peoria', 'Illinois'],
#  ['New London', 'Connecticut'],
#  ['Lyon', 'Nevada'],
#  ['Nez Perce', 'Idaho'],
#  ['Modoc', 'California'],
#  ['Lamar', 'Georgia'],
#  ['Valley', 'Idaho'],
#  ['Union', 'Tennessee'],
#  ['Iowa', 'Wisconsin'],
#  ['Walworth', 'Wisconsin'],
#  ['Williamson', 'Illinois'],
#  ['Tooele', 'Utah'],
#  ['Walsh', 'North Dakota'],
#  ['Lea', 'New Mexico'],
#  ['Talbot', 'Maryland'],
#  ['Wasatch', 'Utah'],
#  ['York', 'Maine'],
#  ['Multnomah', 'Oregon'],
#  ['Fayette', 'West Virginia'],
#  ['Manatee', 'Florida'],
#  ['Zapata', 'Texas'],
#  ['Inyo', 'California'],
#  ['Cleveland', 'North Carolina'],
#  ['St. Bernard', 'Louisiana'],
#  ['Washington', 'Vermont'],
#  ['Calvert', 'Maryland'],
#  ['Graham', 'Arizona'],
#  ["Queen Anne's", 'Maryland'],
#  ['Washington', 'Maryland'],
#  ['Alamosa', 'Colorado'],
#  ['Gogebic', 'Michigan'],
#  ['Albany', 'New York'],
#  ['Angelina', 'Texas'],
#  ['Fremont', 'Iowa'],
#  ['Jackson', 'Mississippi'],
#  ['Orange', 'Texas'],
#  ['Bay', 'Florida'],
#  ['Eagle', 'Colorado'],
#  ['Humphreys', 'Tennessee'],
#  ['Jefferson', 'Oregon'],
#  ['Muskegon', 'Michigan'],
#  ['Knox', 'Indiana'],
#  ['Madison', 'Illinois'],
#  ['Columbia', 'Oregon'],
#  ['Cass', 'North Dakota'],
#  ['Athens', 'Ohio'],
#  ['Juneau', 'Alaska'],
#  ['Franklin', 'Ohio'],
#  ['Duval', 'Texas'],
#  ['Tolland', 'Connecticut'],
#  ['New York', 'New York'],
#  ['Polk', 'Texas'],
#  ['Tehama', 'California'],
#  ['Montgomery', 'Pennsylvania'],
#  ['Saginaw', 'Michigan'],
#  ['Butler', 'Ohio'],
#  ['Alpine', 'California'],
#  ['Columbia', 'Wisconsin'],
#  ['Polk', 'Wisconsin'],
#  ['Pershing', 'Nevada'],
#  ['Sarasota', 'Florida'],
#  ['Morrow', 'Oregon'],
#  ['Cross', 'Arkansas'],
#  ['Duval', 'Florida'],
#  ['Smith', 'Texas'],
#  ['Luzerne', 'Pennsylvania'],
#  ['Kenton', 'Kentucky'],
#  ['Ashland', 'Wisconsin'],
#  ['McDowell', 'North Carolina'],
#  ['Aroostook', 'Maine'],
#  ['West Baton Rouge', 'Louisiana'],
#  ['Providence', 'Rhode Island'],
#  ['Kidder', 'North Dakota'],
#  ['Levy', 'Florida'],
#  ['Wayne', 'Indiana'],
#  ['Steuben', 'Indiana'],
#  ['Dunn', 'Wisconsin'],
#  ['Coleman', 'Texas'],
#  ['Essex', 'New Jersey'],
#  ['Jefferson', 'Florida'],
#  ['Bledsoe', 'Tennessee'],
#  ['La Paz', 'Arizona'],
#  ['Grant', 'Oregon'],
#  ['Allegan', 'Michigan'],
#  ['Converse', 'Wyoming'],
#  ['Northwest Arctic', 'Alaska'],
#  ['Scotts Bluff', 'Nebraska'],
#  ['Ulster', 'New York'],
#  ['Sumter', 'Georgia'],
#  ['Caledonia', 'Vermont'],
#  ['Polk', 'Iowa'],
#  ['Lake', 'Indiana'],
#  ['Hamilton', 'New York'],
#  ['Ellsworth', 'Kansas'],
#  ['Delta', 'Texas'],
#  ['Baldwin', 'Alabama'],
#  ['Sheboygan', 'Wisconsin'],
#  ['Montgomery', 'Maryland'],
#  ['McIntosh', 'Georgia'],
#  ['Finney', 'Kansas'],
#  ['Cheboygan', 'Michigan'],
#  ['Bayfield', 'Wisconsin'],
#  ['Jasper', 'South Carolina'],
#  ['Ottawa', 'Ohio'],
#  ['Bear Lake', 'Idaho'],
#  ['Loudoun', 'Virginia'],
#  ['Pickaway', 'Ohio'],
#  ['Bee', 'Texas'],
#  ['Spotsylvania', 'Virginia'],
#  ['Sussex', 'Virginia'],
#  ['Westchester', 'New York'],
#  ['Johnston', 'North Carolina'],
#  ['Clarke', 'Georgia'],
#  ['Summit', 'Ohio'],
#  ['Lauderdale', 'Tennessee'],
#  ['Sedgwick', 'Colorado'],
#  ['Comal', 'Texas'],
#  ['Bolivar', 'Mississippi'],
#  ['Overton', 'Tennessee'],
#  ['Gilliam', 'Oregon'],
#  ['Antelope', 'Nebraska'],
#  ['Schuylkill', 'Pennsylvania'],
#  ['Day', 'South Dakota'],
#  ['Fauquier', 'Virginia'],
#  ['Jackson', 'North Carolina'],
#  ['Union', 'Arkansas'],
#  ['Madison', 'Nebraska'],
#  ['Weston', 'Wyoming'],
#  ['Harney', 'Oregon'],
#  ['Effingham', 'Georgia'],
#  ['Acadia', 'Louisiana'],
#  ['Bullitt', 'Kentucky'],
#  ['San Benito', 'California'],
#  ['Arlington', 'Virginia'],
#  ['Greene', 'Missouri'],
#  ['Wayne', 'Ohio'],
#  ['Rock Island', 'Illinois'],
#  ['Washington', 'Wisconsin'],
#  ['Camden', 'Georgia'],
#  ['Wabaunsee', 'Kansas'],
#  ['Osage', 'Oklahoma'],
#  ['Marion', 'Indiana'],
#  ['Iron', 'Wisconsin'],
#  ['Rutland', 'Vermont'],
#  ['Christian', 'Missouri'],
#  ['Grand', 'Colorado'],
#  ['Pinellas', 'Florida'],
#  ['Woodbury', 'Iowa'],
#  ['Edmonson', 'Kentucky'],
#  ['Pulaski', 'Virginia'],
#  ['Kane', 'Utah'],
#  ['Northampton', 'Virginia'],
#  ['Otter Tail', 'Minnesota'],
#  ['Hamilton', 'Ohio'],
#  ['Sussex', 'Delaware'],
#  ['Osage', 'Kansas'],
#  ['Stone', 'Missouri'],
#  ['St. Louis City', 'Missouri'],
#  ['Dakota', 'Nebraska'],
#  ['Taylor', 'Wisconsin'],
#  ['Johnson', 'Wyoming'],
#  ['Hot Spring', 'Arkansas'],
#  ['Weld', 'Colorado'],
#  ['Marathon', 'Wisconsin'],
#  ['Pierce', 'Wisconsin'],
#  ['Adams', 'Colorado'],
#  ['Stutsman', 'North Dakota'],
#  ['Scott', 'Minnesota'],
#  ['Laurel', 'Kentucky'],
#  ['Hunt', 'Texas'],
#  ['Yukon-Koyukuk', 'Alaska'],
#  ['Nemaha', 'Nebraska'],
#  ['St. Louis', 'Minnesota'],
#  ['Davison', 'South Dakota'],
#  ['Beaver', 'Pennsylvania'],
#  ['Walker', 'Georgia'],
#  ['Llano', 'Texas'],
#  ['Jackson', 'Michigan'],
#  ['Montgomery', 'Alabama'],
#  ['Whitley', 'Kentucky'],
#  ['Ross', 'Ohio'],
#  ['Garrett', 'Maryland'],
#  ['Brown', 'Indiana'],
#  ['Mecklenburg', 'North Carolina'],
#  ['Hubbard', 'Minnesota'],
#  ['Keith', 'Nebraska'],
#  ['Goliad', 'Texas'],
#  ['Harrison', 'Texas'],
#  ['Marion', 'West Virginia'],
#  ['Kings', 'California'],
#  ['Kenosha', 'Wisconsin'],
#  ['Mecklenburg', 'Virginia'],
#  ['Sherman', 'Oregon'],
#  ['Northampton', 'Pennsylvania'],
#  ['Nodaway', 'Missouri'],
#  ['Sauk', 'Wisconsin'],
#  ['Atchison', 'Missouri'],
#  ['Hall', 'Nebraska'],
#  ['Geauga', 'Ohio'],
#  ['Dakota', 'Minnesota'],
#  ['Benson', 'North Dakota'],
#  ['Grant', 'North Dakota'],
#  ['Bernalillo', 'New Mexico'],
#  ['Mississippi', 'Arkansas'],
#  ['Benton', 'Tennessee'],
#  ['Winnebago', 'Illinois'],
#  ['Yolo', 'California'],
#  ['Pacific', 'Washington'],
#  ['Morgan', 'West Virginia'],
#  ['Marion', 'Kansas'],
#  ['Clay', 'Alabama'],
#  ['Westmoreland', 'Pennsylvania'],
#  ['Clermont', 'Ohio'],
#  ['DeKalb', 'Georgia'],
#  ['Uintah', 'Utah'],
#  ['Lewis', 'Washington'],
#  ['Skamania', 'Washington'],
#  ['McLean', 'Illinois'],
#  ['Sumter', 'Alabama'],
#  ['Hendry', 'Florida'],
#  ['Ontonagon', 'Michigan'],
#  ['Orleans', 'New York'],
#  ['Clinton', 'Pennsylvania'],
#  ['Lake and Peninsula', 'Alaska'],
#  ['Ouray', 'Colorado'],
#  ['Fulton', 'Kentucky'],
#  ['Boone', 'Kentucky'],
#  ['Meigs', 'Ohio'],
#  ['Camden', 'New Jersey'],
#  ['Newport', 'Rhode Island'],
#  ['Washington', 'Missouri'],
#  ['Morgan', 'Colorado'],
#  ['Gallia', 'Ohio'],
#  ['Live Oak', 'Texas'],
#  ['Daggett', 'Utah'],
#  ['Latah', 'Idaho'],
#  ['Olmsted', 'Minnesota'],
#  ['Okaloosa', 'Florida'],
#  ['West Feliciana', 'Louisiana'],
#  ['Nassau', 'Florida'],
#  ['Rusk', 'Texas'],
#  ['Washington', 'Utah'],
#  ['Chesterfield', 'Virginia'],
#  ['Minnehaha', 'South Dakota'],
#  ['Portage', 'Ohio'],
#  ['Montour', 'Pennsylvania'],
#  ['Somervell', 'Texas'],
#  ['Johnson', 'Iowa'],
#  ['Lamb', 'Texas'],
#  ['Douglas', 'Washington'],
#  ['Fairfield', 'Ohio'],
#  ['Chemung', 'New York'],
#  ['Gibson', 'Indiana'],
#  ['Brunswick', 'North Carolina'],
#  ['Hancock', 'Mississippi'],
#  ['Philadelphia', 'Pennsylvania'],
#  ['Lewis', 'Tennessee'],
#  ['Polk', 'Florida'],
#  ['Sullivan', 'New York'],
#  ['Garfield', 'Colorado'],
#  ['Lancaster', 'Pennsylvania'],
#  ['Columbia', 'Washington'],
#  ['Hartley', 'Texas'],
#  ['Ashtabula', 'Ohio'],
#  ['Calcasieu', 'Louisiana'],
#  ['Cuming', 'Nebraska'],
#  ['Bristol', 'Rhode Island'],
#  ['Brooks', 'Texas'],
#  ['Routt', 'Colorado'],
#  ['Limestone', 'Alabama'],
#  ['Waldo', 'Maine'],
#  ['Carbon', 'Utah'],
#  ['Dickson', 'Tennessee'],
#  ['Callaway', 'Missouri'],
#  ['Clark', 'Nevada'],
#  ['Union', 'New Jersey'],
#  ['Paulding', 'Ohio'],
#  ['Logan', 'Colorado'],
#  ['Tucker', 'West Virginia'],
#  ['Carbon', 'Montana'],
#  ['Madison', 'Alabama'],
#  ['Liberty', 'Montana'],
#  ['Richland', 'Montana'],
#  ['Livingston', 'Missouri'],
#  ['Beltrami', 'Minnesota'],
#  ['Somerset', 'Maine'],
#  ['McCracken', 'Kentucky'],
#  ['Cumberland', 'New Jersey'],
#  ['Moffat', 'Colorado'],
#  ['Bennington', 'Vermont'],
#  ['Grant', 'Wisconsin'],
#  ['Cass', 'Minnesota'],
#  ['Berks', 'Pennsylvania'],
#  ['Logan', 'Ohio'],
#  ['Kendall', 'Illinois'],
#  ['Crawford', 'Kansas'],
#  ['Rains', 'Texas'],
#  ['Boyle', 'Kentucky'],
#  ['Oxford', 'Maine'],
#  ['Slope', 'North Dakota'],
#  ['Brazos', 'Texas'],
#  ['Nye', 'Nevada'],
#  ['Marquette', 'Wisconsin'],
#  ['Matagorda', 'Texas'],
#  ['Clackamas', 'Oregon'],
#  ['Le Flore', 'Oklahoma'],
#  ['Marshall', 'Minnesota'],
#  ['Mackinac', 'Michigan'],
#  ['Clear Creek', 'Colorado'],
#  ['Livingston', 'Louisiana'],
#  ['Cass', 'Michigan'],
#  ['Bandera', 'Texas'],
#  ['Itasca', 'Minnesota'],
#  ['Lafayette', 'Missouri'],
#  ['Blue Earth', 'Minnesota'],
#  ['Lee', 'Iowa'],
#  ['Whitfield', 'Georgia'],
#  ['Larue', 'Kentucky'],
#  ['Jasper', 'Illinois'],
#  ['Mahoning', 'Ohio'],
#  ['Bibb', 'Alabama'],
#  ['St. Tammany', 'Louisiana'],
#  ['Williamson', 'Texas'],
#  ['Baker', 'Georgia'],
#  ['Schoharie', 'New York'],
#  ['Stanton', 'Nebraska'],
#  ['Nantucket', 'Massachusetts'],
#  ['Anderson', 'Texas'],
#  ['Wexford', 'Michigan'],
#  ['Taylor', 'Florida'],
#  ['Fort Bend', 'Texas'],
#  ['Warren', 'Indiana'],
#  ['Osceola', 'Florida'],
#  ['San Juan', 'Utah'],
#  ['Jeff Davis', 'Texas'],
#  ['Wyoming', 'New York'],
#  ['Winona', 'Minnesota'],
#  ['Montrose', 'Colorado'],
#  ['Washita', 'Oklahoma'],
#  ['Logan', 'Oklahoma'],
#  ['Pike', 'Ohio'],
#  ['Canadian', 'Oklahoma'],
#  ['Beaverhead', 'Montana'],
#  ['Calhoun', 'Michigan'],
#  ['Custer', 'Colorado'],
#  ['Washington', 'Minnesota'],
#  ['Swain', 'North Carolina'],
#  ['Vermilion', 'Louisiana'],
#  ['Grayson', 'Virginia'],
#  ['Shelby', 'Alabama'],
#  ['Culberson', 'Texas'],
#  ['Evangeline', 'Louisiana'],
#  ['Collin', 'Texas'],
#  ['Bracken', 'Kentucky'],
#  ['Traverse', 'Minnesota'],
#  ['Douglas', 'Nevada'],
#  ['Plaquemines', 'Louisiana'],
#  ['Carroll', 'Arkansas'],
#  ['Costilla', 'Colorado'],
#  ['Marshall', 'Kentucky'],
#  ['Highland', 'Virginia'],
#  ['Calaveras', 'California'],
#  ['Marshall', 'Illinois'],
#  ['Monroe', 'Pennsylvania'],
#  ['Grundy', 'Illinois'],
#  ['Leelanau', 'Michigan'],
#  ['Geary', 'Kansas'],
#  ['Clinton', 'Indiana'],
#  ['Park', 'Colorado'],
#  ['Sheridan', 'Wyoming'],
#  ['Becker', 'Minnesota'],
#  ['Kauai', 'Hawaii'],
#  ['Kalamazoo', 'Michigan'],
#  ['Seminole', 'Florida'],
#  ['Citrus', 'Florida'],
#  ['Albany', 'Wyoming'],
#  ['Kennebec', 'Maine'],
#  ['Summit', 'Colorado'],
#  ['Franklin', 'Arkansas'],
#  ['Burlington', 'New Jersey'],
#  ['Ashland', 'Ohio'],
#  ['Jefferson Davis', 'Louisiana'],
#  ['Jennings', 'Indiana'],
#  ['Cecil', 'Maryland'],
#  ['Calhoun', 'Alabama'],
#  ['St. Croix', 'Wisconsin'],
#  ['Dubuque', 'Iowa'],
#  ['Johnson', 'Arkansas'],
#  ['Kearny', 'Kansas'],
#  ['Berrien', 'Michigan'],
#  ['Wayne', 'West Virginia'],
#  ['Jefferson', 'Idaho'],
#  ['Clay', 'Missouri'],
#  ['Charlevoix', 'Michigan'],
#  ['Solano', 'California'],
#  ['Ballard', 'Kentucky'],
#  ['St. Lawrence', 'New York'],
#  ['Clark', 'Washington'],
#  ['Platte', 'Nebraska'],
#  ['Charles', 'Maryland'],
#  ['North Slope', 'Alaska'],
#  ['Bastrop', 'Texas'],
#  ['Monroe', 'Alabama'],
#  ['Kandiyohi', 'Minnesota'],
#  ...]

# %%
len(county_state)
# Out:
# 2220

# %%
county_state = sorted(county_state, key=lambda x: (x[1], x[0]))
county_state
# Out:
# [['Autauga', 'Alabama'],
#  ['Baldwin', 'Alabama'],
#  ['Barbour', 'Alabama'],
#  ['Bibb', 'Alabama'],
#  ['Calhoun', 'Alabama'],
#  ['Cherokee', 'Alabama'],
#  ['Choctaw', 'Alabama'],
#  ['Clarke', 'Alabama'],
#  ['Clay', 'Alabama'],
#  ['Cleburne', 'Alabama'],
#  ['Coffee', 'Alabama'],
#  ['Colbert', 'Alabama'],
#  ['Covington', 'Alabama'],
#  ['DeKalb', 'Alabama'],
#  ['Elmore', 'Alabama'],
#  ['Hale', 'Alabama'],
#  ['Houston', 'Alabama'],
#  ['Jackson', 'Alabama'],
#  ['Jefferson', 'Alabama'],
#  ['Lauderdale', 'Alabama'],
#  ['Lawrence', 'Alabama'],
#  ['Lee', 'Alabama'],
#  ['Limestone', 'Alabama'],
#  ['Macon', 'Alabama'],
#  ['Madison', 'Alabama'],
#  ['Marion', 'Alabama'],
#  ['Marshall', 'Alabama'],
#  ['Mobile', 'Alabama'],
#  ['Monroe', 'Alabama'],
#  ['Montgomery', 'Alabama'],
#  ['Morgan', 'Alabama'],
#  ['Perry', 'Alabama'],
#  ['Pickens', 'Alabama'],
#  ['Shelby', 'Alabama'],
#  ['St. Clair', 'Alabama'],
#  ['Sumter', 'Alabama'],
#  ['Talladega', 'Alabama'],
#  ['Tallapoosa', 'Alabama'],
#  ['Tuscaloosa', 'Alabama'],
#  ['Aleutians East', 'Alaska'],
#  ['Aleutians West', 'Alaska'],
#  ['Anchorage', 'Alaska'],
#  ['Bethel', 'Alaska'],
#  ['Bristol Bay', 'Alaska'],
#  ['Denali', 'Alaska'],
#  ['Dillingham', 'Alaska'],
#  ['Fairbanks North Star', 'Alaska'],
#  ['Haines', 'Alaska'],
#  ['Juneau', 'Alaska'],
#  ['Kenai Peninsula', 'Alaska'],
#  ['Ketchikan Gateway', 'Alaska'],
#  ['Kodiak Island', 'Alaska'],
#  ['Kusilvak', 'Alaska'],
#  ['Lake and Peninsula', 'Alaska'],
#  ['Matanuska-Susitna', 'Alaska'],
#  ['Nome', 'Alaska'],
#  ['North Slope', 'Alaska'],
#  ['Northwest Arctic', 'Alaska'],
#  ['Prince of Wales-Outer Ketchikan', 'Alaska'],
#  ['Sitka', 'Alaska'],
#  ['Skagway-Hoonah-Angoon', 'Alaska'],
#  ['Southeast Fairbanks', 'Alaska'],
#  ['Valdez-Cordova', 'Alaska'],
#  ['Yakutat', 'Alaska'],
#  ['Yukon-Koyukuk', 'Alaska'],
#  ['Apache', 'Arizona'],
#  ['Cochise', 'Arizona'],
#  ['Coconino', 'Arizona'],
#  ['Gila', 'Arizona'],
#  ['Graham', 'Arizona'],
#  ['Greenlee', 'Arizona'],
#  ['La Paz', 'Arizona'],
#  ['Maricopa', 'Arizona'],
#  ['Mohave', 'Arizona'],
#  ['Navajo', 'Arizona'],
#  ['Pima', 'Arizona'],
#  ['Pinal', 'Arizona'],
#  ['Santa Cruz', 'Arizona'],
#  ['Yavapai', 'Arizona'],
#  ['Yuma', 'Arizona'],
#  ['Arkansas', 'Arkansas'],
#  ['Ashley', 'Arkansas'],
#  ['Baxter', 'Arkansas'],
#  ['Benton', 'Arkansas'],
#  ['Boone', 'Arkansas'],
#  ['Bradley', 'Arkansas'],
#  ['Calhoun', 'Arkansas'],
#  ['Carroll', 'Arkansas'],
#  ['Chicot', 'Arkansas'],
#  ['Clark', 'Arkansas'],
#  ['Cleburne', 'Arkansas'],
#  ['Columbia', 'Arkansas'],
#  ['Conway', 'Arkansas'],
#  ['Craighead', 'Arkansas'],
#  ['Crawford', 'Arkansas'],
#  ['Crittenden', 'Arkansas'],
#  ['Cross', 'Arkansas'],
#  ['Desha', 'Arkansas'],
#  ['Faulkner', 'Arkansas'],
#  ['Franklin', 'Arkansas'],
#  ['Fulton', 'Arkansas'],
#  ['Garland', 'Arkansas'],
#  ['Grant', 'Arkansas'],
#  ['Greene', 'Arkansas'],
#  ['Hempstead', 'Arkansas'],
#  ['Hot Spring', 'Arkansas'],
#  ['Howard', 'Arkansas'],
#  ['Independence', 'Arkansas'],
#  ['Jackson', 'Arkansas'],
#  ['Jefferson', 'Arkansas'],
#  ['Johnson', 'Arkansas'],
#  ['Lafayette', 'Arkansas'],
#  ['Lawrence', 'Arkansas'],
#  ['Lee', 'Arkansas'],
#  ['Lincoln', 'Arkansas'],
#  ['Little River', 'Arkansas'],
#  ['Logan', 'Arkansas'],
#  ['Lonoke', 'Arkansas'],
#  ['Madison', 'Arkansas'],
#  ['Marion', 'Arkansas'],
#  ['Miller', 'Arkansas'],
#  ['Mississippi', 'Arkansas'],
#  ['Monroe', 'Arkansas'],
#  ['Montgomery', 'Arkansas'],
#  ['Newton', 'Arkansas'],
#  ['Ouachita', 'Arkansas'],
#  ['Perry', 'Arkansas'],
#  ['Phillips', 'Arkansas'],
#  ['Pike', 'Arkansas'],
#  ['Poinsett', 'Arkansas'],
#  ['Polk', 'Arkansas'],
#  ['Pope', 'Arkansas'],
#  ['Prairie', 'Arkansas'],
#  ['Pulaski', 'Arkansas'],
#  ['Randolph', 'Arkansas'],
#  ['Saline', 'Arkansas'],
#  ['Scott', 'Arkansas'],
#  ['Searcy', 'Arkansas'],
#  ['Sebastian', 'Arkansas'],
#  ['Sevier', 'Arkansas'],
#  ['Sharp', 'Arkansas'],
#  ['St. Francis', 'Arkansas'],
#  ['Stone', 'Arkansas'],
#  ['Union', 'Arkansas'],
#  ['Van Buren', 'Arkansas'],
#  ['Washington', 'Arkansas'],
#  ['White', 'Arkansas'],
#  ['Woodruff', 'Arkansas'],
#  ['Yell', 'Arkansas'],
#  ['Alameda', 'California'],
#  ['Alpine', 'California'],
#  ['Amador', 'California'],
#  ['Butte', 'California'],
#  ['Calaveras', 'California'],
#  ['Colusa', 'California'],
#  ['Contra Costa', 'California'],
#  ['Del Norte', 'California'],
#  ['El Dorado', 'California'],
#  ['Fresno', 'California'],
#  ['Glenn', 'California'],
#  ['Humboldt', 'California'],
#  ['Imperial', 'California'],
#  ['Inyo', 'California'],
#  ['Kern', 'California'],
#  ['Kings', 'California'],
#  ['Lake', 'California'],
#  ['Lassen', 'California'],
#  ['Los Angeles', 'California'],
#  ['Madera', 'California'],
#  ['Marin', 'California'],
#  ['Mariposa', 'California'],
#  ['Mendocino', 'California'],
#  ['Merced', 'California'],
#  ['Modoc', 'California'],
#  ['Mono', 'California'],
#  ['Monterey', 'California'],
#  ['Napa', 'California'],
#  ['Nevada', 'California'],
#  ['Orange', 'California'],
#  ['Placer', 'California'],
#  ['Plumas', 'California'],
#  ['Riverside', 'California'],
#  ['Sacramento', 'California'],
#  ['San Benito', 'California'],
#  ['San Bernardino', 'California'],
#  ['San Diego', 'California'],
#  ['San Francisco', 'California'],
#  ['San Joaquin', 'California'],
#  ['San Luis Obispo', 'California'],
#  ['San Mateo', 'California'],
#  ['Santa Barbara', 'California'],
#  ['Santa Clara', 'California'],
#  ['Santa Cruz', 'California'],
#  ['Shasta', 'California'],
#  ['Sierra', 'California'],
#  ['Siskiyou', 'California'],
#  ['Solano', 'California'],
#  ['Sonoma', 'California'],
#  ['Stanislaus', 'California'],
#  ['Sutter', 'California'],
#  ['Tehama', 'California'],
#  ['Trinity', 'California'],
#  ['Tulare', 'California'],
#  ['Tuolumne', 'California'],
#  ['Ventura', 'California'],
#  ['Yolo', 'California'],
#  ['Yuba', 'California'],
#  ['Adams', 'Colorado'],
#  ['Alamosa', 'Colorado'],
#  ['Arapahoe', 'Colorado'],
#  ['Baca', 'Colorado'],
#  ['Bent', 'Colorado'],
#  ['Boulder', 'Colorado'],
#  ['Chaffee', 'Colorado'],
#  ['Cheyenne', 'Colorado'],
#  ['Clear Creek', 'Colorado'],
#  ['Conejos', 'Colorado'],
#  ['Costilla', 'Colorado'],
#  ['Crowley', 'Colorado'],
#  ['Custer', 'Colorado'],
#  ['Delta', 'Colorado'],
#  ['Denver', 'Colorado'],
#  ['Dolores', 'Colorado'],
#  ['Douglas', 'Colorado'],
#  ['Eagle', 'Colorado'],
#  ['El Paso', 'Colorado'],
#  ['Elbert', 'Colorado'],
#  ['Fremont', 'Colorado'],
#  ['Garfield', 'Colorado'],
#  ['Gilpin', 'Colorado'],
#  ['Grand', 'Colorado'],
#  ['Gunnison', 'Colorado'],
#  ['Hinsdale', 'Colorado'],
#  ['Huerfano', 'Colorado'],
#  ['Jackson', 'Colorado'],
#  ['Jefferson', 'Colorado'],
#  ['Kiowa', 'Colorado'],
#  ['Kit Carson', 'Colorado'],
#  ['La Plata', 'Colorado'],
#  ['Lake', 'Colorado'],
#  ['Larimer', 'Colorado'],
#  ['Las Animas', 'Colorado'],
#  ['Logan', 'Colorado'],
#  ['Mesa', 'Colorado'],
#  ['Moffat', 'Colorado'],
#  ['Montezuma', 'Colorado'],
#  ['Montrose', 'Colorado'],
#  ['Morgan', 'Colorado'],
#  ['Otero', 'Colorado'],
#  ['Ouray', 'Colorado'],
#  ['Park', 'Colorado'],
#  ['Phillips', 'Colorado'],
#  ['Pitkin', 'Colorado'],
#  ['Prowers', 'Colorado'],
#  ['Pueblo', 'Colorado'],
#  ['Rio Blanco', 'Colorado'],
#  ['Rio Grande', 'Colorado'],
#  ['Routt', 'Colorado'],
#  ['Saguache', 'Colorado'],
#  ['San Juan', 'Colorado'],
#  ['Sedgwick', 'Colorado'],
#  ['Summit', 'Colorado'],
#  ['Teller', 'Colorado'],
#  ['Washington', 'Colorado'],
#  ['Weld', 'Colorado'],
#  ['Yuma', 'Colorado'],
#  ['Fairfield', 'Connecticut'],
#  ['Hartford', 'Connecticut'],
#  ['Litchfield', 'Connecticut'],
#  ['Middlesex', 'Connecticut'],
#  ['New Haven', 'Connecticut'],
#  ['New London', 'Connecticut'],
#  ['Tolland', 'Connecticut'],
#  ['Windham', 'Connecticut'],
#  ['Kent', 'Delaware'],
#  ['New Castle', 'Delaware'],
#  ['Sussex', 'Delaware'],
#  ['District of Columbia', 'District of Columbia'],
#  ['Alachua', 'Florida'],
#  ['Baker', 'Florida'],
#  ['Bay', 'Florida'],
#  ['Brevard', 'Florida'],
#  ['Broward', 'Florida'],
#  ['Charlotte', 'Florida'],
#  ['Citrus', 'Florida'],
#  ['Clay', 'Florida'],
#  ['Collier', 'Florida'],
#  ['Columbia', 'Florida'],
#  ['DeSoto', 'Florida'],
#  ['Dixie', 'Florida'],
#  ['Duval', 'Florida'],
#  ['Escambia', 'Florida'],
#  ['Flagler', 'Florida'],
#  ['Franklin', 'Florida'],
#  ['Gadsden', 'Florida'],
#  ['Glades', 'Florida'],
#  ['Gulf', 'Florida'],
#  ['Hamilton', 'Florida'],
#  ['Hendry', 'Florida'],
#  ['Hernando', 'Florida'],
#  ['Highlands', 'Florida'],
#  ['Hillsborough', 'Florida'],
#  ['Indian River', 'Florida'],
#  ['Jackson', 'Florida'],
#  ['Jefferson', 'Florida'],
#  ['Lafayette', 'Florida'],
#  ['Lake', 'Florida'],
#  ['Lee', 'Florida'],
#  ['Leon', 'Florida'],
#  ['Levy', 'Florida'],
#  ['Liberty', 'Florida'],
#  ['Manatee', 'Florida'],
#  ['Marion', 'Florida'],
#  ['Martin', 'Florida'],
#  ['Miami-Dade', 'Florida'],
#  ['Monroe', 'Florida'],
#  ['Nassau', 'Florida'],
#  ['Okaloosa', 'Florida'],
#  ['Okeechobee', 'Florida'],
#  ['Orange', 'Florida'],
#  ['Osceola', 'Florida'],
#  ['Palm Beach', 'Florida'],
#  ['Pasco', 'Florida'],
#  ['Pinellas', 'Florida'],
#  ['Polk', 'Florida'],
#  ['Putnam', 'Florida'],
#  ['Santa Rosa', 'Florida'],
#  ['Sarasota', 'Florida'],
#  ['Seminole', 'Florida'],
#  ['St. Johns', 'Florida'],
#  ['St. Lucie', 'Florida'],
#  ['Sumter', 'Florida'],
#  ['Taylor', 'Florida'],
#  ['Volusia', 'Florida'],
#  ['Wakulla', 'Florida'],
#  ['Bacon', 'Georgia'],
#  ['Baker', 'Georgia'],
#  ['Banks', 'Georgia'],
#  ['Barrow', 'Georgia'],
#  ['Bartow', 'Georgia'],
#  ['Bibb', 'Georgia'],
#  ['Bleckley', 'Georgia'],
#  ['Bryan', 'Georgia'],
#  ['Bulloch', 'Georgia'],
#  ['Camden', 'Georgia'],
#  ['Catoosa', 'Georgia'],
#  ['Charlton', 'Georgia'],
#  ['Chatham', 'Georgia'],
#  ['Cherokee', 'Georgia'],
#  ['Clarke', 'Georgia'],
#  ['Clayton', 'Georgia'],
#  ['Clinch', 'Georgia'],
#  ['Cobb', 'Georgia'],
#  ['Colquitt', 'Georgia'],
#  ['Cook', 'Georgia'],
#  ['Coweta', 'Georgia'],
#  ['Crawford', 'Georgia'],
#  ['Dade', 'Georgia'],
#  ['Dawson', 'Georgia'],
#  ['DeKalb', 'Georgia'],
#  ['Decatur', 'Georgia'],
#  ['Dougherty', 'Georgia'],
#  ['Effingham', 'Georgia'],
#  ['Emanuel', 'Georgia'],
#  ['Evans', 'Georgia'],
#  ['Fayette', 'Georgia'],
#  ['Floyd', 'Georgia'],
#  ['Forsyth', 'Georgia'],
#  ['Franklin', 'Georgia'],
#  ['Fulton', 'Georgia'],
#  ['Gilmer', 'Georgia'],
#  ['Glascock', 'Georgia'],
#  ['Glynn', 'Georgia'],
#  ['Gordon', 'Georgia'],
#  ['Greene', 'Georgia'],
#  ['Gwinnett', 'Georgia'],
#  ['Habersham', 'Georgia'],
#  ['Haralson', 'Georgia'],
#  ['Hart', 'Georgia'],
#  ['Henry', 'Georgia'],
#  ['Houston', 'Georgia'],
#  ['Jackson', 'Georgia'],
#  ['Jasper', 'Georgia'],
#  ['Jenkins', 'Georgia'],
#  ['Jones', 'Georgia'],
#  ['Lamar', 'Georgia'],
#  ['Laurens', 'Georgia'],
#  ['Liberty', 'Georgia'],
#  ['Lincoln', 'Georgia'],
#  ['Long', 'Georgia'],
#  ['Lowndes', 'Georgia'],
#  ['Lumpkin', 'Georgia'],
#  ['Macon', 'Georgia'],
#  ['Madison', 'Georgia'],
#  ['Marion', 'Georgia'],
#  ['McIntosh', 'Georgia'],
#  ['Meriwether', 'Georgia'],
#  ['Mitchell', 'Georgia'],
#  ['Monroe', 'Georgia'],
#  ['Montgomery', 'Georgia'],
#  ['Morgan', 'Georgia'],
#  ['Murray', 'Georgia'],
#  ['Muscogee', 'Georgia'],
#  ['Newton', 'Georgia'],
#  ['Oconee', 'Georgia'],
#  ['Paulding', 'Georgia'],
#  ['Peach', 'Georgia'],
#  ['Polk', 'Georgia'],
#  ['Rabun', 'Georgia'],
#  ['Randolph', 'Georgia'],
#  ['Richmond', 'Georgia'],
#  ['Rockdale', 'Georgia'],
#  ['Schley', 'Georgia'],
#  ['Seminole', 'Georgia'],
#  ['Stewart', 'Georgia'],
#  ['Sumter', 'Georgia'],
#  ['Talbot', 'Georgia'],
#  ['Tattnall', 'Georgia'],
#  ['Taylor', 'Georgia'],
#  ['Terrell', 'Georgia'],
#  ['Thomas', 'Georgia'],
#  ['Towns', 'Georgia'],
#  ['Troup', 'Georgia'],
#  ['Turner', 'Georgia'],
#  ['Twiggs', 'Georgia'],
#  ['Union', 'Georgia'],
#  ['Walker', 'Georgia'],
#  ['Walton', 'Georgia'],
#  ['Ware', 'Georgia'],
#  ['White', 'Georgia'],
#  ['Whitfield', 'Georgia'],
#  ['Worth', 'Georgia'],
#  ['Hawaii', 'Hawaii'],
#  ['Honolulu', 'Hawaii'],
#  ['Kauai', 'Hawaii'],
#  ['Maui', 'Hawaii'],
#  ['Ada', 'Idaho'],
#  ['Adams', 'Idaho'],
#  ['Bannock', 'Idaho'],
#  ['Bear Lake', 'Idaho'],
#  ['Benewah', 'Idaho'],
#  ['Bingham', 'Idaho'],
#  ['Blaine', 'Idaho'],
#  ['Boise', 'Idaho'],
#  ['Bonner', 'Idaho'],
#  ['Bonneville', 'Idaho'],
#  ['Boundary', 'Idaho'],
#  ['Butte', 'Idaho'],
#  ['Camas', 'Idaho'],
#  ['Canyon', 'Idaho'],
#  ['Caribou', 'Idaho'],
#  ['Cassia', 'Idaho'],
#  ['Clark', 'Idaho'],
#  ['Clearwater', 'Idaho'],
#  ['Custer', 'Idaho'],
#  ['Elmore', 'Idaho'],
#  ['Franklin', 'Idaho'],
#  ['Fremont', 'Idaho'],
#  ['Gooding', 'Idaho'],
#  ['Idaho', 'Idaho'],
#  ['Jefferson', 'Idaho'],
#  ['Jerome', 'Idaho'],
#  ['Kootenai', 'Idaho'],
#  ['Latah', 'Idaho'],
#  ['Lemhi', 'Idaho'],
#  ['Lewis', 'Idaho'],
#  ['Lincoln', 'Idaho'],
#  ['Nez Perce', 'Idaho'],
#  ['Oneida', 'Idaho'],
#  ['Owyhee', 'Idaho'],
#  ['Payette', 'Idaho'],
#  ['Power', 'Idaho'],
#  ['Shoshone', 'Idaho'],
#  ['Teton', 'Idaho'],
#  ['Twin Falls', 'Idaho'],
#  ['Valley', 'Idaho'],
#  ['Washington', 'Idaho'],
#  ['Adams', 'Illinois'],
#  ['Alexander', 'Illinois'],
#  ['Bureau', 'Illinois'],
#  ['Calhoun', 'Illinois'],
#  ['Carroll', 'Illinois'],
#  ['Cass', 'Illinois'],
#  ['Champaign', 'Illinois'],
#  ['Christian', 'Illinois'],
#  ['Clark', 'Illinois'],
#  ['Clinton', 'Illinois'],
#  ['Coles', 'Illinois'],
#  ['Cook', 'Illinois'],
#  ['De Witt', 'Illinois'],
#  ['DeKalb', 'Illinois'],
#  ['Douglas', 'Illinois'],
#  ['DuPage', 'Illinois'],
#  ['Effingham', 'Illinois'],
#  ['Ford', 'Illinois'],
#  ['Franklin', 'Illinois'],
#  ['Fulton', 'Illinois'],
#  ['Gallatin', 'Illinois'],
#  ['Grundy', 'Illinois'],
#  ['Hancock', 'Illinois'],
#  ['Henderson', 'Illinois'],
#  ['Henry', 'Illinois'],
#  ['Iroquois', 'Illinois'],
#  ['Jackson', 'Illinois'],
#  ['Jasper', 'Illinois'],
#  ['Jefferson', 'Illinois'],
#  ['Jersey', 'Illinois'],
#  ['Jo Daviess', 'Illinois'],
#  ['Johnson', 'Illinois'],
#  ['Kane', 'Illinois'],
#  ['Kankakee', 'Illinois'],
#  ['Kendall', 'Illinois'],
#  ['Knox', 'Illinois'],
#  ['Lake', 'Illinois'],
#  ['Lee', 'Illinois'],
#  ['Macoupin', 'Illinois'],
#  ['Madison', 'Illinois'],
#  ['Marion', 'Illinois'],
#  ['Marshall', 'Illinois'],
#  ['Mason', 'Illinois'],
#  ['Massac', 'Illinois'],
#  ['McHenry', 'Illinois'],
#  ['McLean', 'Illinois'],
#  ['Menard', 'Illinois'],
#  ['Monroe', 'Illinois'],
#  ['Morgan', 'Illinois'],
#  ['Moultrie', 'Illinois'],
#  ['Ogle', 'Illinois'],
#  ['Peoria', 'Illinois'],
#  ['Pike', 'Illinois'],
#  ['Pope', 'Illinois'],
#  ['Pulaski', 'Illinois'],
#  ['Rock Island', 'Illinois'],
#  ['Saline', 'Illinois'],
#  ['Sangamon', 'Illinois'],
#  ['Shelby', 'Illinois'],
#  ['St. Clair', 'Illinois'],
#  ['Stephenson', 'Illinois'],
#  ['Tazewell', 'Illinois'],
#  ['Union', 'Illinois'],
#  ['Vermilion', 'Illinois'],
#  ['Wabash', 'Illinois'],
#  ['Warren', 'Illinois'],
#  ['Washington', 'Illinois'],
#  ['Whiteside', 'Illinois'],
#  ['Will', 'Illinois'],
#  ['Williamson', 'Illinois'],
#  ['Winnebago', 'Illinois'],
#  ['Woodford', 'Illinois'],
#  ['Allen', 'Indiana'],
#  ['Bartholomew', 'Indiana'],
#  ['Benton', 'Indiana'],
#  ['Boone', 'Indiana'],
#  ['Brown', 'Indiana'],
#  ['Clark', 'Indiana'],
#  ['Clinton', 'Indiana'],
#  ['Crawford', 'Indiana'],
#  ['Daviess', 'Indiana'],
#  ['DeKalb', 'Indiana'],
#  ['Dearborn', 'Indiana'],
#  ['Delaware', 'Indiana'],
#  ['Elkhart', 'Indiana'],
#  ['Franklin', 'Indiana'],
#  ['Fulton', 'Indiana'],
#  ['Gibson', 'Indiana'],
#  ['Hamilton', 'Indiana'],
#  ['Harrison', 'Indiana'],
#  ['Henry', 'Indiana'],
#  ['Howard', 'Indiana'],
#  ['Huntington', 'Indiana'],
#  ['Jackson', 'Indiana'],
#  ['Jasper', 'Indiana'],
#  ['Jefferson', 'Indiana'],
#  ['Jennings', 'Indiana'],
#  ['Knox', 'Indiana'],
#  ['Kosciusko', 'Indiana'],
#  ['LaGrange', 'Indiana'],
#  ['LaPorte', 'Indiana'],
#  ['Lake', 'Indiana'],
#  ['Madison', 'Indiana'],
#  ['Marion', 'Indiana'],
#  ['Monroe', 'Indiana'],
#  ['Montgomery', 'Indiana'],
#  ['Newton', 'Indiana'],
#  ['Noble', 'Indiana'],
#  ['Ohio', 'Indiana'],
#  ['Orange', 'Indiana'],
#  ['Owen', 'Indiana'],
#  ['Parke', 'Indiana'],
#  ['Porter', 'Indiana'],
#  ['Posey', 'Indiana'],
#  ['Pulaski', 'Indiana'],
#  ['Putnam', 'Indiana'],
#  ['Ripley', 'Indiana'],
#  ['St. Joseph', 'Indiana'],
#  ['Steuben', 'Indiana'],
#  ['Sullivan', 'Indiana'],
#  ['Tippecanoe', 'Indiana'],
#  ['Union', 'Indiana'],
#  ['Vanderburgh', 'Indiana'],
#  ['Vigo', 'Indiana'],
#  ['Wabash', 'Indiana'],
#  ['Warren', 'Indiana'],
#  ['Warrick', 'Indiana'],
#  ['Wayne', 'Indiana'],
#  ['White', 'Indiana'],
#  ['Allamakee', 'Iowa'],
#  ['Benton', 'Iowa'],
#  ['Black Hawk', 'Iowa'],
#  ['Boone', 'Iowa'],
#  ['Buchanan', 'Iowa'],
#  ['Cass', 'Iowa'],
#  ['Cedar', 'Iowa'],
#  ['Chickasaw', 'Iowa'],
#  ['Clayton', 'Iowa'],
#  ['Clinton', 'Iowa'],
#  ['Dallas', 'Iowa'],
#  ['Decatur', 'Iowa'],
#  ['Des Moines', 'Iowa'],
#  ['Dickinson', 'Iowa'],
#  ['Dubuque', 'Iowa'],
#  ['Fremont', 'Iowa'],
#  ['Greene', 'Iowa'],
#  ['Guthrie', 'Iowa'],
#  ['Hamilton', 'Iowa'],
#  ['Hardin', 'Iowa'],
#  ['Harrison', 'Iowa'],
#  ['Henry', 'Iowa'],
#  ['Iowa', 'Iowa'],
#  ['Jackson', 'Iowa'],
#  ['Jasper', 'Iowa'],
#  ['Johnson', 'Iowa'],
#  ['Lee', 'Iowa'],
#  ['Linn', 'Iowa'],
#  ['Louisa', 'Iowa'],
#  ['Marion', 'Iowa'],
#  ['Muscatine', 'Iowa'],
#  ['Polk', 'Iowa'],
#  ['Pottawattamie', 'Iowa'],
#  ['Poweshiek', 'Iowa'],
#  ['Scott', 'Iowa'],
#  ['Sioux', 'Iowa'],
#  ['Story', 'Iowa'],
#  ['Tama', 'Iowa'],
#  ['Union', 'Iowa'],
#  ['Van Buren', 'Iowa'],
#  ['Warren', 'Iowa'],
#  ['Winneshiek', 'Iowa'],
#  ['Woodbury', 'Iowa'],
#  ['Allen', 'Kansas'],
#  ['Atchison', 'Kansas'],
#  ['Barber', 'Kansas'],
#  ['Barton', 'Kansas'],
#  ['Chase', 'Kansas'],
#  ['Cherokee', 'Kansas'],
#  ['Clay', 'Kansas'],
#  ['Cloud', 'Kansas'],
#  ['Coffey', 'Kansas'],
#  ['Comanche', 'Kansas'],
#  ['Cowley', 'Kansas'],
#  ['Crawford', 'Kansas'],
#  ['Dickinson', 'Kansas'],
#  ['Douglas', 'Kansas'],
#  ['Ellsworth', 'Kansas'],
#  ['Finney', 'Kansas'],
#  ['Geary', 'Kansas'],
#  ['Gove', 'Kansas'],
#  ['Harvey', 'Kansas'],
#  ['Jefferson', 'Kansas'],
#  ['Jewell', 'Kansas'],
#  ['Johnson', 'Kansas'],
#  ['Kearny', 'Kansas'],
#  ['Kingman', 'Kansas'],
#  ['Kiowa', 'Kansas'],
#  ['Leavenworth', 'Kansas'],
#  ['Linn', 'Kansas'],
#  ['Lyon', 'Kansas'],
#  ['Marion', 'Kansas'],
#  ['Meade', 'Kansas'],
#  ['Miami', 'Kansas'],
#  ['Mitchell', 'Kansas'],
#  ['Montgomery', 'Kansas'],
#  ['Morton', 'Kansas'],
#  ['Norton', 'Kansas'],
#  ['Osage', 'Kansas'],
#  ['Osborne', 'Kansas'],
#  ['Pottawatomie', 'Kansas'],
#  ['Pratt', 'Kansas'],
#  ['Reno', 'Kansas'],
#  ['Republic', 'Kansas'],
#  ['Riley', 'Kansas'],
#  ['Rooks', 'Kansas'],
#  ['Russell', 'Kansas'],
#  ['Saline', 'Kansas'],
#  ['Sedgwick', 'Kansas'],
#  ['Seward', 'Kansas'],
#  ['Shawnee', 'Kansas'],
#  ['Stafford', 'Kansas'],
#  ['Thomas', 'Kansas'],
#  ['Trego', 'Kansas'],
#  ['Wabaunsee', 'Kansas'],
#  ['Wilson', 'Kansas'],
#  ['Woodson', 'Kansas'],
#  ['Wyandotte', 'Kansas'],
#  ['Adair', 'Kentucky'],
#  ['Ballard', 'Kentucky'],
#  ['Bell', 'Kentucky'],
#  ['Boone', 'Kentucky'],
#  ['Boyd', 'Kentucky'],
#  ['Boyle', 'Kentucky'],
#  ['Bracken', 'Kentucky'],
#  ['Breathitt', 'Kentucky'],
#  ['Bullitt', 'Kentucky'],
#  ['Calloway', 'Kentucky'],
#  ['Campbell', 'Kentucky'],
#  ['Carter', 'Kentucky'],
#  ['Christian', 'Kentucky'],
#  ['Edmonson', 'Kentucky'],
#  ['Fayette', 'Kentucky'],
#  ['Fulton', 'Kentucky'],
#  ['Graves', 'Kentucky'],
#  ['Greenup', 'Kentucky'],
#  ['Hardin', 'Kentucky'],
#  ['Harlan', 'Kentucky'],
#  ['Henderson', 'Kentucky'],
#  ['Hickman', 'Kentucky'],
#  ['Jefferson', 'Kentucky'],
#  ['Jessamine', 'Kentucky'],
#  ['Kenton', 'Kentucky'],
#  ['Knox', 'Kentucky'],
#  ['Larue', 'Kentucky'],
#  ['Laurel', 'Kentucky'],
#  ['Letcher', 'Kentucky'],
#  ['Lewis', 'Kentucky'],
#  ['Livingston', 'Kentucky'],
#  ['Lyon', 'Kentucky'],
#  ['Madison', 'Kentucky'],
#  ['Marshall', 'Kentucky'],
#  ['Martin', 'Kentucky'],
#  ['McCracken', 'Kentucky'],
#  ['McCreary', 'Kentucky'],
#  ['Meade', 'Kentucky'],
#  ['Mercer', 'Kentucky'],
#  ['Muhlenberg', 'Kentucky'],
#  ['Ohio', 'Kentucky'],
#  ['Owen', 'Kentucky'],
#  ['Pulaski', 'Kentucky'],
#  ['Rockcastle', 'Kentucky'],
#  ['Rowan', 'Kentucky'],
#  ['Russell', 'Kentucky'],
#  ['Spencer', 'Kentucky'],
#  ['Taylor', 'Kentucky'],
#  ['Trigg', 'Kentucky'],
#  ['Warren', 'Kentucky'],
#  ['Washington', 'Kentucky'],
#  ['Wayne', 'Kentucky'],
#  ['Whitley', 'Kentucky'],
#  ['Wolfe', 'Kentucky'],
#  ['Woodford', 'Kentucky'],
#  ['Acadia', 'Louisiana'],
#  ['Allen', 'Louisiana'],
#  ['Ascension', 'Louisiana'],
#  ['Avoyelles', 'Louisiana'],
#  ['Bienville', 'Louisiana'],
#  ['Bossier', 'Louisiana'],
#  ['Caddo', 'Louisiana'],
#  ['Calcasieu', 'Louisiana'],
#  ['Cameron', 'Louisiana'],
#  ['Claiborne', 'Louisiana'],
#  ['De Soto', 'Louisiana'],
#  ['East Baton Rouge', 'Louisiana'],
#  ['East Feliciana', 'Louisiana'],
#  ['Evangeline', 'Louisiana'],
#  ['Iberia', 'Louisiana'],
#  ['Iberville', 'Louisiana'],
#  ['Jefferson', 'Louisiana'],
#  ['Jefferson Davis', 'Louisiana'],
#  ['Lafayette', 'Louisiana'],
#  ['Lafourche', 'Louisiana'],
#  ['Livingston', 'Louisiana'],
#  ['Madison', 'Louisiana'],
#  ['Morehouse', 'Louisiana'],
#  ['Natchitoches', 'Louisiana'],
#  ['Orleans', 'Louisiana'],
#  ['Ouachita', 'Louisiana'],
#  ['Plaquemines', 'Louisiana'],
#  ['Pointe Coupee', 'Louisiana'],
#  ['Rapides', 'Louisiana'],
#  ['Red River', 'Louisiana'],
#  ['St. Bernard', 'Louisiana'],
#  ['St. Charles', 'Louisiana'],
#  ['St. James', 'Louisiana'],
#  ['St. John the Baptist', 'Louisiana'],
#  ['St. Landry', 'Louisiana'],
#  ['St. Martin', 'Louisiana'],
#  ['St. Tammany', 'Louisiana'],
#  ['Terrebonne', 'Louisiana'],
#  ['Union', 'Louisiana'],
#  ['Vermilion', 'Louisiana'],
#  ['Vernon', 'Louisiana'],
#  ['Washington', 'Louisiana'],
#  ['West Baton Rouge', 'Louisiana'],
#  ['West Feliciana', 'Louisiana'],
#  ['Androscoggin', 'Maine'],
#  ['Aroostook', 'Maine'],
#  ['Cumberland', 'Maine'],
#  ['Franklin', 'Maine'],
#  ['Hancock', 'Maine'],
#  ['Kennebec', 'Maine'],
#  ['Knox', 'Maine'],
#  ['Lincoln', 'Maine'],
#  ['Oxford', 'Maine'],
#  ['Penobscot', 'Maine'],
#  ['Piscataquis', 'Maine'],
#  ['Sagadahoc', 'Maine'],
#  ['Somerset', 'Maine'],
#  ['Waldo', 'Maine'],
#  ['Washington', 'Maine'],
#  ['York', 'Maine'],
#  ['Allegany', 'Maryland'],
#  ['Anne Arundel', 'Maryland'],
#  ['Baltimore', 'Maryland'],
#  ['Calvert', 'Maryland'],
#  ['Caroline', 'Maryland'],
#  ['Carroll', 'Maryland'],
#  ['Cecil', 'Maryland'],
#  ['Charles', 'Maryland'],
#  ['Dorchester', 'Maryland'],
#  ['Frederick', 'Maryland'],
#  ['Garrett', 'Maryland'],
#  ['Harford', 'Maryland'],
#  ['Howard', 'Maryland'],
#  ['Kent', 'Maryland'],
#  ['Montgomery', 'Maryland'],
#  ["Prince George's", 'Maryland'],
#  ["Queen Anne's", 'Maryland'],
#  ['Somerset', 'Maryland'],
#  ["St. Mary's", 'Maryland'],
#  ['Talbot', 'Maryland'],
#  ['Washington', 'Maryland'],
#  ['Wicomico', 'Maryland'],
#  ['Worcester', 'Maryland'],
#  ['Barnstable', 'Massachusetts'],
#  ['Berkshire', 'Massachusetts'],
#  ['Bristol', 'Massachusetts'],
#  ['Dukes', 'Massachusetts'],
#  ['Essex', 'Massachusetts'],
#  ['Franklin', 'Massachusetts'],
#  ['Hampden', 'Massachusetts'],
#  ['Hampshire', 'Massachusetts'],
#  ['Middlesex', 'Massachusetts'],
#  ['Nantucket', 'Massachusetts'],
#  ['Norfolk', 'Massachusetts'],
#  ['Plymouth', 'Massachusetts'],
#  ['Suffolk', 'Massachusetts'],
#  ['Worcester', 'Massachusetts'],
#  ['Alcona', 'Michigan'],
#  ['Alger', 'Michigan'],
#  ['Allegan', 'Michigan'],
#  ['Alpena', 'Michigan'],
#  ['Antrim', 'Michigan'],
#  ['Arenac', 'Michigan'],
#  ['Baraga', 'Michigan'],
#  ['Barry', 'Michigan'],
#  ['Bay', 'Michigan'],
#  ['Benzie', 'Michigan'],
#  ['Berrien', 'Michigan'],
#  ['Branch', 'Michigan'],
#  ['Calhoun', 'Michigan'],
#  ['Cass', 'Michigan'],
#  ['Charlevoix', 'Michigan'],
#  ['Cheboygan', 'Michigan'],
#  ['Chippewa', 'Michigan'],
#  ['Clare', 'Michigan'],
#  ['Clinton', 'Michigan'],
#  ['Crawford', 'Michigan'],
#  ['Delta', 'Michigan'],
#  ['Dickinson', 'Michigan'],
#  ['Eaton', 'Michigan'],
#  ['Emmet', 'Michigan'],
#  ['Genesee', 'Michigan'],
#  ['Gladwin', 'Michigan'],
#  ['Gogebic', 'Michigan'],
#  ['Grand Traverse', 'Michigan'],
#  ['Gratiot', 'Michigan'],
#  ['Hillsdale', 'Michigan'],
#  ['Houghton', 'Michigan'],
#  ['Huron', 'Michigan'],
#  ['Ingham', 'Michigan'],
#  ['Ionia', 'Michigan'],
#  ['Iosco', 'Michigan'],
#  ['Iron', 'Michigan'],
#  ['Isabella', 'Michigan'],
#  ['Jackson', 'Michigan'],
#  ['Kalamazoo', 'Michigan'],
#  ['Kalkaska', 'Michigan'],
#  ['Kent', 'Michigan'],
#  ['Keweenaw', 'Michigan'],
#  ['Lapeer', 'Michigan'],
#  ['Leelanau', 'Michigan'],
#  ['Lenawee', 'Michigan'],
#  ['Livingston', 'Michigan'],
#  ['Luce', 'Michigan'],
#  ['Mackinac', 'Michigan'],
#  ['Macomb', 'Michigan'],
#  ['Manistee', 'Michigan'],
#  ['Marquette', 'Michigan'],
#  ['Mason', 'Michigan'],
#  ['Mecosta', 'Michigan'],
#  ['Midland', 'Michigan'],
#  ['Missaukee', 'Michigan'],
#  ['Monroe', 'Michigan'],
#  ['Montcalm', 'Michigan'],
#  ['Montmorency', 'Michigan'],
#  ['Muskegon', 'Michigan'],
#  ['Newaygo', 'Michigan'],
#  ['Oakland', 'Michigan'],
#  ['Oceana', 'Michigan'],
#  ['Ogemaw', 'Michigan'],
#  ['Ontonagon', 'Michigan'],
#  ['Osceola', 'Michigan'],
#  ['Oscoda', 'Michigan'],
#  ['Otsego', 'Michigan'],
#  ['Ottawa', 'Michigan'],
#  ['Presque Isle', 'Michigan'],
#  ['Roscommon', 'Michigan'],
#  ['Saginaw', 'Michigan'],
#  ['Sanilac', 'Michigan'],
#  ['Schoolcraft', 'Michigan'],
#  ['Shiawassee', 'Michigan'],
#  ['St. Clair', 'Michigan'],
#  ['St. Joseph', 'Michigan'],
#  ['Tuscola', 'Michigan'],
#  ['Van Buren', 'Michigan'],
#  ['Washtenaw', 'Michigan'],
#  ['Wayne', 'Michigan'],
#  ['Wexford', 'Michigan'],
#  ['Aitkin', 'Minnesota'],
#  ['Anoka', 'Minnesota'],
#  ['Becker', 'Minnesota'],
#  ['Beltrami', 'Minnesota'],
#  ['Big Stone', 'Minnesota'],
#  ['Blue Earth', 'Minnesota'],
#  ['Brown', 'Minnesota'],
#  ['Carlton', 'Minnesota'],
#  ['Carver', 'Minnesota'],
#  ['Cass', 'Minnesota'],
#  ['Chisago', 'Minnesota'],
#  ['Clay', 'Minnesota'],
#  ['Clearwater', 'Minnesota'],
#  ['Cook', 'Minnesota'],
#  ['Cottonwood', 'Minnesota'],
#  ['Crow Wing', 'Minnesota'],
#  ['Dakota', 'Minnesota'],
#  ['Douglas', 'Minnesota'],
#  ['Faribault', 'Minnesota'],
#  ['Fillmore', 'Minnesota'],
#  ['Freeborn', 'Minnesota'],
#  ['Goodhue', 'Minnesota'],
#  ['Grant', 'Minnesota'],
#  ['Hennepin', 'Minnesota'],
#  ['Houston', 'Minnesota'],
#  ['Hubbard', 'Minnesota'],
#  ['Itasca', 'Minnesota'],
#  ['Jackson', 'Minnesota'],
#  ['Kandiyohi', 'Minnesota'],
#  ['Kittson', 'Minnesota'],
#  ['Koochiching', 'Minnesota'],
#  ['Lac qui Parle', 'Minnesota'],
#  ['Lake', 'Minnesota'],
#  ['Lake of the Woods', 'Minnesota'],
#  ['Le Sueur', 'Minnesota'],
#  ['Lincoln', 'Minnesota'],
#  ['Lyon', 'Minnesota'],
#  ['Mahnomen', 'Minnesota'],
#  ['Marshall', 'Minnesota'],
#  ['McLeod', 'Minnesota'],
#  ['Meeker', 'Minnesota'],
#  ['Mille Lacs', 'Minnesota'],
#  ['Morrison', 'Minnesota'],
#  ['Mower', 'Minnesota'],
#  ['Murray', 'Minnesota'],
#  ['Nicollet', 'Minnesota'],
#  ['Norman', 'Minnesota'],
#  ['Olmsted', 'Minnesota'],
#  ['Otter Tail', 'Minnesota'],
#  ['Pine', 'Minnesota'],
#  ['Pipestone', 'Minnesota'],
#  ['Polk', 'Minnesota'],
#  ['Pope', 'Minnesota'],
#  ['Ramsey', 'Minnesota'],
#  ['Redwood', 'Minnesota'],
#  ['Renville', 'Minnesota'],
#  ['Rice', 'Minnesota'],
#  ['Rock', 'Minnesota'],
#  ['Roseau', 'Minnesota'],
#  ['Scott', 'Minnesota'],
#  ['St. Louis', 'Minnesota'],
#  ['Stearns', 'Minnesota'],
#  ['Steele', 'Minnesota'],
#  ...]

# %%
county_state[0]
# Out:
# ['Autauga', 'Alabama']

# %%
states = sorted(list(set([cs[1] for cs in county_state])))
states
# Out:
# ['Alabama',
#  'Alaska',
#  'Arizona',
#  'Arkansas',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'Delaware',
#  'District of Columbia',
#  'Florida',
#  'Georgia',
#  'Hawaii',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Kansas',
#  'Kentucky',
#  'Louisiana',
#  'Maine',
#  'Maryland',
#  'Massachusetts',
#  'Michigan',
#  'Minnesota',
#  'Mississippi',
#  'Missouri',
#  'Montana',
#  'Nebraska',
#  'Nevada',
#  'New Hampshire',
#  'New Jersey',
#  'New Mexico',
#  'New York',
#  'North Carolina',
#  'North Dakota',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Rhode Island',
#  'South Carolina',
#  'South Dakota',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'Vermont',
#  'Virginia',
#  'Washington',
#  'West Virginia',
#  'Wisconsin',
#  'Wyoming']

# %%
len(states)
# Out:
# 51

# %%
len(State.query.all())
# Out:
# 0

# %%
for state in states:
    state_in = State(name=state)
    db.session.add(state_in)
    
db.session.commit()

# %%
alabama = State.query.first()
alabama.counties
# Out:
# []

# %%
db_states = State.query.all()

for state in db_states:
    print(state.id, state.name)

# %%
db_states[0].counties

# %%
dir(County)

# %%
County.__table__
# Out:
# Table('county', MetaData(bind=None), Column('id', Integer(), table=<county>, primary_key=True, nullable=False), Column('county_name', String(length=50), table=<county>, nullable=False), Column('state_id', Integer(), ForeignKey('state.id'), table=<county>, nullable=False), schema=None)

# %%
for cs in county_state:
    county_in = County(county_name=cs[0], county_state=State.query.filter_by(name=cs[1]).first())
    db.session.add(county_in)

db.session.commit()

# %%
for county in alabama.counties:
    print(county.county_name, alabama.name)
# Out:
# Autauga Alabama
# Baldwin Alabama
# Barbour Alabama
# Bibb Alabama
# Calhoun Alabama
# Cherokee Alabama
# Choctaw Alabama
# Clarke Alabama
# Clay Alabama
# Cleburne Alabama
# Coffee Alabama
# Colbert Alabama
# Covington Alabama
# DeKalb Alabama
# Elmore Alabama
# Hale Alabama
# Houston Alabama
# Jackson Alabama
# Jefferson Alabama
# Lauderdale Alabama
# Lawrence Alabama
# Lee Alabama
# Limestone Alabama
# Macon Alabama
# Madison Alabama
# Marion Alabama
# Marshall Alabama
# Mobile Alabama
# Monroe Alabama
# Montgomery Alabama
# Morgan Alabama
# Perry Alabama
# Pickens Alabama
# Shelby Alabama
# St. Clair Alabama
# Sumter Alabama
# Talladega Alabama
# Tallapoosa Alabama
# Tuscaloosa Alabama

# %%
autauga = County.query.first()
dir(autauga)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__mapper__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__table__',
#  '__tablename__',
#  '__weakref__',
#  '_decl_class_registry',
#  '_sa_class_manager',
#  '_sa_instance_state',
#  'county_name',
#  'county_state',
#  'id',
#  'metadata',
#  'query',
#  'query_class',
#  'region',
#  'state_id']

# %%
autauga.county_state.name
# Out:
# 'Alabama'

# %%
db_counties = County.query.all()

for county in db_counties:
    print(county.id, county.county_name, county.)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-0e3cfdab19f6> in <module>
#       2
#       3 for county in db_counties:
# ----> 4     print(county.id, county.county_name, county.state_id.name)
#
# AttributeError: 'int' object has no attribute 'name'

# %%
for season in ['Winter', 'Spring', 'Summer', 'Fall']:
    seas_in = Season(name=season)
    db.session.add(seas_in)

db.session.commit()

# %%
[season.name for season in Season.query.all()]
# Out:
# ['Winter', 'Spring', 'Summer', 'Fall']
