# %%
from ebird import db
# Out:
# C:\Users\jayja\anaconda3\envs\flask-kernel\lib\site-packages\flask_sqlalchemy\__init__.py:833: FSADeprecationWarning: SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and will be disabled by default in the future.  Set it to True or False to suppress this warning.
#   warnings.warn(FSADeprecationWarning(

# %%
from ebird.models import Bird, County, State, Season, Region, Lookup
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-27-227e003225df> in <module>
# ----> 1 from ebird.models import Bird, County, State, Season, Region, Lookup
#
# ImportError: cannot import name 'Lookup' from 'ebird.models' (C:\Users\jayja\Desktop\repos\noreallyimfine\ebird-project\ebird\models.py)

# %%
db.create_all()

# %%
Bird.query.first()

# %%
import pandas as pd
birds = pd.read_csv('C:/Users/jayja/Desktop/bird.csv')

# %%
for bird in birds['0']:
    input = Bird(name=bird)
    db.session.add(input)

db.session.commit()

# %%
len(Bird.query.all())
# Out:
# 790

# %%
birds = Bird.query.all()

for bird in birds:
    print(bird.id, bird.name)

# %%
from joblib import load

# %%
cs2r = load("C:/Users/jayja/Desktop/old-ebird/bird_app/utils/counties_to_regions.joblib")
cs2r
# Out:
# {'Autauga,Alabama': 'Deep South',
#  'Baldwin,Alabama': 'Gulf Coast',
#  'Barbour,Alabama': 'Deep South',
#  'Bibb,Alabama': 'Appohzarka',
#  'Blount,Alabama': 'Appohzarka',
#  'Bullock,Alabama': 'Deep South',
#  'Butler,Alabama': 'Deep South',
#  'Calhoun,Alabama': 'Appohzarka',
#  'Chambers,Alabama': 'Deep South',
#  'Cherokee,Alabama': 'Appohzarka',
#  'Chilton,Alabama': 'Appohzarka',
#  'Choctaw,Alabama': 'Deep South',
#  'Clarke,Alabama': 'Deep South',
#  'Clay,Alabama': 'Deep South',
#  'Cleburne,Alabama': 'Appohzarka',
#  'Coffee,Alabama': 'Deep South',
#  'Colbert,Alabama': 'Appohzarka',
#  'Conecuh,Alabama': 'Deep South',
#  'Coosa,Alabama': 'Deep South',
#  'Covington,Alabama': 'Deep South',
#  'Crenshaw,Alabama': 'Deep South',
#  'Cullman,Alabama': 'Appohzarka',
#  'Dale,Alabama': 'Deep South',
#  'Dallas,Alabama': 'Deep South',
#  'DeKalb,Alabama': 'Appohzarka',
#  'Elmore,Alabama': 'Deep South',
#  'Escambia,Alabama': 'Deep South',
#  'Etowah,Alabama': 'Appohzarka',
#  'Fayette,Alabama': 'Appohzarka',
#  'Franklin,Alabama': 'Appohzarka',
#  'Geneva,Alabama': 'Deep South',
#  'Greene,Alabama': 'Deep South',
#  'Hale,Alabama': 'Deep South',
#  'Henry,Alabama': 'Deep South',
#  'Houston,Alabama': 'Deep South',
#  'Jackson,Alabama': 'Appohzarka',
#  'Jefferson,Alabama': 'Appohzarka',
#  'Lamar,Alabama': 'Appohzarka',
#  'Lauderdale,Alabama': 'Appohzarka',
#  'Lawrence,Alabama': 'Appohzarka',
#  'Lee,Alabama': 'Deep South',
#  'Limestone,Alabama': 'Appohzarka',
#  'Lowndes,Alabama': 'Deep South',
#  'Macon,Alabama': 'Deep South',
#  'Madison,Alabama': 'Appohzarka',
#  'Marengo,Alabama': 'Deep South',
#  'Marion,Alabama': 'Appohzarka',
#  'Marshall,Alabama': 'Appohzarka',
#  'Mobile,Alabama': 'Gulf Coast',
#  'Monroe,Alabama': 'Deep South',
#  'Montgomery,Alabama': 'Deep South',
#  'Morgan,Alabama': 'Appohzarka',
#  'Perry,Alabama': 'Deep South',
#  'Pickens,Alabama': 'Deep South',
#  'Pike,Alabama': 'Deep South',
#  'Randolph,Alabama': 'Deep South',
#  'Russell,Alabama': 'Deep South',
#  'St. Clair,Alabama': 'Appohzarka',
#  'Shelby,Alabama': 'Appohzarka',
#  'Sumter,Alabama': 'Deep South',
#  'Talladega,Alabama': 'Appohzarka',
#  'Tallapoosa,Alabama': 'Deep South',
#  'Tuscaloosa,Alabama': 'Deep South',
#  'Walker,Alabama': 'Appohzarka',
#  'Washington,Alabama': 'Deep South',
#  'Wilcox,Alabama': 'Deep South',
#  'Winston,Alabama': 'Appohzarka',
#  'Aleutians East,Alaska': 'Mountain West',
#  'Aleutians West,Alaska': 'Mountain West',
#  'Anchorage,Alaska': 'Mountain West',
#  'Bethel,Alaska': 'Mountain West',
#  'Bristol Bay,Alaska': 'Mountain West',
#  'Denali,Alaska': 'Mountain West',
#  'Dillingham,Alaska': 'Mountain West',
#  'Fairbanks North Star,Alaska': 'Mountain West',
#  'Haines,Alaska': 'Northwest',
#  'Skagway-Hoonah-Angoon,Alaska': 'Northwest',
#  'Juneau,Alaska': 'Northwest',
#  'Kenai Peninsula,Alaska': 'Mountain West',
#  'Ketchikan Gateway,Alaska': 'Northwest',
#  'Kodiak Island,Alaska': 'Mountain West',
#  'Kusilvak,Alaska': 'Mountain West',
#  'Lake and Peninsula,Alaska': 'Mountain West',
#  'Matanuska-Susitna,Alaska': 'Mountain West',
#  'Nome,Alaska': 'Mountain West',
#  'North Slope,Alaska': 'Mountain West',
#  'Northwest Arctic,Alaska': 'Mountain West',
#  'Petersburg Borough,Alaska': 'Northwest',
#  'Prince of Wales-Outer Ketchikan,Alaska': 'Northwest',
#  'Sitka,Alaska': 'Northwest',
#  'Skagway Municipality,Alaska': 'Northwest',
#  'Southeast Fairbanks,Alaska': 'Mountain West',
#  'Valdez-Cordova,Alaska': 'Mountain West',
#  'Wrangell City and Borough,Alaska': 'Northwest',
#  'Yakutat,Alaska': 'Northwest',
#  'Yukon-Koyukuk,Alaska': 'Mountain West',
#  'Apache,Arizona': 'Mountain West',
#  'Cochise,Arizona': 'Southwest',
#  'Coconino,Arizona': 'Mountain West',
#  'Gila,Arizona': 'Southwest',
#  'Graham,Arizona': 'Southwest',
#  'Greenlee,Arizona': 'Southwest',
#  'La Paz,Arizona': 'Southwest',
#  'Maricopa,Arizona': 'Southwest',
#  'Mohave,Arizona': 'Southwest',
#  'Navajo,Arizona': 'Mountain West',
#  'Pima,Arizona': 'Southwest',
#  'Pinal,Arizona': 'Southwest',
#  'Santa Cruz,Arizona': 'Southwest',
#  'Yavapai,Arizona': 'Southwest',
#  'Yuma,Arizona': 'Southwest',
#  'Arkansas,Arkansas': 'Deep South',
#  'Ashley,Arkansas': 'Deep South',
#  'Baxter,Arkansas': 'Appohzarka',
#  'Benton,Arkansas': 'Appohzarka',
#  'Boone,Arkansas': 'Appohzarka',
#  'Bradley,Arkansas': 'Deep South',
#  'Calhoun,Arkansas': 'Deep South',
#  'Carroll,Arkansas': 'Appohzarka',
#  'Chicot,Arkansas': 'Deep South',
#  'Clark,Arkansas': 'Appohzarka',
#  'Clay,Arkansas': 'Deep South',
#  'Cleburne,Arkansas': 'Appohzarka',
#  'Cleveland,Arkansas': 'Deep South',
#  'Columbia,Arkansas': 'Deep South',
#  'Conway,Arkansas': 'Appohzarka',
#  'Craighead,Arkansas': 'Deep South',
#  'Crawford,Arkansas': 'Appohzarka',
#  'Crittenden,Arkansas': 'Deep South',
#  'Cross,Arkansas': 'Deep South',
#  'Dallas,Arkansas': 'Deep South',
#  'Desha,Arkansas': 'Deep South',
#  'Drew,Arkansas': 'Deep South',
#  'Faulkner,Arkansas': 'Appohzarka',
#  'Franklin,Arkansas': 'Appohzarka',
#  'Fulton,Arkansas': 'Appohzarka',
#  'Garland,Arkansas': 'Appohzarka',
#  'Grant,Arkansas': 'Appohzarka',
#  'Greene,Arkansas': 'Deep South',
#  'Hempstead,Arkansas': 'Deep South',
#  'Hot Spring,Arkansas': 'Appohzarka',
#  'Howard,Arkansas': 'Deep South',
#  'Independence,Arkansas': 'Appohzarka',
#  'Izard,Arkansas': 'Appohzarka',
#  'Jackson,Arkansas': 'Deep South',
#  'Jefferson,Arkansas': 'Deep South',
#  'Johnson,Arkansas': 'Appohzarka',
#  'Lafayette,Arkansas': 'Deep South',
#  'Lawrence,Arkansas': 'Appohzarka',
#  'Lee,Arkansas': 'Deep South',
#  'Lincoln,Arkansas': 'Deep South',
#  'Little River,Arkansas': 'Deep South',
#  'Logan,Arkansas': 'Appohzarka',
#  'Lonoke,Arkansas': 'Appohzarka',
#  'Madison,Arkansas': 'Appohzarka',
#  'Marion,Arkansas': 'Appohzarka',
#  'Miller,Arkansas': 'Deep South',
#  'Mississippi,Arkansas': 'Deep South',
#  'Monroe,Arkansas': 'Deep South',
#  'Montgomery,Arkansas': 'Appohzarka',
#  'Nevada,Arkansas': 'Deep South',
#  'Newton,Arkansas': 'Appohzarka',
#  'Ouachita,Arkansas': 'Deep South',
#  'Perry,Arkansas': 'Appohzarka',
#  'Phillips,Arkansas': 'Deep South',
#  'Pike,Arkansas': 'Appohzarka',
#  'Poinsett,Arkansas': 'Deep South',
#  'Polk,Arkansas': 'Appohzarka',
#  'Pope,Arkansas': 'Appohzarka',
#  'Prairie,Arkansas': 'Deep South',
#  'Pulaski,Arkansas': 'Appohzarka',
#  'Randolph,Arkansas': 'Appohzarka',
#  'St. Francis,Arkansas': 'Deep South',
#  'Saline,Arkansas': 'Appohzarka',
#  'Scott,Arkansas': 'Appohzarka',
#  'Searcy,Arkansas': 'Appohzarka',
#  'Sebastian,Arkansas': 'Appohzarka',
#  'Sevier,Arkansas': 'Deep South',
#  'Sharp,Arkansas': 'Appohzarka',
#  'Stone,Arkansas': 'Appohzarka',
#  'Union,Arkansas': 'Deep South',
#  'Van Buren,Arkansas': 'Appohzarka',
#  'Washington,Arkansas': 'Appohzarka',
#  'White,Arkansas': 'Appohzarka',
#  'Woodruff,Arkansas': 'Deep South',
#  'Yell,Arkansas': 'Appohzarka',
#  'Alameda,California': 'Northwest',
#  'Alpine,California': 'Mountain West',
#  'Amador,California': 'Mountain West',
#  'Butte,California': 'Mountain West',
#  'Calaveras,California': 'Mountain West',
#  'Colusa,California': 'Mountain West',
#  'Contra Costa,California': 'Northwest',
#  'Del Norte,California': 'Northwest',
#  'El Dorado,California': 'Mountain West',
#  'Fresno,California': 'West Coast',
#  'Glenn,California': 'Mountain West',
#  'Humboldt,California': 'Northwest',
#  'Imperial,California': 'Southwest',
#  'Inyo,California': 'Southwest',
#  'Kern,California': 'West Coast',
#  'Kings,California': 'West Coast',
#  'Lake,California': 'Northwest',
#  'Lassen,California': 'Mountain West',
#  'Los Angeles,California': 'West Coast',
#  'Madera,California': 'West Coast',
#  'Marin,California': 'Northwest',
#  'Mariposa,California': 'Mountain West',
#  'Mendocino,California': 'Northwest',
#  'Merced,California': 'West Coast',
#  'Modoc,California': 'Mountain West',
#  'Mono,California': 'Mountain West',
#  'Monterey,California': 'West Coast',
#  'Napa,California': 'Northwest',
#  'Nevada,California': 'Mountain West',
#  'Orange,California': 'West Coast',
#  'Placer,California': 'Mountain West',
#  'Plumas,California': 'Mountain West',
#  'Riverside,California': 'West Coast',
#  'Sacramento,California': 'Mountain West',
#  'San Benito,California': 'West Coast',
#  'San Bernardino,California': 'West Coast',
#  'San Diego,California': 'West Coast',
#  'San Francisco,California': 'Northwest',
#  'San Joaquin,California': 'West Coast',
#  'San Luis Obispo,California': 'West Coast',
#  'San Mateo,California': 'Northwest',
#  'Santa Barbara,California': 'West Coast',
#  'Santa Clara,California': 'Northwest',
#  'Santa Cruz,California': 'Northwest',
#  'Shasta,California': 'Mountain West',
#  'Sierra,California': 'Mountain West',
#  'Siskiyou,California': 'Mountain West',
#  'Solano,California': 'Northwest',
#  'Sonoma,California': 'Northwest',
#  'Stanislaus,California': 'West Coast',
#  'Sutter,California': 'Mountain West',
#  'Tehama,California': 'Mountain West',
#  'Trinity,California': 'Northwest',
#  'Tulare,California': 'West Coast',
#  'Tuolumne,California': 'Mountain West',
#  'Ventura,California': 'West Coast',
#  'Yolo,California': 'Mountain West',
#  'Yuba,California': 'Mountain West',
#  'Adams,Colorado': 'Mountain West',
#  'Alamosa,Colorado': 'Southwest',
#  'Arapahoe,Colorado': 'Mountain West',
#  'Archuleta,Colorado': 'Mountain West',
#  'Baca,Colorado': 'Great Plains',
#  'Bent,Colorado': 'Great Plains',
#  'Boulder,Colorado': 'Mountain West',
#  'Broomfield,Colorado': 'Mountain West',
#  'Chaffee,Colorado': 'Mountain West',
#  'Cheyenne,Colorado': 'Great Plains',
#  'Clear Creek,Colorado': 'Mountain West',
#  'Conejos,Colorado': 'Southwest',
#  'Costilla,Colorado': 'Southwest',
#  'Crowley,Colorado': 'Great Plains',
#  'Custer,Colorado': 'Mountain West',
#  'Delta,Colorado': 'Mountain West',
#  'Denver,Colorado': 'Mountain West',
#  'Dolores,Colorado': 'Mountain West',
#  'Douglas,Colorado': 'Mountain West',
#  'Eagle,Colorado': 'Mountain West',
#  'Elbert,Colorado': 'Mountain West',
#  'El Paso,Colorado': 'Mountain West',
#  'Fremont,Colorado': 'Mountain West',
#  'Garfield,Colorado': 'Mountain West',
#  'Gilpin,Colorado': 'Mountain West',
#  'Grand,Colorado': 'Mountain West',
#  'Gunnison,Colorado': 'Mountain West',
#  'Hinsdale,Colorado': 'Mountain West',
#  'Huerfano,Colorado': 'Great Plains',
#  'Jackson,Colorado': 'Mountain West',
#  'Jefferson,Colorado': 'Mountain West',
#  'Kiowa,Colorado': 'Great Plains',
#  'Kit Carson,Colorado': 'Great Plains',
#  'Lake,Colorado': 'Mountain West',
#  'La Plata,Colorado': 'Mountain West',
#  'Larimer,Colorado': 'Mountain West',
#  'Las Animas,Colorado': 'Great Plains',
#  'Lincoln,Colorado': 'Great Plains',
#  'Logan,Colorado': 'Great Plains',
#  'Mesa,Colorado': 'Mountain West',
#  'Mineral,Colorado': 'Mountain West',
#  'Moffat,Colorado': 'Mountain West',
#  'Montezuma,Colorado': 'Mountain West',
#  'Montrose,Colorado': 'Mountain West',
#  'Morgan,Colorado': 'Great Plains',
#  'Otero,Colorado': 'Great Plains',
#  'Ouray,Colorado': 'Mountain West',
#  'Park,Colorado': 'Mountain West',
#  'Phillips,Colorado': 'Great Plains',
#  'Pitkin,Colorado': 'Mountain West',
#  'Prowers,Colorado': 'Great Plains',
#  'Pueblo,Colorado': 'Great Plains',
#  'Rio Blanco,Colorado': 'Mountain West',
#  'Rio Grande,Colorado': 'Southwest',
#  'Routt,Colorado': 'Mountain West',
#  'Saguache,Colorado': 'Southwest',
#  'San Juan,Colorado': 'Mountain West',
#  'San Miguel,Colorado': 'Mountain West',
#  'Sedgwick,Colorado': 'Great Plains',
#  'Summit,Colorado': 'Mountain West',
#  'Teller,Colorado': 'Mountain West',
#  'Washington,Colorado': 'Great Plains',
#  'Weld,Colorado': 'Great Plains',
#  'Yuma,Colorado': 'Great Plains',
#  'Fairfield,Connecticut': 'Mid-Atlantic North',
#  'Hartford,Connecticut': 'Northeast',
#  'Litchfield,Connecticut': 'Northeast',
#  'Middlesex,Connecticut': 'Northeast',
#  'New Haven,Connecticut': 'Mid-Atlantic North',
#  'New London,Connecticut': 'Northeast',
#  'Tolland,Connecticut': 'Northeast',
#  'Windham,Connecticut': 'Northeast',
#  'Kent,Delaware': 'Mid-Atlantic South',
#  'New Castle,Delaware': 'Mid-Atlantic North',
#  'Sussex,Delaware': 'Mid-Atlantic South',
#  'District of Columbia,District of Columbia': 'Mid-Atlantic South',
#  'Alachua,Florida': 'Deep South',
#  'Baker,Florida': 'Deep South',
#  'Bay,Florida': 'Deep South',
#  'Bradford,Florida': 'Deep South',
#  'Brevard,Florida': 'Southern Florida',
#  'Broward,Florida': 'Southern Florida',
#  'Calhoun,Florida': 'Deep South',
#  'Charlotte,Florida': 'Southern Florida',
#  'Citrus,Florida': 'Southern Florida',
#  'Clay,Florida': 'Deep South',
#  'Collier,Florida': 'Southern Florida',
#  'Columbia,Florida': 'Deep South',
#  'DeSoto,Florida': 'Southern Florida',
#  'Dixie,Florida': 'Deep South',
#  'Duval,Florida': 'Deep South',
#  'Escambia,Florida': 'Deep South',
#  'Flagler,Florida': 'Deep South',
#  'Franklin,Florida': 'Deep South',
#  'Gadsden,Florida': 'Deep South',
#  'Gilchrist,Florida': 'Deep South',
#  'Glades,Florida': 'Southern Florida',
#  'Gulf,Florida': 'Deep South',
#  'Hamilton,Florida': 'Deep South',
#  'Hardee,Florida': 'Southern Florida',
#  'Hendry,Florida': 'Southern Florida',
#  'Hernando,Florida': 'Southern Florida',
#  'Highlands,Florida': 'Southern Florida',
#  'Hillsborough,Florida': 'Southern Florida',
#  'Holmes,Florida': 'Deep South',
#  'Indian River,Florida': 'Southern Florida',
#  'Jackson,Florida': 'Deep South',
#  'Jefferson,Florida': 'Deep South',
#  'Lafayette,Florida': 'Deep South',
#  'Lake,Florida': 'Southern Florida',
#  'Lee,Florida': 'Southern Florida',
#  'Leon,Florida': 'Deep South',
#  'Levy,Florida': 'Deep South',
#  'Liberty,Florida': 'Deep South',
#  'Madison,Florida': 'Deep South',
#  'Manatee,Florida': 'Southern Florida',
#  'Marion,Florida': 'Deep South',
#  'Martin,Florida': 'Southern Florida',
#  'Miami-Dade,Florida': 'Southern Florida',
#  'Monroe,Florida': 'Southern Florida',
#  'Nassau,Florida': 'Deep South',
#  'Okaloosa,Florida': 'Deep South',
#  'Okeechobee,Florida': 'Southern Florida',
#  'Orange,Florida': 'Southern Florida',
#  'Osceola,Florida': 'Southern Florida',
#  'Palm Beach,Florida': 'Southern Florida',
#  'Pasco,Florida': 'Southern Florida',
#  'Pinellas,Florida': 'Southern Florida',
#  'Polk,Florida': 'Southern Florida',
#  'Putnam,Florida': 'Deep South',
#  'St. Johns,Florida': 'Deep South',
#  'St. Lucie,Florida': 'Southern Florida',
#  'Santa Rosa,Florida': 'Deep South',
#  'Sarasota,Florida': 'Southern Florida',
#  'Seminole,Florida': 'Southern Florida',
#  'Sumter,Florida': 'Southern Florida',
#  'Suwannee,Florida': 'Deep South',
#  'Taylor,Florida': 'Deep South',
#  'Union,Florida': 'Deep South',
#  'Volusia,Florida': 'Deep South',
#  'Wakulla,Florida': 'Deep South',
#  'Walton,Florida': 'Deep South',
#  'Washington,Florida': 'Deep South',
#  'Appling,Georgia': 'Deep South',
#  'Atkinson,Georgia': 'Deep South',
#  'Bacon,Georgia': 'Deep South',
#  'Baker,Georgia': 'Deep South',
#  'Baldwin,Georgia': 'Deep South',
#  'Banks,Georgia': 'Appohzarka',
#  'Barrow,Georgia': 'Deep South',
#  'Bartow,Georgia': 'Appohzarka',
#  'Ben Hill,Georgia': 'Deep South',
#  'Berrien,Georgia': 'Deep South',
#  'Bibb,Georgia': 'Deep South',
#  'Bleckley,Georgia': 'Deep South',
#  'Brantley,Georgia': 'Deep South',
#  'Brooks,Georgia': 'Deep South',
#  'Bryan,Georgia': 'Deep South',
#  'Bulloch,Georgia': 'Deep South',
#  'Burke,Georgia': 'Deep South',
#  'Butts,Georgia': 'Deep South',
#  'Calhoun,Georgia': 'Deep South',
#  'Camden,Georgia': 'Deep South',
#  'Candler,Georgia': 'Deep South',
#  'Carroll,Georgia': 'Deep South',
#  'Catoosa,Georgia': 'Appohzarka',
#  'Charlton,Georgia': 'Deep South',
#  'Chatham,Georgia': 'Deep South',
#  'Chattahoochee,Georgia': 'Deep South',
#  'Chattooga,Georgia': 'Appohzarka',
#  'Cherokee,Georgia': 'Deep South',
#  'Clarke,Georgia': 'Deep South',
#  'Clay,Georgia': 'Deep South',
#  'Clayton,Georgia': 'Deep South',
#  'Clinch,Georgia': 'Deep South',
#  'Cobb,Georgia': 'Deep South',
#  'Coffee,Georgia': 'Deep South',
#  'Colquitt,Georgia': 'Deep South',
#  'Columbia,Georgia': 'Deep South',
#  'Cook,Georgia': 'Deep South',
#  'Coweta,Georgia': 'Deep South',
#  'Crawford,Georgia': 'Deep South',
#  'Crisp,Georgia': 'Deep South',
#  'Dade,Georgia': 'Appohzarka',
#  'Dawson,Georgia': 'Appohzarka',
#  'Decatur,Georgia': 'Deep South',
#  'DeKalb,Georgia': 'Deep South',
#  'Dodge,Georgia': 'Deep South',
#  'Dooly,Georgia': 'Deep South',
#  'Dougherty,Georgia': 'Deep South',
#  'Douglas,Georgia': 'Deep South',
#  'Early,Georgia': 'Deep South',
#  'Echols,Georgia': 'Deep South',
#  'Effingham,Georgia': 'Deep South',
#  'Elbert,Georgia': 'Deep South',
#  'Emanuel,Georgia': 'Deep South',
#  'Evans,Georgia': 'Deep South',
#  'Fannin,Georgia': 'Appohzarka',
#  'Fayette,Georgia': 'Deep South',
#  'Floyd,Georgia': 'Appohzarka',
#  'Forsyth,Georgia': 'Deep South',
#  'Franklin,Georgia': 'Appohzarka',
#  'Fulton,Georgia': 'Deep South',
#  'Gilmer,Georgia': 'Appohzarka',
#  'Glascock,Georgia': 'Deep South',
#  'Glynn,Georgia': 'Deep South',
#  'Gordon,Georgia': 'Appohzarka',
#  'Grady,Georgia': 'Deep South',
#  'Greene,Georgia': 'Deep South',
#  'Gwinnett,Georgia': 'Deep South',
#  'Habersham,Georgia': 'Appohzarka',
#  'Hall,Georgia': 'Appohzarka',
#  'Hancock,Georgia': 'Deep South',
#  'Haralson,Georgia': 'Appohzarka',
#  'Harris,Georgia': 'Deep South',
#  'Hart,Georgia': 'Appohzarka',
#  'Heard,Georgia': 'Deep South',
#  'Henry,Georgia': 'Deep South',
#  'Houston,Georgia': 'Deep South',
#  'Irwin,Georgia': 'Deep South',
#  'Jackson,Georgia': 'Deep South',
#  'Jasper,Georgia': 'Deep South',
#  'Jeff Davis,Georgia': 'Deep South',
#  'Jefferson,Georgia': 'Deep South',
#  'Jenkins,Georgia': 'Deep South',
#  'Johnson,Georgia': 'Deep South',
#  'Jones,Georgia': 'Deep South',
#  'Lamar,Georgia': 'Deep South',
#  'Lanier,Georgia': 'Deep South',
#  'Laurens,Georgia': 'Deep South',
#  'Lee,Georgia': 'Deep South',
#  'Liberty,Georgia': 'Deep South',
#  'Lincoln,Georgia': 'Deep South',
#  'Long,Georgia': 'Deep South',
#  'Lowndes,Georgia': 'Deep South',
#  'Lumpkin,Georgia': 'Appohzarka',
#  'McDuffie,Georgia': 'Deep South',
#  'McIntosh,Georgia': 'Deep South',
#  'Macon,Georgia': 'Deep South',
#  'Madison,Georgia': 'Deep South',
#  'Marion,Georgia': 'Deep South',
#  'Meriwether,Georgia': 'Deep South',
#  'Miller,Georgia': 'Deep South',
#  'Mitchell,Georgia': 'Deep South',
#  'Monroe,Georgia': 'Deep South',
#  'Montgomery,Georgia': 'Deep South',
#  'Morgan,Georgia': 'Deep South',
#  'Murray,Georgia': 'Appohzarka',
#  'Muscogee,Georgia': 'Deep South',
#  'Newton,Georgia': 'Deep South',
#  'Oconee,Georgia': 'Deep South',
#  'Oglethorpe,Georgia': 'Deep South',
#  'Paulding,Georgia': 'Deep South',
#  'Peach,Georgia': 'Deep South',
#  'Pickens,Georgia': 'Appohzarka',
#  'Pierce,Georgia': 'Deep South',
#  'Pike,Georgia': 'Deep South',
#  'Polk,Georgia': 'Appohzarka',
#  'Pulaski,Georgia': 'Deep South',
#  'Putnam,Georgia': 'Deep South',
#  'Quitman,Georgia': 'Deep South',
#  'Rabun,Georgia': 'Appohzarka',
#  'Randolph,Georgia': 'Deep South',
#  'Richmond,Georgia': 'Deep South',
#  'Rockdale,Georgia': 'Deep South',
#  'Schley,Georgia': 'Deep South',
#  'Screven,Georgia': 'Deep South',
#  'Seminole,Georgia': 'Deep South',
#  'Spalding,Georgia': 'Deep South',
#  'Stephens,Georgia': 'Appohzarka',
#  'Stewart,Georgia': 'Deep South',
#  'Sumter,Georgia': 'Deep South',
#  'Talbot,Georgia': 'Deep South',
#  'Taliaferro,Georgia': 'Deep South',
#  'Tattnall,Georgia': 'Deep South',
#  'Taylor,Georgia': 'Deep South',
#  'Telfair,Georgia': 'Deep South',
#  'Terrell,Georgia': 'Deep South',
#  'Thomas,Georgia': 'Deep South',
#  'Tift,Georgia': 'Deep South',
#  'Toombs,Georgia': 'Deep South',
#  'Towns,Georgia': 'Appohzarka',
#  'Treutlen,Georgia': 'Deep South',
#  'Troup,Georgia': 'Deep South',
#  'Turner,Georgia': 'Deep South',
#  'Twiggs,Georgia': 'Deep South',
#  'Union,Georgia': 'Appohzarka',
#  'Upson,Georgia': 'Deep South',
#  'Walker,Georgia': 'Appohzarka',
#  'Walton,Georgia': 'Deep South',
#  'Ware,Georgia': 'Deep South',
#  'Warren,Georgia': 'Deep South',
#  'Washington,Georgia': 'Deep South',
#  'Wayne,Georgia': 'Deep South',
#  'Webster,Georgia': 'Deep South',
#  'Wheeler,Georgia': 'Deep South',
#  'White,Georgia': 'Appohzarka',
#  'Whitfield,Georgia': 'Appohzarka',
#  'Wilcox,Georgia': 'Deep South',
#  'Wilkes,Georgia': 'Deep South',
#  'Wilkinson,Georgia': 'Deep South',
#  'Worth,Georgia': 'Deep South',
#  'Hawaii,Hawaii': 'West Coast',
#  'Honolulu,Hawaii': 'West Coast',
#  'Kalawao,Hawaii': 'West Coast',
#  'Kauai,Hawaii': 'West Coast',
#  'Maui,Hawaii': 'West Coast',
#  'Ada,Idaho': 'Mountain West',
#  'Adams,Idaho': 'Mountain West',
#  'Bannock,Idaho': 'Mountain West',
#  'Bear Lake,Idaho': 'Mountain West',
#  'Benewah,Idaho': 'Mountain West',
#  'Bingham,Idaho': 'Mountain West',
#  'Blaine,Idaho': 'Mountain West',
#  'Boise,Idaho': 'Mountain West',
#  'Bonner,Idaho': 'Mountain West',
#  'Bonneville,Idaho': 'Mountain West',
#  'Boundary,Idaho': 'Mountain West',
#  'Butte,Idaho': 'Mountain West',
#  'Camas,Idaho': 'Mountain West',
#  'Canyon,Idaho': 'Mountain West',
#  'Caribou,Idaho': 'Mountain West',
#  'Cassia,Idaho': 'Mountain West',
#  'Clark,Idaho': 'Mountain West',
#  'Clearwater,Idaho': 'Mountain West',
#  'Custer,Idaho': 'Mountain West',
#  'Elmore,Idaho': 'Mountain West',
#  'Franklin,Idaho': 'Mountain West',
#  'Fremont,Idaho': 'Mountain West',
#  'Gem,Idaho': 'Mountain West',
#  'Gooding,Idaho': 'Mountain West',
#  'Idaho,Idaho': 'Mountain West',
#  'Jefferson,Idaho': 'Mountain West',
#  'Jerome,Idaho': 'Mountain West',
#  'Kootenai,Idaho': 'Mountain West',
#  'Latah,Idaho': 'Mountain West',
#  'Lemhi,Idaho': 'Mountain West',
#  'Lewis,Idaho': 'Mountain West',
#  'Lincoln,Idaho': 'Mountain West',
#  'Madison,Idaho': 'Mountain West',
#  'Minidoka,Idaho': 'Mountain West',
#  'Nez Perce,Idaho': 'Mountain West',
#  'Oneida,Idaho': 'Mountain West',
#  'Owyhee,Idaho': 'Mountain West',
#  'Payette,Idaho': 'Mountain West',
#  'Power,Idaho': 'Mountain West',
#  'Shoshone,Idaho': 'Mountain West',
#  'Teton,Idaho': 'Mountain West',
#  'Twin Falls,Idaho': 'Mountain West',
#  'Valley,Idaho': 'Mountain West',
#  'Washington,Idaho': 'Mountain West',
#  'Adams,Illinois': 'Heartland',
#  'Alexander,Illinois': 'Appohzarka',
#  'Bond,Illinois': 'Heartland',
#  'Boone,Illinois': 'Great Lakes',
#  'Brown,Illinois': 'Heartland',
#  'Bureau,Illinois': 'Great Lakes',
#  'Calhoun,Illinois': 'Heartland',
#  'Carroll,Illinois': 'Heartland',
#  'Cass,Illinois': 'Heartland',
#  'Champaign,Illinois': 'Heartland',
#  'Christian,Illinois': 'Heartland',
#  'Clark,Illinois': 'Appohzarka',
#  'Clay,Illinois': 'Appohzarka',
#  'Clinton,Illinois': 'Heartland',
#  'Coles,Illinois': 'Heartland',
#  'Cook,Illinois': 'Great Lakes',
#  'Crawford,Illinois': 'Appohzarka',
#  'Cumberland,Illinois': 'Appohzarka',
#  'DeKalb,Illinois': 'Great Lakes',
#  'De Witt,Illinois': 'Heartland',
#  'Douglas,Illinois': 'Heartland',
#  'DuPage,Illinois': 'Great Lakes',
#  'Edgar,Illinois': 'Appohzarka',
#  'Edwards,Illinois': 'Appohzarka',
#  'Effingham,Illinois': 'Appohzarka',
#  'Fayette,Illinois': 'Appohzarka',
#  'Ford,Illinois': 'Heartland',
#  'Franklin,Illinois': 'Appohzarka',
#  'Fulton,Illinois': 'Heartland',
#  'Gallatin,Illinois': 'Appohzarka',
#  'Greene,Illinois': 'Heartland',
#  'Grundy,Illinois': 'Great Lakes',
#  'Hamilton,Illinois': 'Appohzarka',
#  'Hancock,Illinois': 'Heartland',
#  'Hardin,Illinois': 'Appohzarka',
#  'Henderson,Illinois': 'Heartland',
#  'Henry,Illinois': 'Heartland',
#  'Iroquois,Illinois': 'Heartland',
#  'Jackson,Illinois': 'Appohzarka',
#  'Jasper,Illinois': 'Appohzarka',
#  'Jefferson,Illinois': 'Appohzarka',
#  'Jersey,Illinois': 'Heartland',
#  'Jo Daviess,Illinois': 'Heartland',
#  'Johnson,Illinois': 'Appohzarka',
#  'Kane,Illinois': 'Great Lakes',
#  'Kankakee,Illinois': 'Great Lakes',
#  'Kendall,Illinois': 'Great Lakes',
#  'Knox,Illinois': 'Heartland',
#  'Lake,Illinois': 'Great Lakes',
#  'LaSalle,Illinois': 'Great Lakes',
#  'Lawrence,Illinois': 'Appohzarka',
#  'Lee,Illinois': 'Heartland',
#  'Livingston,Illinois': 'Heartland',
#  'Logan,Illinois': 'Heartland',
#  'McDonough,Illinois': 'Heartland',
#  'McHenry,Illinois': 'Great Lakes',
#  'McLean,Illinois': 'Heartland',
#  'Macon,Illinois': 'Heartland',
#  'Macoupin,Illinois': 'Heartland',
#  'Madison,Illinois': 'Heartland',
#  'Marion,Illinois': 'Appohzarka',
#  'Marshall,Illinois': 'Great Lakes',
#  'Mason,Illinois': 'Heartland',
#  'Massac,Illinois': 'Appohzarka',
#  'Menard,Illinois': 'Heartland',
#  'Mercer,Illinois': 'Heartland',
#  'Monroe,Illinois': 'Heartland',
#  'Montgomery,Illinois': 'Heartland',
#  'Morgan,Illinois': 'Heartland',
#  'Moultrie,Illinois': 'Heartland',
#  'Ogle,Illinois': 'Heartland',
#  'Peoria,Illinois': 'Great Lakes',
#  'Perry,Illinois': 'Appohzarka',
#  'Piatt,Illinois': 'Heartland',
#  'Pike,Illinois': 'Heartland',
#  'Pope,Illinois': 'Appohzarka',
#  'Pulaski,Illinois': 'Appohzarka',
#  'Putnam,Illinois': 'Great Lakes',
#  'Randolph,Illinois': 'Appohzarka',
#  'Richland,Illinois': 'Appohzarka',
#  'Rock Island,Illinois': 'Heartland',
#  'St. Clair,Illinois': 'Heartland',
#  'Saline,Illinois': 'Appohzarka',
#  'Sangamon,Illinois': 'Heartland',
#  'Schuyler,Illinois': 'Heartland',
#  'Scott,Illinois': 'Heartland',
#  'Shelby,Illinois': 'Heartland',
#  'Stark,Illinois': 'Great Lakes',
#  'Stephenson,Illinois': 'Heartland',
#  'Tazewell,Illinois': 'Great Lakes',
#  'Union,Illinois': 'Appohzarka',
#  'Vermilion,Illinois': 'Heartland',
#  'Wabash,Illinois': 'Appohzarka',
#  'Warren,Illinois': 'Heartland',
#  'Washington,Illinois': 'Appohzarka',
#  'Wayne,Illinois': 'Appohzarka',
#  'White,Illinois': 'Appohzarka',
#  'Whiteside,Illinois': 'Heartland',
#  'Will,Illinois': 'Great Lakes',
#  'Williamson,Illinois': 'Appohzarka',
#  'Winnebago,Illinois': 'Great Lakes',
#  'Woodford,Illinois': 'Great Lakes',
#  'Adams,Indiana': 'Heartland',
#  'Allen,Indiana': 'Great Lakes',
#  'Bartholomew,Indiana': 'Appohzarka',
#  'Benton,Indiana': 'Heartland',
#  'Blackford,Indiana': 'Heartland',
#  'Boone,Indiana': 'Heartland',
#  'Brown,Indiana': 'Appohzarka',
#  'Carroll,Indiana': 'Heartland',
#  'Cass,Indiana': 'Heartland',
#  'Clark,Indiana': 'Appohzarka',
#  'Clay,Indiana': 'Appohzarka',
#  'Clinton,Indiana': 'Heartland',
#  'Crawford,Indiana': 'Appohzarka',
#  'Daviess,Indiana': 'Appohzarka',
#  'Dearborn,Indiana': 'Appohzarka',
#  'Decatur,Indiana': 'Appohzarka',
#  'DeKalb,Indiana': 'Heartland',
#  'Delaware,Indiana': 'Heartland',
#  'Dubois,Indiana': 'Appohzarka',
#  'Elkhart,Indiana': 'Great Lakes',
#  'Fayette,Indiana': 'Appohzarka',
#  'Floyd,Indiana': 'Appohzarka',
#  'Fountain,Indiana': 'Heartland',
#  'Franklin,Indiana': 'Appohzarka',
#  'Fulton,Indiana': 'Heartland',
#  'Gibson,Indiana': 'Appohzarka',
#  'Grant,Indiana': 'Heartland',
#  'Greene,Indiana': 'Appohzarka',
#  'Hamilton,Indiana': 'Heartland',
#  'Hancock,Indiana': 'Heartland',
#  'Harrison,Indiana': 'Appohzarka',
#  'Hendricks,Indiana': 'Heartland',
#  'Henry,Indiana': 'Heartland',
#  'Howard,Indiana': 'Heartland',
#  'Huntington,Indiana': 'Heartland',
#  'Jackson,Indiana': 'Appohzarka',
#  'Jasper,Indiana': 'Great Lakes',
#  'Jay,Indiana': 'Heartland',
#  'Jefferson,Indiana': 'Appohzarka',
#  'Jennings,Indiana': 'Appohzarka',
#  'Johnson,Indiana': 'Heartland',
#  'Knox,Indiana': 'Appohzarka',
#  'Kosciusko,Indiana': 'Great Lakes',
#  'LaGrange,Indiana': 'Heartland',
#  'Lake,Indiana': 'Great Lakes',
#  'LaPorte,Indiana': 'Great Lakes',
#  'Lawrence,Indiana': 'Appohzarka',
#  'Madison,Indiana': 'Heartland',
#  'Marion,Indiana': 'Heartland',
#  'Marshall,Indiana': 'Great Lakes',
#  'Martin,Indiana': 'Appohzarka',
#  'Miami,Indiana': 'Heartland',
#  'Monroe,Indiana': 'Appohzarka',
#  'Montgomery,Indiana': 'Heartland',
#  'Morgan,Indiana': 'Heartland',
#  'Newton,Indiana': 'Great Lakes',
#  'Noble,Indiana': 'Heartland',
#  'Ohio,Indiana': 'Appohzarka',
#  'Orange,Indiana': 'Appohzarka',
#  'Owen,Indiana': 'Appohzarka',
#  'Parke,Indiana': 'Appohzarka',
#  'Perry,Indiana': 'Appohzarka',
#  'Pike,Indiana': 'Appohzarka',
#  'Porter,Indiana': 'Great Lakes',
#  'Posey,Indiana': 'Appohzarka',
#  'Pulaski,Indiana': 'Heartland',
#  'Putnam,Indiana': 'Heartland',
#  'Randolph,Indiana': 'Heartland',
#  'Ripley,Indiana': 'Appohzarka',
#  'Rush,Indiana': 'Heartland',
#  'St. Joseph,Indiana': 'Great Lakes',
#  'Scott,Indiana': 'Appohzarka',
#  'Shelby,Indiana': 'Heartland',
#  'Spencer,Indiana': 'Appohzarka',
#  'Starke,Indiana': 'Great Lakes',
#  'Steuben,Indiana': 'Heartland',
#  'Sullivan,Indiana': 'Appohzarka',
#  'Switzerland,Indiana': 'Appohzarka',
#  'Tippecanoe,Indiana': 'Heartland',
#  'Tipton,Indiana': 'Heartland',
#  'Union,Indiana': 'Appohzarka',
#  'Vanderburgh,Indiana': 'Appohzarka',
#  'Vermillion,Indiana': 'Appohzarka',
#  'Vigo,Indiana': 'Appohzarka',
#  'Wabash,Indiana': 'Heartland',
#  'Warren,Indiana': 'Heartland',
#  'Warrick,Indiana': 'Appohzarka',
#  'Washington,Indiana': 'Appohzarka',
#  'Wayne,Indiana': 'Appohzarka',
#  'Wells,Indiana': 'Heartland',
#  'White,Indiana': 'Heartland',
#  'Whitley,Indiana': 'Great Lakes',
#  'Adair,Iowa': 'Heartland',
#  'Adams,Iowa': 'Heartland',
#  'Allamakee,Iowa': 'Heartland',
#  'Appanoose,Iowa': 'Heartland',
#  'Audubon,Iowa': 'Heartland',
#  'Benton,Iowa': 'Heartland',
#  'Black Hawk,Iowa': 'Heartland',
#  'Boone,Iowa': 'Heartland',
#  'Bremer,Iowa': 'Heartland',
#  'Buchanan,Iowa': 'Heartland',
#  'Buena Vista,Iowa': 'Heartland',
#  'Butler,Iowa': 'Heartland',
#  'Calhoun,Iowa': 'Heartland',
#  'Carroll,Iowa': 'Heartland',
#  'Cass,Iowa': 'Heartland',
#  'Cedar,Iowa': 'Heartland',
#  'Cerro Gordo,Iowa': 'Heartland',
#  'Cherokee,Iowa': 'Heartland',
#  'Chickasaw,Iowa': 'Heartland',
#  'Clarke,Iowa': 'Heartland',
#  'Clay,Iowa': 'Heartland',
#  'Clayton,Iowa': 'Heartland',
#  'Clinton,Iowa': 'Heartland',
#  'Crawford,Iowa': 'Heartland',
#  'Dallas,Iowa': 'Heartland',
#  'Davis,Iowa': 'Heartland',
#  'Decatur,Iowa': 'Heartland',
#  'Delaware,Iowa': 'Heartland',
#  'Des Moines,Iowa': 'Heartland',
#  'Dickinson,Iowa': 'Heartland',
#  'Dubuque,Iowa': 'Heartland',
#  'Emmet,Iowa': 'Heartland',
#  'Fayette,Iowa': 'Heartland',
#  'Floyd,Iowa': 'Heartland',
#  'Franklin,Iowa': 'Heartland',
#  'Fremont,Iowa': 'Heartland',
#  'Greene,Iowa': 'Heartland',
#  'Grundy,Iowa': 'Heartland',
#  'Guthrie,Iowa': 'Heartland',
#  'Hamilton,Iowa': 'Heartland',
#  'Hancock,Iowa': 'Heartland',
#  'Hardin,Iowa': 'Heartland',
#  'Harrison,Iowa': 'Heartland',
#  'Henry,Iowa': 'Heartland',
#  'Howard,Iowa': 'Heartland',
#  'Humboldt,Iowa': 'Heartland',
#  'Ida,Iowa': 'Heartland',
#  'Iowa,Iowa': 'Heartland',
#  'Jackson,Iowa': 'Heartland',
#  'Jasper,Iowa': 'Heartland',
#  'Jefferson,Iowa': 'Heartland',
#  'Johnson,Iowa': 'Heartland',
#  'Jones,Iowa': 'Heartland',
#  'Keokuk,Iowa': 'Heartland',
#  'Kossuth,Iowa': 'Heartland',
#  'Lee,Iowa': 'Heartland',
#  'Linn,Iowa': 'Heartland',
#  'Louisa,Iowa': 'Heartland',
#  'Lucas,Iowa': 'Heartland',
#  'Lyon,Iowa': 'Heartland',
#  'Madison,Iowa': 'Heartland',
#  'Mahaska,Iowa': 'Heartland',
#  'Marion,Iowa': 'Heartland',
#  'Marshall,Iowa': 'Heartland',
#  'Mills,Iowa': 'Heartland',
#  'Mitchell,Iowa': 'Heartland',
#  'Monona,Iowa': 'Heartland',
#  'Monroe,Iowa': 'Heartland',
#  'Montgomery,Iowa': 'Heartland',
#  'Muscatine,Iowa': 'Heartland',
#  "O'Brien,Iowa": 'Heartland',
#  'Osceola,Iowa': 'Heartland',
#  'Page,Iowa': 'Heartland',
#  'Palo Alto,Iowa': 'Heartland',
#  'Plymouth,Iowa': 'Heartland',
#  'Pocahontas,Iowa': 'Heartland',
#  'Polk,Iowa': 'Heartland',
#  'Pottawattamie,Iowa': 'Heartland',
#  'Poweshiek,Iowa': 'Heartland',
#  'Ringgold,Iowa': 'Heartland',
#  'Sac,Iowa': 'Heartland',
#  'Scott,Iowa': 'Heartland',
#  'Shelby,Iowa': 'Heartland',
#  'Sioux,Iowa': 'Heartland',
#  'Story,Iowa': 'Heartland',
#  'Tama,Iowa': 'Heartland',
#  'Taylor,Iowa': 'Heartland',
#  'Union,Iowa': 'Heartland',
#  'Van Buren,Iowa': 'Heartland',
#  'Wapello,Iowa': 'Heartland',
#  'Warren,Iowa': 'Heartland',
#  'Washington,Iowa': 'Heartland',
#  'Wayne,Iowa': 'Heartland',
#  'Webster,Iowa': 'Heartland',
#  'Winnebago,Iowa': 'Heartland',
#  'Winneshiek,Iowa': 'Heartland',
#  'Woodbury,Iowa': 'Heartland',
#  'Worth,Iowa': 'Heartland',
#  'Wright,Iowa': 'Heartland',
#  'Allen,Kansas': 'Appohzarka',
#  'Anderson,Kansas': 'Appohzarka',
#  'Atchison,Kansas': 'Heartland',
#  'Barber,Kansas': 'Great Plains',
#  'Barton,Kansas': 'Great Plains',
#  'Bourbon,Kansas': 'Appohzarka',
#  'Brown,Kansas': 'Heartland',
#  'Butler,Kansas': 'Great Plains',
#  'Chase,Kansas': 'Great Plains',
#  'Chautauqua,Kansas': 'Appohzarka',
#  'Cherokee,Kansas': 'Appohzarka',
#  'Cheyenne,Kansas': 'Great Plains',
#  'Clark,Kansas': 'Great Plains',
#  'Clay,Kansas': 'Great Plains',
#  'Cloud,Kansas': 'Great Plains',
#  'Coffey,Kansas': 'Appohzarka',
#  'Comanche,Kansas': 'Great Plains',
#  'Cowley,Kansas': 'Great Plains',
#  'Crawford,Kansas': 'Appohzarka',
#  'Decatur,Kansas': 'Great Plains',
#  'Dickinson,Kansas': 'Great Plains',
#  'Doniphan,Kansas': 'Heartland',
#  'Douglas,Kansas': 'Heartland',
#  'Edwards,Kansas': 'Great Plains',
#  'Elk,Kansas': 'Appohzarka',
#  'Ellis,Kansas': 'Great Plains',
#  'Ellsworth,Kansas': 'Great Plains',
#  'Finney,Kansas': 'Great Plains',
#  'Ford,Kansas': 'Great Plains',
#  'Franklin,Kansas': 'Heartland',
#  'Geary,Kansas': 'Great Plains',
#  'Gove,Kansas': 'Great Plains',
#  'Graham,Kansas': 'Great Plains',
#  'Grant,Kansas': 'Great Plains',
#  'Gray,Kansas': 'Great Plains',
#  'Greeley,Kansas': 'Great Plains',
#  'Greenwood,Kansas': 'Great Plains',
#  'Hamilton,Kansas': 'Great Plains',
#  'Harper,Kansas': 'Great Plains',
#  'Harvey,Kansas': 'Great Plains',
#  'Haskell,Kansas': 'Great Plains',
#  'Hodgeman,Kansas': 'Great Plains',
#  'Jackson,Kansas': 'Heartland',
#  'Jefferson,Kansas': 'Heartland',
#  'Jewell,Kansas': 'Great Plains',
#  'Johnson,Kansas': 'Heartland',
#  'Kearny,Kansas': 'Great Plains',
#  'Kingman,Kansas': 'Great Plains',
#  'Kiowa,Kansas': 'Great Plains',
#  'Labette,Kansas': 'Appohzarka',
#  'Lane,Kansas': 'Great Plains',
#  'Leavenworth,Kansas': 'Heartland',
#  'Lincoln,Kansas': 'Great Plains',
#  'Linn,Kansas': 'Heartland',
#  'Logan,Kansas': 'Great Plains',
#  'Lyon,Kansas': 'Great Plains',
#  'McPherson,Kansas': 'Great Plains',
#  'Marion,Kansas': 'Great Plains',
#  'Marshall,Kansas': 'Heartland',
#  'Meade,Kansas': 'Great Plains',
#  'Miami,Kansas': 'Heartland',
#  'Mitchell,Kansas': 'Great Plains',
#  'Montgomery,Kansas': 'Appohzarka',
#  'Morris,Kansas': 'Great Plains',
#  'Morton,Kansas': 'Great Plains',
#  'Nemaha,Kansas': 'Heartland',
#  'Neosho,Kansas': 'Appohzarka',
#  'Ness,Kansas': 'Great Plains',
#  'Norton,Kansas': 'Great Plains',
#  'Osage,Kansas': 'Heartland',
#  'Osborne,Kansas': 'Great Plains',
#  'Ottawa,Kansas': 'Great Plains',
#  'Pawnee,Kansas': 'Great Plains',
#  'Phillips,Kansas': 'Great Plains',
#  'Pottawatomie,Kansas': 'Great Plains',
#  'Pratt,Kansas': 'Great Plains',
#  'Rawlins,Kansas': 'Great Plains',
#  'Reno,Kansas': 'Great Plains',
#  'Republic,Kansas': 'Great Plains',
#  'Rice,Kansas': 'Great Plains',
#  'Riley,Kansas': 'Great Plains',
#  'Rooks,Kansas': 'Great Plains',
#  'Rush,Kansas': 'Great Plains',
#  'Russell,Kansas': 'Great Plains',
#  'Saline,Kansas': 'Great Plains',
#  'Scott,Kansas': 'Great Plains',
#  'Sedgwick,Kansas': 'Great Plains',
#  'Seward,Kansas': 'Great Plains',
#  'Shawnee,Kansas': 'Heartland',
#  'Sheridan,Kansas': 'Great Plains',
#  'Sherman,Kansas': 'Great Plains',
#  'Smith,Kansas': 'Great Plains',
#  'Stafford,Kansas': 'Great Plains',
#  'Stanton,Kansas': 'Great Plains',
#  'Stevens,Kansas': 'Great Plains',
#  'Sumner,Kansas': 'Great Plains',
#  'Thomas,Kansas': 'Great Plains',
#  'Trego,Kansas': 'Great Plains',
#  'Wabaunsee,Kansas': 'Great Plains',
#  'Wallace,Kansas': 'Great Plains',
#  'Washington,Kansas': 'Great Plains',
#  'Wichita,Kansas': 'Great Plains',
#  'Wilson,Kansas': 'Appohzarka',
#  'Woodson,Kansas': 'Appohzarka',
#  'Wyandotte,Kansas': 'Heartland',
#  'Adair,Kentucky': 'Appohzarka',
#  'Allen,Kentucky': 'Appohzarka',
#  'Anderson,Kentucky': 'Appohzarka',
#  'Ballard,Kentucky': 'Appohzarka',
#  'Barren,Kentucky': 'Appohzarka',
#  'Bath,Kentucky': 'Appohzarka',
#  'Bell,Kentucky': 'Appohzarka',
#  ...}

# %%
county_state = [cs.split(',') for cs in cs2r]
county_state
# Out:
# [['Autauga', 'Alabama'],
#  ['Baldwin', 'Alabama'],
#  ['Barbour', 'Alabama'],
#  ['Bibb', 'Alabama'],
#  ['Blount', 'Alabama'],
#  ['Bullock', 'Alabama'],
#  ['Butler', 'Alabama'],
#  ['Calhoun', 'Alabama'],
#  ['Chambers', 'Alabama'],
#  ['Cherokee', 'Alabama'],
#  ['Chilton', 'Alabama'],
#  ['Choctaw', 'Alabama'],
#  ['Clarke', 'Alabama'],
#  ['Clay', 'Alabama'],
#  ['Cleburne', 'Alabama'],
#  ['Coffee', 'Alabama'],
#  ['Colbert', 'Alabama'],
#  ['Conecuh', 'Alabama'],
#  ['Coosa', 'Alabama'],
#  ['Covington', 'Alabama'],
#  ['Crenshaw', 'Alabama'],
#  ['Cullman', 'Alabama'],
#  ['Dale', 'Alabama'],
#  ['Dallas', 'Alabama'],
#  ['DeKalb', 'Alabama'],
#  ['Elmore', 'Alabama'],
#  ['Escambia', 'Alabama'],
#  ['Etowah', 'Alabama'],
#  ['Fayette', 'Alabama'],
#  ['Franklin', 'Alabama'],
#  ['Geneva', 'Alabama'],
#  ['Greene', 'Alabama'],
#  ['Hale', 'Alabama'],
#  ['Henry', 'Alabama'],
#  ['Houston', 'Alabama'],
#  ['Jackson', 'Alabama'],
#  ['Jefferson', 'Alabama'],
#  ['Lamar', 'Alabama'],
#  ['Lauderdale', 'Alabama'],
#  ['Lawrence', 'Alabama'],
#  ['Lee', 'Alabama'],
#  ['Limestone', 'Alabama'],
#  ['Lowndes', 'Alabama'],
#  ['Macon', 'Alabama'],
#  ['Madison', 'Alabama'],
#  ['Marengo', 'Alabama'],
#  ['Marion', 'Alabama'],
#  ['Marshall', 'Alabama'],
#  ['Mobile', 'Alabama'],
#  ['Monroe', 'Alabama'],
#  ['Montgomery', 'Alabama'],
#  ['Morgan', 'Alabama'],
#  ['Perry', 'Alabama'],
#  ['Pickens', 'Alabama'],
#  ['Pike', 'Alabama'],
#  ['Randolph', 'Alabama'],
#  ['Russell', 'Alabama'],
#  ['St. Clair', 'Alabama'],
#  ['Shelby', 'Alabama'],
#  ['Sumter', 'Alabama'],
#  ['Talladega', 'Alabama'],
#  ['Tallapoosa', 'Alabama'],
#  ['Tuscaloosa', 'Alabama'],
#  ['Walker', 'Alabama'],
#  ['Washington', 'Alabama'],
#  ['Wilcox', 'Alabama'],
#  ['Winston', 'Alabama'],
#  ['Aleutians East', 'Alaska'],
#  ['Aleutians West', 'Alaska'],
#  ['Anchorage', 'Alaska'],
#  ['Bethel', 'Alaska'],
#  ['Bristol Bay', 'Alaska'],
#  ['Denali', 'Alaska'],
#  ['Dillingham', 'Alaska'],
#  ['Fairbanks North Star', 'Alaska'],
#  ['Haines', 'Alaska'],
#  ['Skagway-Hoonah-Angoon', 'Alaska'],
#  ['Juneau', 'Alaska'],
#  ['Kenai Peninsula', 'Alaska'],
#  ['Ketchikan Gateway', 'Alaska'],
#  ['Kodiak Island', 'Alaska'],
#  ['Kusilvak', 'Alaska'],
#  ['Lake and Peninsula', 'Alaska'],
#  ['Matanuska-Susitna', 'Alaska'],
#  ['Nome', 'Alaska'],
#  ['North Slope', 'Alaska'],
#  ['Northwest Arctic', 'Alaska'],
#  ['Petersburg Borough', 'Alaska'],
#  ['Prince of Wales-Outer Ketchikan', 'Alaska'],
#  ['Sitka', 'Alaska'],
#  ['Skagway Municipality', 'Alaska'],
#  ['Southeast Fairbanks', 'Alaska'],
#  ['Valdez-Cordova', 'Alaska'],
#  ['Wrangell City and Borough', 'Alaska'],
#  ['Yakutat', 'Alaska'],
#  ['Yukon-Koyukuk', 'Alaska'],
#  ['Apache', 'Arizona'],
#  ['Cochise', 'Arizona'],
#  ['Coconino', 'Arizona'],
#  ['Gila', 'Arizona'],
#  ['Graham', 'Arizona'],
#  ['Greenlee', 'Arizona'],
#  ['La Paz', 'Arizona'],
#  ['Maricopa', 'Arizona'],
#  ['Mohave', 'Arizona'],
#  ['Navajo', 'Arizona'],
#  ['Pima', 'Arizona'],
#  ['Pinal', 'Arizona'],
#  ['Santa Cruz', 'Arizona'],
#  ['Yavapai', 'Arizona'],
#  ['Yuma', 'Arizona'],
#  ['Arkansas', 'Arkansas'],
#  ['Ashley', 'Arkansas'],
#  ['Baxter', 'Arkansas'],
#  ['Benton', 'Arkansas'],
#  ['Boone', 'Arkansas'],
#  ['Bradley', 'Arkansas'],
#  ['Calhoun', 'Arkansas'],
#  ['Carroll', 'Arkansas'],
#  ['Chicot', 'Arkansas'],
#  ['Clark', 'Arkansas'],
#  ['Clay', 'Arkansas'],
#  ['Cleburne', 'Arkansas'],
#  ['Cleveland', 'Arkansas'],
#  ['Columbia', 'Arkansas'],
#  ['Conway', 'Arkansas'],
#  ['Craighead', 'Arkansas'],
#  ['Crawford', 'Arkansas'],
#  ['Crittenden', 'Arkansas'],
#  ['Cross', 'Arkansas'],
#  ['Dallas', 'Arkansas'],
#  ['Desha', 'Arkansas'],
#  ['Drew', 'Arkansas'],
#  ['Faulkner', 'Arkansas'],
#  ['Franklin', 'Arkansas'],
#  ['Fulton', 'Arkansas'],
#  ['Garland', 'Arkansas'],
#  ['Grant', 'Arkansas'],
#  ['Greene', 'Arkansas'],
#  ['Hempstead', 'Arkansas'],
#  ['Hot Spring', 'Arkansas'],
#  ['Howard', 'Arkansas'],
#  ['Independence', 'Arkansas'],
#  ['Izard', 'Arkansas'],
#  ['Jackson', 'Arkansas'],
#  ['Jefferson', 'Arkansas'],
#  ['Johnson', 'Arkansas'],
#  ['Lafayette', 'Arkansas'],
#  ['Lawrence', 'Arkansas'],
#  ['Lee', 'Arkansas'],
#  ['Lincoln', 'Arkansas'],
#  ['Little River', 'Arkansas'],
#  ['Logan', 'Arkansas'],
#  ['Lonoke', 'Arkansas'],
#  ['Madison', 'Arkansas'],
#  ['Marion', 'Arkansas'],
#  ['Miller', 'Arkansas'],
#  ['Mississippi', 'Arkansas'],
#  ['Monroe', 'Arkansas'],
#  ['Montgomery', 'Arkansas'],
#  ['Nevada', 'Arkansas'],
#  ['Newton', 'Arkansas'],
#  ['Ouachita', 'Arkansas'],
#  ['Perry', 'Arkansas'],
#  ['Phillips', 'Arkansas'],
#  ['Pike', 'Arkansas'],
#  ['Poinsett', 'Arkansas'],
#  ['Polk', 'Arkansas'],
#  ['Pope', 'Arkansas'],
#  ['Prairie', 'Arkansas'],
#  ['Pulaski', 'Arkansas'],
#  ['Randolph', 'Arkansas'],
#  ['St. Francis', 'Arkansas'],
#  ['Saline', 'Arkansas'],
#  ['Scott', 'Arkansas'],
#  ['Searcy', 'Arkansas'],
#  ['Sebastian', 'Arkansas'],
#  ['Sevier', 'Arkansas'],
#  ['Sharp', 'Arkansas'],
#  ['Stone', 'Arkansas'],
#  ['Union', 'Arkansas'],
#  ['Van Buren', 'Arkansas'],
#  ['Washington', 'Arkansas'],
#  ['White', 'Arkansas'],
#  ['Woodruff', 'Arkansas'],
#  ['Yell', 'Arkansas'],
#  ['Alameda', 'California'],
#  ['Alpine', 'California'],
#  ['Amador', 'California'],
#  ['Butte', 'California'],
#  ['Calaveras', 'California'],
#  ['Colusa', 'California'],
#  ['Contra Costa', 'California'],
#  ['Del Norte', 'California'],
#  ['El Dorado', 'California'],
#  ['Fresno', 'California'],
#  ['Glenn', 'California'],
#  ['Humboldt', 'California'],
#  ['Imperial', 'California'],
#  ['Inyo', 'California'],
#  ['Kern', 'California'],
#  ['Kings', 'California'],
#  ['Lake', 'California'],
#  ['Lassen', 'California'],
#  ['Los Angeles', 'California'],
#  ['Madera', 'California'],
#  ['Marin', 'California'],
#  ['Mariposa', 'California'],
#  ['Mendocino', 'California'],
#  ['Merced', 'California'],
#  ['Modoc', 'California'],
#  ['Mono', 'California'],
#  ['Monterey', 'California'],
#  ['Napa', 'California'],
#  ['Nevada', 'California'],
#  ['Orange', 'California'],
#  ['Placer', 'California'],
#  ['Plumas', 'California'],
#  ['Riverside', 'California'],
#  ['Sacramento', 'California'],
#  ['San Benito', 'California'],
#  ['San Bernardino', 'California'],
#  ['San Diego', 'California'],
#  ['San Francisco', 'California'],
#  ['San Joaquin', 'California'],
#  ['San Luis Obispo', 'California'],
#  ['San Mateo', 'California'],
#  ['Santa Barbara', 'California'],
#  ['Santa Clara', 'California'],
#  ['Santa Cruz', 'California'],
#  ['Shasta', 'California'],
#  ['Sierra', 'California'],
#  ['Siskiyou', 'California'],
#  ['Solano', 'California'],
#  ['Sonoma', 'California'],
#  ['Stanislaus', 'California'],
#  ['Sutter', 'California'],
#  ['Tehama', 'California'],
#  ['Trinity', 'California'],
#  ['Tulare', 'California'],
#  ['Tuolumne', 'California'],
#  ['Ventura', 'California'],
#  ['Yolo', 'California'],
#  ['Yuba', 'California'],
#  ['Adams', 'Colorado'],
#  ['Alamosa', 'Colorado'],
#  ['Arapahoe', 'Colorado'],
#  ['Archuleta', 'Colorado'],
#  ['Baca', 'Colorado'],
#  ['Bent', 'Colorado'],
#  ['Boulder', 'Colorado'],
#  ['Broomfield', 'Colorado'],
#  ['Chaffee', 'Colorado'],
#  ['Cheyenne', 'Colorado'],
#  ['Clear Creek', 'Colorado'],
#  ['Conejos', 'Colorado'],
#  ['Costilla', 'Colorado'],
#  ['Crowley', 'Colorado'],
#  ['Custer', 'Colorado'],
#  ['Delta', 'Colorado'],
#  ['Denver', 'Colorado'],
#  ['Dolores', 'Colorado'],
#  ['Douglas', 'Colorado'],
#  ['Eagle', 'Colorado'],
#  ['Elbert', 'Colorado'],
#  ['El Paso', 'Colorado'],
#  ['Fremont', 'Colorado'],
#  ['Garfield', 'Colorado'],
#  ['Gilpin', 'Colorado'],
#  ['Grand', 'Colorado'],
#  ['Gunnison', 'Colorado'],
#  ['Hinsdale', 'Colorado'],
#  ['Huerfano', 'Colorado'],
#  ['Jackson', 'Colorado'],
#  ['Jefferson', 'Colorado'],
#  ['Kiowa', 'Colorado'],
#  ['Kit Carson', 'Colorado'],
#  ['Lake', 'Colorado'],
#  ['La Plata', 'Colorado'],
#  ['Larimer', 'Colorado'],
#  ['Las Animas', 'Colorado'],
#  ['Lincoln', 'Colorado'],
#  ['Logan', 'Colorado'],
#  ['Mesa', 'Colorado'],
#  ['Mineral', 'Colorado'],
#  ['Moffat', 'Colorado'],
#  ['Montezuma', 'Colorado'],
#  ['Montrose', 'Colorado'],
#  ['Morgan', 'Colorado'],
#  ['Otero', 'Colorado'],
#  ['Ouray', 'Colorado'],
#  ['Park', 'Colorado'],
#  ['Phillips', 'Colorado'],
#  ['Pitkin', 'Colorado'],
#  ['Prowers', 'Colorado'],
#  ['Pueblo', 'Colorado'],
#  ['Rio Blanco', 'Colorado'],
#  ['Rio Grande', 'Colorado'],
#  ['Routt', 'Colorado'],
#  ['Saguache', 'Colorado'],
#  ['San Juan', 'Colorado'],
#  ['San Miguel', 'Colorado'],
#  ['Sedgwick', 'Colorado'],
#  ['Summit', 'Colorado'],
#  ['Teller', 'Colorado'],
#  ['Washington', 'Colorado'],
#  ['Weld', 'Colorado'],
#  ['Yuma', 'Colorado'],
#  ['Fairfield', 'Connecticut'],
#  ['Hartford', 'Connecticut'],
#  ['Litchfield', 'Connecticut'],
#  ['Middlesex', 'Connecticut'],
#  ['New Haven', 'Connecticut'],
#  ['New London', 'Connecticut'],
#  ['Tolland', 'Connecticut'],
#  ['Windham', 'Connecticut'],
#  ['Kent', 'Delaware'],
#  ['New Castle', 'Delaware'],
#  ['Sussex', 'Delaware'],
#  ['District of Columbia', 'District of Columbia'],
#  ['Alachua', 'Florida'],
#  ['Baker', 'Florida'],
#  ['Bay', 'Florida'],
#  ['Bradford', 'Florida'],
#  ['Brevard', 'Florida'],
#  ['Broward', 'Florida'],
#  ['Calhoun', 'Florida'],
#  ['Charlotte', 'Florida'],
#  ['Citrus', 'Florida'],
#  ['Clay', 'Florida'],
#  ['Collier', 'Florida'],
#  ['Columbia', 'Florida'],
#  ['DeSoto', 'Florida'],
#  ['Dixie', 'Florida'],
#  ['Duval', 'Florida'],
#  ['Escambia', 'Florida'],
#  ['Flagler', 'Florida'],
#  ['Franklin', 'Florida'],
#  ['Gadsden', 'Florida'],
#  ['Gilchrist', 'Florida'],
#  ['Glades', 'Florida'],
#  ['Gulf', 'Florida'],
#  ['Hamilton', 'Florida'],
#  ['Hardee', 'Florida'],
#  ['Hendry', 'Florida'],
#  ['Hernando', 'Florida'],
#  ['Highlands', 'Florida'],
#  ['Hillsborough', 'Florida'],
#  ['Holmes', 'Florida'],
#  ['Indian River', 'Florida'],
#  ['Jackson', 'Florida'],
#  ['Jefferson', 'Florida'],
#  ['Lafayette', 'Florida'],
#  ['Lake', 'Florida'],
#  ['Lee', 'Florida'],
#  ['Leon', 'Florida'],
#  ['Levy', 'Florida'],
#  ['Liberty', 'Florida'],
#  ['Madison', 'Florida'],
#  ['Manatee', 'Florida'],
#  ['Marion', 'Florida'],
#  ['Martin', 'Florida'],
#  ['Miami-Dade', 'Florida'],
#  ['Monroe', 'Florida'],
#  ['Nassau', 'Florida'],
#  ['Okaloosa', 'Florida'],
#  ['Okeechobee', 'Florida'],
#  ['Orange', 'Florida'],
#  ['Osceola', 'Florida'],
#  ['Palm Beach', 'Florida'],
#  ['Pasco', 'Florida'],
#  ['Pinellas', 'Florida'],
#  ['Polk', 'Florida'],
#  ['Putnam', 'Florida'],
#  ['St. Johns', 'Florida'],
#  ['St. Lucie', 'Florida'],
#  ['Santa Rosa', 'Florida'],
#  ['Sarasota', 'Florida'],
#  ['Seminole', 'Florida'],
#  ['Sumter', 'Florida'],
#  ['Suwannee', 'Florida'],
#  ['Taylor', 'Florida'],
#  ['Union', 'Florida'],
#  ['Volusia', 'Florida'],
#  ['Wakulla', 'Florida'],
#  ['Walton', 'Florida'],
#  ['Washington', 'Florida'],
#  ['Appling', 'Georgia'],
#  ['Atkinson', 'Georgia'],
#  ['Bacon', 'Georgia'],
#  ['Baker', 'Georgia'],
#  ['Baldwin', 'Georgia'],
#  ['Banks', 'Georgia'],
#  ['Barrow', 'Georgia'],
#  ['Bartow', 'Georgia'],
#  ['Ben Hill', 'Georgia'],
#  ['Berrien', 'Georgia'],
#  ['Bibb', 'Georgia'],
#  ['Bleckley', 'Georgia'],
#  ['Brantley', 'Georgia'],
#  ['Brooks', 'Georgia'],
#  ['Bryan', 'Georgia'],
#  ['Bulloch', 'Georgia'],
#  ['Burke', 'Georgia'],
#  ['Butts', 'Georgia'],
#  ['Calhoun', 'Georgia'],
#  ['Camden', 'Georgia'],
#  ['Candler', 'Georgia'],
#  ['Carroll', 'Georgia'],
#  ['Catoosa', 'Georgia'],
#  ['Charlton', 'Georgia'],
#  ['Chatham', 'Georgia'],
#  ['Chattahoochee', 'Georgia'],
#  ['Chattooga', 'Georgia'],
#  ['Cherokee', 'Georgia'],
#  ['Clarke', 'Georgia'],
#  ['Clay', 'Georgia'],
#  ['Clayton', 'Georgia'],
#  ['Clinch', 'Georgia'],
#  ['Cobb', 'Georgia'],
#  ['Coffee', 'Georgia'],
#  ['Colquitt', 'Georgia'],
#  ['Columbia', 'Georgia'],
#  ['Cook', 'Georgia'],
#  ['Coweta', 'Georgia'],
#  ['Crawford', 'Georgia'],
#  ['Crisp', 'Georgia'],
#  ['Dade', 'Georgia'],
#  ['Dawson', 'Georgia'],
#  ['Decatur', 'Georgia'],
#  ['DeKalb', 'Georgia'],
#  ['Dodge', 'Georgia'],
#  ['Dooly', 'Georgia'],
#  ['Dougherty', 'Georgia'],
#  ['Douglas', 'Georgia'],
#  ['Early', 'Georgia'],
#  ['Echols', 'Georgia'],
#  ['Effingham', 'Georgia'],
#  ['Elbert', 'Georgia'],
#  ['Emanuel', 'Georgia'],
#  ['Evans', 'Georgia'],
#  ['Fannin', 'Georgia'],
#  ['Fayette', 'Georgia'],
#  ['Floyd', 'Georgia'],
#  ['Forsyth', 'Georgia'],
#  ['Franklin', 'Georgia'],
#  ['Fulton', 'Georgia'],
#  ['Gilmer', 'Georgia'],
#  ['Glascock', 'Georgia'],
#  ['Glynn', 'Georgia'],
#  ['Gordon', 'Georgia'],
#  ['Grady', 'Georgia'],
#  ['Greene', 'Georgia'],
#  ['Gwinnett', 'Georgia'],
#  ['Habersham', 'Georgia'],
#  ['Hall', 'Georgia'],
#  ['Hancock', 'Georgia'],
#  ['Haralson', 'Georgia'],
#  ['Harris', 'Georgia'],
#  ['Hart', 'Georgia'],
#  ['Heard', 'Georgia'],
#  ['Henry', 'Georgia'],
#  ['Houston', 'Georgia'],
#  ['Irwin', 'Georgia'],
#  ['Jackson', 'Georgia'],
#  ['Jasper', 'Georgia'],
#  ['Jeff Davis', 'Georgia'],
#  ['Jefferson', 'Georgia'],
#  ['Jenkins', 'Georgia'],
#  ['Johnson', 'Georgia'],
#  ['Jones', 'Georgia'],
#  ['Lamar', 'Georgia'],
#  ['Lanier', 'Georgia'],
#  ['Laurens', 'Georgia'],
#  ['Lee', 'Georgia'],
#  ['Liberty', 'Georgia'],
#  ['Lincoln', 'Georgia'],
#  ['Long', 'Georgia'],
#  ['Lowndes', 'Georgia'],
#  ['Lumpkin', 'Georgia'],
#  ['McDuffie', 'Georgia'],
#  ['McIntosh', 'Georgia'],
#  ['Macon', 'Georgia'],
#  ['Madison', 'Georgia'],
#  ['Marion', 'Georgia'],
#  ['Meriwether', 'Georgia'],
#  ['Miller', 'Georgia'],
#  ['Mitchell', 'Georgia'],
#  ['Monroe', 'Georgia'],
#  ['Montgomery', 'Georgia'],
#  ['Morgan', 'Georgia'],
#  ['Murray', 'Georgia'],
#  ['Muscogee', 'Georgia'],
#  ['Newton', 'Georgia'],
#  ['Oconee', 'Georgia'],
#  ['Oglethorpe', 'Georgia'],
#  ['Paulding', 'Georgia'],
#  ['Peach', 'Georgia'],
#  ['Pickens', 'Georgia'],
#  ['Pierce', 'Georgia'],
#  ['Pike', 'Georgia'],
#  ['Polk', 'Georgia'],
#  ['Pulaski', 'Georgia'],
#  ['Putnam', 'Georgia'],
#  ['Quitman', 'Georgia'],
#  ['Rabun', 'Georgia'],
#  ['Randolph', 'Georgia'],
#  ['Richmond', 'Georgia'],
#  ['Rockdale', 'Georgia'],
#  ['Schley', 'Georgia'],
#  ['Screven', 'Georgia'],
#  ['Seminole', 'Georgia'],
#  ['Spalding', 'Georgia'],
#  ['Stephens', 'Georgia'],
#  ['Stewart', 'Georgia'],
#  ['Sumter', 'Georgia'],
#  ['Talbot', 'Georgia'],
#  ['Taliaferro', 'Georgia'],
#  ['Tattnall', 'Georgia'],
#  ['Taylor', 'Georgia'],
#  ['Telfair', 'Georgia'],
#  ['Terrell', 'Georgia'],
#  ['Thomas', 'Georgia'],
#  ['Tift', 'Georgia'],
#  ['Toombs', 'Georgia'],
#  ['Towns', 'Georgia'],
#  ['Treutlen', 'Georgia'],
#  ['Troup', 'Georgia'],
#  ['Turner', 'Georgia'],
#  ['Twiggs', 'Georgia'],
#  ['Union', 'Georgia'],
#  ['Upson', 'Georgia'],
#  ['Walker', 'Georgia'],
#  ['Walton', 'Georgia'],
#  ['Ware', 'Georgia'],
#  ['Warren', 'Georgia'],
#  ['Washington', 'Georgia'],
#  ['Wayne', 'Georgia'],
#  ['Webster', 'Georgia'],
#  ['Wheeler', 'Georgia'],
#  ['White', 'Georgia'],
#  ['Whitfield', 'Georgia'],
#  ['Wilcox', 'Georgia'],
#  ['Wilkes', 'Georgia'],
#  ['Wilkinson', 'Georgia'],
#  ['Worth', 'Georgia'],
#  ['Hawaii', 'Hawaii'],
#  ['Honolulu', 'Hawaii'],
#  ['Kalawao', 'Hawaii'],
#  ['Kauai', 'Hawaii'],
#  ['Maui', 'Hawaii'],
#  ['Ada', 'Idaho'],
#  ['Adams', 'Idaho'],
#  ['Bannock', 'Idaho'],
#  ['Bear Lake', 'Idaho'],
#  ['Benewah', 'Idaho'],
#  ['Bingham', 'Idaho'],
#  ['Blaine', 'Idaho'],
#  ['Boise', 'Idaho'],
#  ['Bonner', 'Idaho'],
#  ['Bonneville', 'Idaho'],
#  ['Boundary', 'Idaho'],
#  ['Butte', 'Idaho'],
#  ['Camas', 'Idaho'],
#  ['Canyon', 'Idaho'],
#  ['Caribou', 'Idaho'],
#  ['Cassia', 'Idaho'],
#  ['Clark', 'Idaho'],
#  ['Clearwater', 'Idaho'],
#  ['Custer', 'Idaho'],
#  ['Elmore', 'Idaho'],
#  ['Franklin', 'Idaho'],
#  ['Fremont', 'Idaho'],
#  ['Gem', 'Idaho'],
#  ['Gooding', 'Idaho'],
#  ['Idaho', 'Idaho'],
#  ['Jefferson', 'Idaho'],
#  ['Jerome', 'Idaho'],
#  ['Kootenai', 'Idaho'],
#  ['Latah', 'Idaho'],
#  ['Lemhi', 'Idaho'],
#  ['Lewis', 'Idaho'],
#  ['Lincoln', 'Idaho'],
#  ['Madison', 'Idaho'],
#  ['Minidoka', 'Idaho'],
#  ['Nez Perce', 'Idaho'],
#  ['Oneida', 'Idaho'],
#  ['Owyhee', 'Idaho'],
#  ['Payette', 'Idaho'],
#  ['Power', 'Idaho'],
#  ['Shoshone', 'Idaho'],
#  ['Teton', 'Idaho'],
#  ['Twin Falls', 'Idaho'],
#  ['Valley', 'Idaho'],
#  ['Washington', 'Idaho'],
#  ['Adams', 'Illinois'],
#  ['Alexander', 'Illinois'],
#  ['Bond', 'Illinois'],
#  ['Boone', 'Illinois'],
#  ['Brown', 'Illinois'],
#  ['Bureau', 'Illinois'],
#  ['Calhoun', 'Illinois'],
#  ['Carroll', 'Illinois'],
#  ['Cass', 'Illinois'],
#  ['Champaign', 'Illinois'],
#  ['Christian', 'Illinois'],
#  ['Clark', 'Illinois'],
#  ['Clay', 'Illinois'],
#  ['Clinton', 'Illinois'],
#  ['Coles', 'Illinois'],
#  ['Cook', 'Illinois'],
#  ['Crawford', 'Illinois'],
#  ['Cumberland', 'Illinois'],
#  ['DeKalb', 'Illinois'],
#  ['De Witt', 'Illinois'],
#  ['Douglas', 'Illinois'],
#  ['DuPage', 'Illinois'],
#  ['Edgar', 'Illinois'],
#  ['Edwards', 'Illinois'],
#  ['Effingham', 'Illinois'],
#  ['Fayette', 'Illinois'],
#  ['Ford', 'Illinois'],
#  ['Franklin', 'Illinois'],
#  ['Fulton', 'Illinois'],
#  ['Gallatin', 'Illinois'],
#  ['Greene', 'Illinois'],
#  ['Grundy', 'Illinois'],
#  ['Hamilton', 'Illinois'],
#  ['Hancock', 'Illinois'],
#  ['Hardin', 'Illinois'],
#  ['Henderson', 'Illinois'],
#  ['Henry', 'Illinois'],
#  ['Iroquois', 'Illinois'],
#  ['Jackson', 'Illinois'],
#  ['Jasper', 'Illinois'],
#  ['Jefferson', 'Illinois'],
#  ['Jersey', 'Illinois'],
#  ['Jo Daviess', 'Illinois'],
#  ['Johnson', 'Illinois'],
#  ['Kane', 'Illinois'],
#  ['Kankakee', 'Illinois'],
#  ['Kendall', 'Illinois'],
#  ['Knox', 'Illinois'],
#  ['Lake', 'Illinois'],
#  ['LaSalle', 'Illinois'],
#  ['Lawrence', 'Illinois'],
#  ['Lee', 'Illinois'],
#  ['Livingston', 'Illinois'],
#  ['Logan', 'Illinois'],
#  ['McDonough', 'Illinois'],
#  ['McHenry', 'Illinois'],
#  ['McLean', 'Illinois'],
#  ['Macon', 'Illinois'],
#  ['Macoupin', 'Illinois'],
#  ['Madison', 'Illinois'],
#  ['Marion', 'Illinois'],
#  ['Marshall', 'Illinois'],
#  ['Mason', 'Illinois'],
#  ['Massac', 'Illinois'],
#  ['Menard', 'Illinois'],
#  ['Mercer', 'Illinois'],
#  ['Monroe', 'Illinois'],
#  ['Montgomery', 'Illinois'],
#  ['Morgan', 'Illinois'],
#  ['Moultrie', 'Illinois'],
#  ['Ogle', 'Illinois'],
#  ['Peoria', 'Illinois'],
#  ['Perry', 'Illinois'],
#  ['Piatt', 'Illinois'],
#  ['Pike', 'Illinois'],
#  ['Pope', 'Illinois'],
#  ['Pulaski', 'Illinois'],
#  ['Putnam', 'Illinois'],
#  ['Randolph', 'Illinois'],
#  ['Richland', 'Illinois'],
#  ['Rock Island', 'Illinois'],
#  ['St. Clair', 'Illinois'],
#  ['Saline', 'Illinois'],
#  ['Sangamon', 'Illinois'],
#  ['Schuyler', 'Illinois'],
#  ['Scott', 'Illinois'],
#  ['Shelby', 'Illinois'],
#  ['Stark', 'Illinois'],
#  ['Stephenson', 'Illinois'],
#  ['Tazewell', 'Illinois'],
#  ['Union', 'Illinois'],
#  ['Vermilion', 'Illinois'],
#  ['Wabash', 'Illinois'],
#  ['Warren', 'Illinois'],
#  ['Washington', 'Illinois'],
#  ['Wayne', 'Illinois'],
#  ['White', 'Illinois'],
#  ['Whiteside', 'Illinois'],
#  ['Will', 'Illinois'],
#  ['Williamson', 'Illinois'],
#  ['Winnebago', 'Illinois'],
#  ['Woodford', 'Illinois'],
#  ['Adams', 'Indiana'],
#  ['Allen', 'Indiana'],
#  ['Bartholomew', 'Indiana'],
#  ['Benton', 'Indiana'],
#  ['Blackford', 'Indiana'],
#  ['Boone', 'Indiana'],
#  ['Brown', 'Indiana'],
#  ['Carroll', 'Indiana'],
#  ['Cass', 'Indiana'],
#  ['Clark', 'Indiana'],
#  ['Clay', 'Indiana'],
#  ['Clinton', 'Indiana'],
#  ['Crawford', 'Indiana'],
#  ['Daviess', 'Indiana'],
#  ['Dearborn', 'Indiana'],
#  ['Decatur', 'Indiana'],
#  ['DeKalb', 'Indiana'],
#  ['Delaware', 'Indiana'],
#  ['Dubois', 'Indiana'],
#  ['Elkhart', 'Indiana'],
#  ['Fayette', 'Indiana'],
#  ['Floyd', 'Indiana'],
#  ['Fountain', 'Indiana'],
#  ['Franklin', 'Indiana'],
#  ['Fulton', 'Indiana'],
#  ['Gibson', 'Indiana'],
#  ['Grant', 'Indiana'],
#  ['Greene', 'Indiana'],
#  ['Hamilton', 'Indiana'],
#  ['Hancock', 'Indiana'],
#  ['Harrison', 'Indiana'],
#  ['Hendricks', 'Indiana'],
#  ['Henry', 'Indiana'],
#  ['Howard', 'Indiana'],
#  ['Huntington', 'Indiana'],
#  ['Jackson', 'Indiana'],
#  ['Jasper', 'Indiana'],
#  ['Jay', 'Indiana'],
#  ['Jefferson', 'Indiana'],
#  ['Jennings', 'Indiana'],
#  ['Johnson', 'Indiana'],
#  ['Knox', 'Indiana'],
#  ['Kosciusko', 'Indiana'],
#  ['LaGrange', 'Indiana'],
#  ['Lake', 'Indiana'],
#  ['LaPorte', 'Indiana'],
#  ['Lawrence', 'Indiana'],
#  ['Madison', 'Indiana'],
#  ['Marion', 'Indiana'],
#  ['Marshall', 'Indiana'],
#  ['Martin', 'Indiana'],
#  ['Miami', 'Indiana'],
#  ['Monroe', 'Indiana'],
#  ['Montgomery', 'Indiana'],
#  ['Morgan', 'Indiana'],
#  ['Newton', 'Indiana'],
#  ['Noble', 'Indiana'],
#  ['Ohio', 'Indiana'],
#  ['Orange', 'Indiana'],
#  ['Owen', 'Indiana'],
#  ['Parke', 'Indiana'],
#  ['Perry', 'Indiana'],
#  ['Pike', 'Indiana'],
#  ['Porter', 'Indiana'],
#  ['Posey', 'Indiana'],
#  ['Pulaski', 'Indiana'],
#  ['Putnam', 'Indiana'],
#  ['Randolph', 'Indiana'],
#  ['Ripley', 'Indiana'],
#  ['Rush', 'Indiana'],
#  ['St. Joseph', 'Indiana'],
#  ['Scott', 'Indiana'],
#  ['Shelby', 'Indiana'],
#  ['Spencer', 'Indiana'],
#  ['Starke', 'Indiana'],
#  ['Steuben', 'Indiana'],
#  ['Sullivan', 'Indiana'],
#  ['Switzerland', 'Indiana'],
#  ['Tippecanoe', 'Indiana'],
#  ['Tipton', 'Indiana'],
#  ['Union', 'Indiana'],
#  ['Vanderburgh', 'Indiana'],
#  ['Vermillion', 'Indiana'],
#  ['Vigo', 'Indiana'],
#  ['Wabash', 'Indiana'],
#  ['Warren', 'Indiana'],
#  ['Warrick', 'Indiana'],
#  ['Washington', 'Indiana'],
#  ['Wayne', 'Indiana'],
#  ['Wells', 'Indiana'],
#  ['White', 'Indiana'],
#  ['Whitley', 'Indiana'],
#  ['Adair', 'Iowa'],
#  ['Adams', 'Iowa'],
#  ['Allamakee', 'Iowa'],
#  ['Appanoose', 'Iowa'],
#  ['Audubon', 'Iowa'],
#  ['Benton', 'Iowa'],
#  ['Black Hawk', 'Iowa'],
#  ['Boone', 'Iowa'],
#  ['Bremer', 'Iowa'],
#  ['Buchanan', 'Iowa'],
#  ['Buena Vista', 'Iowa'],
#  ['Butler', 'Iowa'],
#  ['Calhoun', 'Iowa'],
#  ['Carroll', 'Iowa'],
#  ['Cass', 'Iowa'],
#  ['Cedar', 'Iowa'],
#  ['Cerro Gordo', 'Iowa'],
#  ['Cherokee', 'Iowa'],
#  ['Chickasaw', 'Iowa'],
#  ['Clarke', 'Iowa'],
#  ['Clay', 'Iowa'],
#  ['Clayton', 'Iowa'],
#  ['Clinton', 'Iowa'],
#  ['Crawford', 'Iowa'],
#  ['Dallas', 'Iowa'],
#  ['Davis', 'Iowa'],
#  ['Decatur', 'Iowa'],
#  ['Delaware', 'Iowa'],
#  ['Des Moines', 'Iowa'],
#  ['Dickinson', 'Iowa'],
#  ['Dubuque', 'Iowa'],
#  ['Emmet', 'Iowa'],
#  ['Fayette', 'Iowa'],
#  ['Floyd', 'Iowa'],
#  ['Franklin', 'Iowa'],
#  ['Fremont', 'Iowa'],
#  ['Greene', 'Iowa'],
#  ['Grundy', 'Iowa'],
#  ['Guthrie', 'Iowa'],
#  ['Hamilton', 'Iowa'],
#  ['Hancock', 'Iowa'],
#  ['Hardin', 'Iowa'],
#  ['Harrison', 'Iowa'],
#  ['Henry', 'Iowa'],
#  ['Howard', 'Iowa'],
#  ['Humboldt', 'Iowa'],
#  ['Ida', 'Iowa'],
#  ['Iowa', 'Iowa'],
#  ['Jackson', 'Iowa'],
#  ['Jasper', 'Iowa'],
#  ['Jefferson', 'Iowa'],
#  ['Johnson', 'Iowa'],
#  ['Jones', 'Iowa'],
#  ['Keokuk', 'Iowa'],
#  ['Kossuth', 'Iowa'],
#  ['Lee', 'Iowa'],
#  ['Linn', 'Iowa'],
#  ['Louisa', 'Iowa'],
#  ['Lucas', 'Iowa'],
#  ['Lyon', 'Iowa'],
#  ['Madison', 'Iowa'],
#  ['Mahaska', 'Iowa'],
#  ['Marion', 'Iowa'],
#  ['Marshall', 'Iowa'],
#  ['Mills', 'Iowa'],
#  ['Mitchell', 'Iowa'],
#  ['Monona', 'Iowa'],
#  ['Monroe', 'Iowa'],
#  ['Montgomery', 'Iowa'],
#  ['Muscatine', 'Iowa'],
#  ["O'Brien", 'Iowa'],
#  ['Osceola', 'Iowa'],
#  ['Page', 'Iowa'],
#  ['Palo Alto', 'Iowa'],
#  ['Plymouth', 'Iowa'],
#  ['Pocahontas', 'Iowa'],
#  ['Polk', 'Iowa'],
#  ['Pottawattamie', 'Iowa'],
#  ['Poweshiek', 'Iowa'],
#  ['Ringgold', 'Iowa'],
#  ['Sac', 'Iowa'],
#  ['Scott', 'Iowa'],
#  ['Shelby', 'Iowa'],
#  ['Sioux', 'Iowa'],
#  ['Story', 'Iowa'],
#  ['Tama', 'Iowa'],
#  ['Taylor', 'Iowa'],
#  ['Union', 'Iowa'],
#  ['Van Buren', 'Iowa'],
#  ['Wapello', 'Iowa'],
#  ['Warren', 'Iowa'],
#  ['Washington', 'Iowa'],
#  ['Wayne', 'Iowa'],
#  ['Webster', 'Iowa'],
#  ['Winnebago', 'Iowa'],
#  ['Winneshiek', 'Iowa'],
#  ['Woodbury', 'Iowa'],
#  ['Worth', 'Iowa'],
#  ['Wright', 'Iowa'],
#  ['Allen', 'Kansas'],
#  ['Anderson', 'Kansas'],
#  ['Atchison', 'Kansas'],
#  ['Barber', 'Kansas'],
#  ['Barton', 'Kansas'],
#  ['Bourbon', 'Kansas'],
#  ['Brown', 'Kansas'],
#  ['Butler', 'Kansas'],
#  ['Chase', 'Kansas'],
#  ['Chautauqua', 'Kansas'],
#  ['Cherokee', 'Kansas'],
#  ['Cheyenne', 'Kansas'],
#  ['Clark', 'Kansas'],
#  ['Clay', 'Kansas'],
#  ['Cloud', 'Kansas'],
#  ['Coffey', 'Kansas'],
#  ['Comanche', 'Kansas'],
#  ['Cowley', 'Kansas'],
#  ['Crawford', 'Kansas'],
#  ['Decatur', 'Kansas'],
#  ['Dickinson', 'Kansas'],
#  ['Doniphan', 'Kansas'],
#  ['Douglas', 'Kansas'],
#  ['Edwards', 'Kansas'],
#  ['Elk', 'Kansas'],
#  ['Ellis', 'Kansas'],
#  ['Ellsworth', 'Kansas'],
#  ['Finney', 'Kansas'],
#  ['Ford', 'Kansas'],
#  ['Franklin', 'Kansas'],
#  ['Geary', 'Kansas'],
#  ['Gove', 'Kansas'],
#  ['Graham', 'Kansas'],
#  ['Grant', 'Kansas'],
#  ['Gray', 'Kansas'],
#  ['Greeley', 'Kansas'],
#  ['Greenwood', 'Kansas'],
#  ['Hamilton', 'Kansas'],
#  ['Harper', 'Kansas'],
#  ['Harvey', 'Kansas'],
#  ['Haskell', 'Kansas'],
#  ['Hodgeman', 'Kansas'],
#  ['Jackson', 'Kansas'],
#  ['Jefferson', 'Kansas'],
#  ['Jewell', 'Kansas'],
#  ['Johnson', 'Kansas'],
#  ['Kearny', 'Kansas'],
#  ['Kingman', 'Kansas'],
#  ['Kiowa', 'Kansas'],
#  ['Labette', 'Kansas'],
#  ['Lane', 'Kansas'],
#  ['Leavenworth', 'Kansas'],
#  ['Lincoln', 'Kansas'],
#  ['Linn', 'Kansas'],
#  ['Logan', 'Kansas'],
#  ['Lyon', 'Kansas'],
#  ['McPherson', 'Kansas'],
#  ['Marion', 'Kansas'],
#  ['Marshall', 'Kansas'],
#  ['Meade', 'Kansas'],
#  ['Miami', 'Kansas'],
#  ['Mitchell', 'Kansas'],
#  ['Montgomery', 'Kansas'],
#  ['Morris', 'Kansas'],
#  ['Morton', 'Kansas'],
#  ['Nemaha', 'Kansas'],
#  ['Neosho', 'Kansas'],
#  ['Ness', 'Kansas'],
#  ['Norton', 'Kansas'],
#  ['Osage', 'Kansas'],
#  ['Osborne', 'Kansas'],
#  ['Ottawa', 'Kansas'],
#  ['Pawnee', 'Kansas'],
#  ['Phillips', 'Kansas'],
#  ['Pottawatomie', 'Kansas'],
#  ['Pratt', 'Kansas'],
#  ['Rawlins', 'Kansas'],
#  ['Reno', 'Kansas'],
#  ['Republic', 'Kansas'],
#  ['Rice', 'Kansas'],
#  ['Riley', 'Kansas'],
#  ['Rooks', 'Kansas'],
#  ['Rush', 'Kansas'],
#  ['Russell', 'Kansas'],
#  ['Saline', 'Kansas'],
#  ['Scott', 'Kansas'],
#  ['Sedgwick', 'Kansas'],
#  ['Seward', 'Kansas'],
#  ['Shawnee', 'Kansas'],
#  ['Sheridan', 'Kansas'],
#  ['Sherman', 'Kansas'],
#  ['Smith', 'Kansas'],
#  ['Stafford', 'Kansas'],
#  ['Stanton', 'Kansas'],
#  ['Stevens', 'Kansas'],
#  ['Sumner', 'Kansas'],
#  ['Thomas', 'Kansas'],
#  ['Trego', 'Kansas'],
#  ['Wabaunsee', 'Kansas'],
#  ['Wallace', 'Kansas'],
#  ['Washington', 'Kansas'],
#  ['Wichita', 'Kansas'],
#  ['Wilson', 'Kansas'],
#  ['Woodson', 'Kansas'],
#  ['Wyandotte', 'Kansas'],
#  ['Adair', 'Kentucky'],
#  ['Allen', 'Kentucky'],
#  ['Anderson', 'Kentucky'],
#  ['Ballard', 'Kentucky'],
#  ['Barren', 'Kentucky'],
#  ['Bath', 'Kentucky'],
#  ['Bell', 'Kentucky'],
#  ...]

# %%
len(county_state)
# Out:
# 3142

# %%
county_state = sorted(county_state, key=lambda x: (x[1], x[0]))
county_state
# Out:
# [['Autauga', 'Alabama'],
#  ['Baldwin', 'Alabama'],
#  ['Barbour', 'Alabama'],
#  ['Bibb', 'Alabama'],
#  ['Blount', 'Alabama'],
#  ['Bullock', 'Alabama'],
#  ['Butler', 'Alabama'],
#  ['Calhoun', 'Alabama'],
#  ['Chambers', 'Alabama'],
#  ['Cherokee', 'Alabama'],
#  ['Chilton', 'Alabama'],
#  ['Choctaw', 'Alabama'],
#  ['Clarke', 'Alabama'],
#  ['Clay', 'Alabama'],
#  ['Cleburne', 'Alabama'],
#  ['Coffee', 'Alabama'],
#  ['Colbert', 'Alabama'],
#  ['Conecuh', 'Alabama'],
#  ['Coosa', 'Alabama'],
#  ['Covington', 'Alabama'],
#  ['Crenshaw', 'Alabama'],
#  ['Cullman', 'Alabama'],
#  ['Dale', 'Alabama'],
#  ['Dallas', 'Alabama'],
#  ['DeKalb', 'Alabama'],
#  ['Elmore', 'Alabama'],
#  ['Escambia', 'Alabama'],
#  ['Etowah', 'Alabama'],
#  ['Fayette', 'Alabama'],
#  ['Franklin', 'Alabama'],
#  ['Geneva', 'Alabama'],
#  ['Greene', 'Alabama'],
#  ['Hale', 'Alabama'],
#  ['Henry', 'Alabama'],
#  ['Houston', 'Alabama'],
#  ['Jackson', 'Alabama'],
#  ['Jefferson', 'Alabama'],
#  ['Lamar', 'Alabama'],
#  ['Lauderdale', 'Alabama'],
#  ['Lawrence', 'Alabama'],
#  ['Lee', 'Alabama'],
#  ['Limestone', 'Alabama'],
#  ['Lowndes', 'Alabama'],
#  ['Macon', 'Alabama'],
#  ['Madison', 'Alabama'],
#  ['Marengo', 'Alabama'],
#  ['Marion', 'Alabama'],
#  ['Marshall', 'Alabama'],
#  ['Mobile', 'Alabama'],
#  ['Monroe', 'Alabama'],
#  ['Montgomery', 'Alabama'],
#  ['Morgan', 'Alabama'],
#  ['Perry', 'Alabama'],
#  ['Pickens', 'Alabama'],
#  ['Pike', 'Alabama'],
#  ['Randolph', 'Alabama'],
#  ['Russell', 'Alabama'],
#  ['Shelby', 'Alabama'],
#  ['St. Clair', 'Alabama'],
#  ['Sumter', 'Alabama'],
#  ['Talladega', 'Alabama'],
#  ['Tallapoosa', 'Alabama'],
#  ['Tuscaloosa', 'Alabama'],
#  ['Walker', 'Alabama'],
#  ['Washington', 'Alabama'],
#  ['Wilcox', 'Alabama'],
#  ['Winston', 'Alabama'],
#  ['Aleutians East', 'Alaska'],
#  ['Aleutians West', 'Alaska'],
#  ['Anchorage', 'Alaska'],
#  ['Bethel', 'Alaska'],
#  ['Bristol Bay', 'Alaska'],
#  ['Denali', 'Alaska'],
#  ['Dillingham', 'Alaska'],
#  ['Fairbanks North Star', 'Alaska'],
#  ['Haines', 'Alaska'],
#  ['Juneau', 'Alaska'],
#  ['Kenai Peninsula', 'Alaska'],
#  ['Ketchikan Gateway', 'Alaska'],
#  ['Kodiak Island', 'Alaska'],
#  ['Kusilvak', 'Alaska'],
#  ['Lake and Peninsula', 'Alaska'],
#  ['Matanuska-Susitna', 'Alaska'],
#  ['Nome', 'Alaska'],
#  ['North Slope', 'Alaska'],
#  ['Northwest Arctic', 'Alaska'],
#  ['Petersburg Borough', 'Alaska'],
#  ['Prince of Wales-Outer Ketchikan', 'Alaska'],
#  ['Sitka', 'Alaska'],
#  ['Skagway Municipality', 'Alaska'],
#  ['Skagway-Hoonah-Angoon', 'Alaska'],
#  ['Southeast Fairbanks', 'Alaska'],
#  ['Valdez-Cordova', 'Alaska'],
#  ['Wrangell City and Borough', 'Alaska'],
#  ['Yakutat', 'Alaska'],
#  ['Yukon-Koyukuk', 'Alaska'],
#  ['Apache', 'Arizona'],
#  ['Cochise', 'Arizona'],
#  ['Coconino', 'Arizona'],
#  ['Gila', 'Arizona'],
#  ['Graham', 'Arizona'],
#  ['Greenlee', 'Arizona'],
#  ['La Paz', 'Arizona'],
#  ['Maricopa', 'Arizona'],
#  ['Mohave', 'Arizona'],
#  ['Navajo', 'Arizona'],
#  ['Pima', 'Arizona'],
#  ['Pinal', 'Arizona'],
#  ['Santa Cruz', 'Arizona'],
#  ['Yavapai', 'Arizona'],
#  ['Yuma', 'Arizona'],
#  ['Arkansas', 'Arkansas'],
#  ['Ashley', 'Arkansas'],
#  ['Baxter', 'Arkansas'],
#  ['Benton', 'Arkansas'],
#  ['Boone', 'Arkansas'],
#  ['Bradley', 'Arkansas'],
#  ['Calhoun', 'Arkansas'],
#  ['Carroll', 'Arkansas'],
#  ['Chicot', 'Arkansas'],
#  ['Clark', 'Arkansas'],
#  ['Clay', 'Arkansas'],
#  ['Cleburne', 'Arkansas'],
#  ['Cleveland', 'Arkansas'],
#  ['Columbia', 'Arkansas'],
#  ['Conway', 'Arkansas'],
#  ['Craighead', 'Arkansas'],
#  ['Crawford', 'Arkansas'],
#  ['Crittenden', 'Arkansas'],
#  ['Cross', 'Arkansas'],
#  ['Dallas', 'Arkansas'],
#  ['Desha', 'Arkansas'],
#  ['Drew', 'Arkansas'],
#  ['Faulkner', 'Arkansas'],
#  ['Franklin', 'Arkansas'],
#  ['Fulton', 'Arkansas'],
#  ['Garland', 'Arkansas'],
#  ['Grant', 'Arkansas'],
#  ['Greene', 'Arkansas'],
#  ['Hempstead', 'Arkansas'],
#  ['Hot Spring', 'Arkansas'],
#  ['Howard', 'Arkansas'],
#  ['Independence', 'Arkansas'],
#  ['Izard', 'Arkansas'],
#  ['Jackson', 'Arkansas'],
#  ['Jefferson', 'Arkansas'],
#  ['Johnson', 'Arkansas'],
#  ['Lafayette', 'Arkansas'],
#  ['Lawrence', 'Arkansas'],
#  ['Lee', 'Arkansas'],
#  ['Lincoln', 'Arkansas'],
#  ['Little River', 'Arkansas'],
#  ['Logan', 'Arkansas'],
#  ['Lonoke', 'Arkansas'],
#  ['Madison', 'Arkansas'],
#  ['Marion', 'Arkansas'],
#  ['Miller', 'Arkansas'],
#  ['Mississippi', 'Arkansas'],
#  ['Monroe', 'Arkansas'],
#  ['Montgomery', 'Arkansas'],
#  ['Nevada', 'Arkansas'],
#  ['Newton', 'Arkansas'],
#  ['Ouachita', 'Arkansas'],
#  ['Perry', 'Arkansas'],
#  ['Phillips', 'Arkansas'],
#  ['Pike', 'Arkansas'],
#  ['Poinsett', 'Arkansas'],
#  ['Polk', 'Arkansas'],
#  ['Pope', 'Arkansas'],
#  ['Prairie', 'Arkansas'],
#  ['Pulaski', 'Arkansas'],
#  ['Randolph', 'Arkansas'],
#  ['Saline', 'Arkansas'],
#  ['Scott', 'Arkansas'],
#  ['Searcy', 'Arkansas'],
#  ['Sebastian', 'Arkansas'],
#  ['Sevier', 'Arkansas'],
#  ['Sharp', 'Arkansas'],
#  ['St. Francis', 'Arkansas'],
#  ['Stone', 'Arkansas'],
#  ['Union', 'Arkansas'],
#  ['Van Buren', 'Arkansas'],
#  ['Washington', 'Arkansas'],
#  ['White', 'Arkansas'],
#  ['Woodruff', 'Arkansas'],
#  ['Yell', 'Arkansas'],
#  ['Alameda', 'California'],
#  ['Alpine', 'California'],
#  ['Amador', 'California'],
#  ['Butte', 'California'],
#  ['Calaveras', 'California'],
#  ['Colusa', 'California'],
#  ['Contra Costa', 'California'],
#  ['Del Norte', 'California'],
#  ['El Dorado', 'California'],
#  ['Fresno', 'California'],
#  ['Glenn', 'California'],
#  ['Humboldt', 'California'],
#  ['Imperial', 'California'],
#  ['Inyo', 'California'],
#  ['Kern', 'California'],
#  ['Kings', 'California'],
#  ['Lake', 'California'],
#  ['Lassen', 'California'],
#  ['Los Angeles', 'California'],
#  ['Madera', 'California'],
#  ['Marin', 'California'],
#  ['Mariposa', 'California'],
#  ['Mendocino', 'California'],
#  ['Merced', 'California'],
#  ['Modoc', 'California'],
#  ['Mono', 'California'],
#  ['Monterey', 'California'],
#  ['Napa', 'California'],
#  ['Nevada', 'California'],
#  ['Orange', 'California'],
#  ['Placer', 'California'],
#  ['Plumas', 'California'],
#  ['Riverside', 'California'],
#  ['Sacramento', 'California'],
#  ['San Benito', 'California'],
#  ['San Bernardino', 'California'],
#  ['San Diego', 'California'],
#  ['San Francisco', 'California'],
#  ['San Joaquin', 'California'],
#  ['San Luis Obispo', 'California'],
#  ['San Mateo', 'California'],
#  ['Santa Barbara', 'California'],
#  ['Santa Clara', 'California'],
#  ['Santa Cruz', 'California'],
#  ['Shasta', 'California'],
#  ['Sierra', 'California'],
#  ['Siskiyou', 'California'],
#  ['Solano', 'California'],
#  ['Sonoma', 'California'],
#  ['Stanislaus', 'California'],
#  ['Sutter', 'California'],
#  ['Tehama', 'California'],
#  ['Trinity', 'California'],
#  ['Tulare', 'California'],
#  ['Tuolumne', 'California'],
#  ['Ventura', 'California'],
#  ['Yolo', 'California'],
#  ['Yuba', 'California'],
#  ['Adams', 'Colorado'],
#  ['Alamosa', 'Colorado'],
#  ['Arapahoe', 'Colorado'],
#  ['Archuleta', 'Colorado'],
#  ['Baca', 'Colorado'],
#  ['Bent', 'Colorado'],
#  ['Boulder', 'Colorado'],
#  ['Broomfield', 'Colorado'],
#  ['Chaffee', 'Colorado'],
#  ['Cheyenne', 'Colorado'],
#  ['Clear Creek', 'Colorado'],
#  ['Conejos', 'Colorado'],
#  ['Costilla', 'Colorado'],
#  ['Crowley', 'Colorado'],
#  ['Custer', 'Colorado'],
#  ['Delta', 'Colorado'],
#  ['Denver', 'Colorado'],
#  ['Dolores', 'Colorado'],
#  ['Douglas', 'Colorado'],
#  ['Eagle', 'Colorado'],
#  ['El Paso', 'Colorado'],
#  ['Elbert', 'Colorado'],
#  ['Fremont', 'Colorado'],
#  ['Garfield', 'Colorado'],
#  ['Gilpin', 'Colorado'],
#  ['Grand', 'Colorado'],
#  ['Gunnison', 'Colorado'],
#  ['Hinsdale', 'Colorado'],
#  ['Huerfano', 'Colorado'],
#  ['Jackson', 'Colorado'],
#  ['Jefferson', 'Colorado'],
#  ['Kiowa', 'Colorado'],
#  ['Kit Carson', 'Colorado'],
#  ['La Plata', 'Colorado'],
#  ['Lake', 'Colorado'],
#  ['Larimer', 'Colorado'],
#  ['Las Animas', 'Colorado'],
#  ['Lincoln', 'Colorado'],
#  ['Logan', 'Colorado'],
#  ['Mesa', 'Colorado'],
#  ['Mineral', 'Colorado'],
#  ['Moffat', 'Colorado'],
#  ['Montezuma', 'Colorado'],
#  ['Montrose', 'Colorado'],
#  ['Morgan', 'Colorado'],
#  ['Otero', 'Colorado'],
#  ['Ouray', 'Colorado'],
#  ['Park', 'Colorado'],
#  ['Phillips', 'Colorado'],
#  ['Pitkin', 'Colorado'],
#  ['Prowers', 'Colorado'],
#  ['Pueblo', 'Colorado'],
#  ['Rio Blanco', 'Colorado'],
#  ['Rio Grande', 'Colorado'],
#  ['Routt', 'Colorado'],
#  ['Saguache', 'Colorado'],
#  ['San Juan', 'Colorado'],
#  ['San Miguel', 'Colorado'],
#  ['Sedgwick', 'Colorado'],
#  ['Summit', 'Colorado'],
#  ['Teller', 'Colorado'],
#  ['Washington', 'Colorado'],
#  ['Weld', 'Colorado'],
#  ['Yuma', 'Colorado'],
#  ['Fairfield', 'Connecticut'],
#  ['Hartford', 'Connecticut'],
#  ['Litchfield', 'Connecticut'],
#  ['Middlesex', 'Connecticut'],
#  ['New Haven', 'Connecticut'],
#  ['New London', 'Connecticut'],
#  ['Tolland', 'Connecticut'],
#  ['Windham', 'Connecticut'],
#  ['Kent', 'Delaware'],
#  ['New Castle', 'Delaware'],
#  ['Sussex', 'Delaware'],
#  ['District of Columbia', 'District of Columbia'],
#  ['Alachua', 'Florida'],
#  ['Baker', 'Florida'],
#  ['Bay', 'Florida'],
#  ['Bradford', 'Florida'],
#  ['Brevard', 'Florida'],
#  ['Broward', 'Florida'],
#  ['Calhoun', 'Florida'],
#  ['Charlotte', 'Florida'],
#  ['Citrus', 'Florida'],
#  ['Clay', 'Florida'],
#  ['Collier', 'Florida'],
#  ['Columbia', 'Florida'],
#  ['DeSoto', 'Florida'],
#  ['Dixie', 'Florida'],
#  ['Duval', 'Florida'],
#  ['Escambia', 'Florida'],
#  ['Flagler', 'Florida'],
#  ['Franklin', 'Florida'],
#  ['Gadsden', 'Florida'],
#  ['Gilchrist', 'Florida'],
#  ['Glades', 'Florida'],
#  ['Gulf', 'Florida'],
#  ['Hamilton', 'Florida'],
#  ['Hardee', 'Florida'],
#  ['Hendry', 'Florida'],
#  ['Hernando', 'Florida'],
#  ['Highlands', 'Florida'],
#  ['Hillsborough', 'Florida'],
#  ['Holmes', 'Florida'],
#  ['Indian River', 'Florida'],
#  ['Jackson', 'Florida'],
#  ['Jefferson', 'Florida'],
#  ['Lafayette', 'Florida'],
#  ['Lake', 'Florida'],
#  ['Lee', 'Florida'],
#  ['Leon', 'Florida'],
#  ['Levy', 'Florida'],
#  ['Liberty', 'Florida'],
#  ['Madison', 'Florida'],
#  ['Manatee', 'Florida'],
#  ['Marion', 'Florida'],
#  ['Martin', 'Florida'],
#  ['Miami-Dade', 'Florida'],
#  ['Monroe', 'Florida'],
#  ['Nassau', 'Florida'],
#  ['Okaloosa', 'Florida'],
#  ['Okeechobee', 'Florida'],
#  ['Orange', 'Florida'],
#  ['Osceola', 'Florida'],
#  ['Palm Beach', 'Florida'],
#  ['Pasco', 'Florida'],
#  ['Pinellas', 'Florida'],
#  ['Polk', 'Florida'],
#  ['Putnam', 'Florida'],
#  ['Santa Rosa', 'Florida'],
#  ['Sarasota', 'Florida'],
#  ['Seminole', 'Florida'],
#  ['St. Johns', 'Florida'],
#  ['St. Lucie', 'Florida'],
#  ['Sumter', 'Florida'],
#  ['Suwannee', 'Florida'],
#  ['Taylor', 'Florida'],
#  ['Union', 'Florida'],
#  ['Volusia', 'Florida'],
#  ['Wakulla', 'Florida'],
#  ['Walton', 'Florida'],
#  ['Washington', 'Florida'],
#  ['Appling', 'Georgia'],
#  ['Atkinson', 'Georgia'],
#  ['Bacon', 'Georgia'],
#  ['Baker', 'Georgia'],
#  ['Baldwin', 'Georgia'],
#  ['Banks', 'Georgia'],
#  ['Barrow', 'Georgia'],
#  ['Bartow', 'Georgia'],
#  ['Ben Hill', 'Georgia'],
#  ['Berrien', 'Georgia'],
#  ['Bibb', 'Georgia'],
#  ['Bleckley', 'Georgia'],
#  ['Brantley', 'Georgia'],
#  ['Brooks', 'Georgia'],
#  ['Bryan', 'Georgia'],
#  ['Bulloch', 'Georgia'],
#  ['Burke', 'Georgia'],
#  ['Butts', 'Georgia'],
#  ['Calhoun', 'Georgia'],
#  ['Camden', 'Georgia'],
#  ['Candler', 'Georgia'],
#  ['Carroll', 'Georgia'],
#  ['Catoosa', 'Georgia'],
#  ['Charlton', 'Georgia'],
#  ['Chatham', 'Georgia'],
#  ['Chattahoochee', 'Georgia'],
#  ['Chattooga', 'Georgia'],
#  ['Cherokee', 'Georgia'],
#  ['Clarke', 'Georgia'],
#  ['Clay', 'Georgia'],
#  ['Clayton', 'Georgia'],
#  ['Clinch', 'Georgia'],
#  ['Cobb', 'Georgia'],
#  ['Coffee', 'Georgia'],
#  ['Colquitt', 'Georgia'],
#  ['Columbia', 'Georgia'],
#  ['Cook', 'Georgia'],
#  ['Coweta', 'Georgia'],
#  ['Crawford', 'Georgia'],
#  ['Crisp', 'Georgia'],
#  ['Dade', 'Georgia'],
#  ['Dawson', 'Georgia'],
#  ['DeKalb', 'Georgia'],
#  ['Decatur', 'Georgia'],
#  ['Dodge', 'Georgia'],
#  ['Dooly', 'Georgia'],
#  ['Dougherty', 'Georgia'],
#  ['Douglas', 'Georgia'],
#  ['Early', 'Georgia'],
#  ['Echols', 'Georgia'],
#  ['Effingham', 'Georgia'],
#  ['Elbert', 'Georgia'],
#  ['Emanuel', 'Georgia'],
#  ['Evans', 'Georgia'],
#  ['Fannin', 'Georgia'],
#  ['Fayette', 'Georgia'],
#  ['Floyd', 'Georgia'],
#  ['Forsyth', 'Georgia'],
#  ['Franklin', 'Georgia'],
#  ['Fulton', 'Georgia'],
#  ['Gilmer', 'Georgia'],
#  ['Glascock', 'Georgia'],
#  ['Glynn', 'Georgia'],
#  ['Gordon', 'Georgia'],
#  ['Grady', 'Georgia'],
#  ['Greene', 'Georgia'],
#  ['Gwinnett', 'Georgia'],
#  ['Habersham', 'Georgia'],
#  ['Hall', 'Georgia'],
#  ['Hancock', 'Georgia'],
#  ['Haralson', 'Georgia'],
#  ['Harris', 'Georgia'],
#  ['Hart', 'Georgia'],
#  ['Heard', 'Georgia'],
#  ['Henry', 'Georgia'],
#  ['Houston', 'Georgia'],
#  ['Irwin', 'Georgia'],
#  ['Jackson', 'Georgia'],
#  ['Jasper', 'Georgia'],
#  ['Jeff Davis', 'Georgia'],
#  ['Jefferson', 'Georgia'],
#  ['Jenkins', 'Georgia'],
#  ['Johnson', 'Georgia'],
#  ['Jones', 'Georgia'],
#  ['Lamar', 'Georgia'],
#  ['Lanier', 'Georgia'],
#  ['Laurens', 'Georgia'],
#  ['Lee', 'Georgia'],
#  ['Liberty', 'Georgia'],
#  ['Lincoln', 'Georgia'],
#  ['Long', 'Georgia'],
#  ['Lowndes', 'Georgia'],
#  ['Lumpkin', 'Georgia'],
#  ['Macon', 'Georgia'],
#  ['Madison', 'Georgia'],
#  ['Marion', 'Georgia'],
#  ['McDuffie', 'Georgia'],
#  ['McIntosh', 'Georgia'],
#  ['Meriwether', 'Georgia'],
#  ['Miller', 'Georgia'],
#  ['Mitchell', 'Georgia'],
#  ['Monroe', 'Georgia'],
#  ['Montgomery', 'Georgia'],
#  ['Morgan', 'Georgia'],
#  ['Murray', 'Georgia'],
#  ['Muscogee', 'Georgia'],
#  ['Newton', 'Georgia'],
#  ['Oconee', 'Georgia'],
#  ['Oglethorpe', 'Georgia'],
#  ['Paulding', 'Georgia'],
#  ['Peach', 'Georgia'],
#  ['Pickens', 'Georgia'],
#  ['Pierce', 'Georgia'],
#  ['Pike', 'Georgia'],
#  ['Polk', 'Georgia'],
#  ['Pulaski', 'Georgia'],
#  ['Putnam', 'Georgia'],
#  ['Quitman', 'Georgia'],
#  ['Rabun', 'Georgia'],
#  ['Randolph', 'Georgia'],
#  ['Richmond', 'Georgia'],
#  ['Rockdale', 'Georgia'],
#  ['Schley', 'Georgia'],
#  ['Screven', 'Georgia'],
#  ['Seminole', 'Georgia'],
#  ['Spalding', 'Georgia'],
#  ['Stephens', 'Georgia'],
#  ['Stewart', 'Georgia'],
#  ['Sumter', 'Georgia'],
#  ['Talbot', 'Georgia'],
#  ['Taliaferro', 'Georgia'],
#  ['Tattnall', 'Georgia'],
#  ['Taylor', 'Georgia'],
#  ['Telfair', 'Georgia'],
#  ['Terrell', 'Georgia'],
#  ['Thomas', 'Georgia'],
#  ['Tift', 'Georgia'],
#  ['Toombs', 'Georgia'],
#  ['Towns', 'Georgia'],
#  ['Treutlen', 'Georgia'],
#  ['Troup', 'Georgia'],
#  ['Turner', 'Georgia'],
#  ['Twiggs', 'Georgia'],
#  ['Union', 'Georgia'],
#  ['Upson', 'Georgia'],
#  ['Walker', 'Georgia'],
#  ['Walton', 'Georgia'],
#  ['Ware', 'Georgia'],
#  ['Warren', 'Georgia'],
#  ['Washington', 'Georgia'],
#  ['Wayne', 'Georgia'],
#  ['Webster', 'Georgia'],
#  ['Wheeler', 'Georgia'],
#  ['White', 'Georgia'],
#  ['Whitfield', 'Georgia'],
#  ['Wilcox', 'Georgia'],
#  ['Wilkes', 'Georgia'],
#  ['Wilkinson', 'Georgia'],
#  ['Worth', 'Georgia'],
#  ['Hawaii', 'Hawaii'],
#  ['Honolulu', 'Hawaii'],
#  ['Kalawao', 'Hawaii'],
#  ['Kauai', 'Hawaii'],
#  ['Maui', 'Hawaii'],
#  ['Ada', 'Idaho'],
#  ['Adams', 'Idaho'],
#  ['Bannock', 'Idaho'],
#  ['Bear Lake', 'Idaho'],
#  ['Benewah', 'Idaho'],
#  ['Bingham', 'Idaho'],
#  ['Blaine', 'Idaho'],
#  ['Boise', 'Idaho'],
#  ['Bonner', 'Idaho'],
#  ['Bonneville', 'Idaho'],
#  ['Boundary', 'Idaho'],
#  ['Butte', 'Idaho'],
#  ['Camas', 'Idaho'],
#  ['Canyon', 'Idaho'],
#  ['Caribou', 'Idaho'],
#  ['Cassia', 'Idaho'],
#  ['Clark', 'Idaho'],
#  ['Clearwater', 'Idaho'],
#  ['Custer', 'Idaho'],
#  ['Elmore', 'Idaho'],
#  ['Franklin', 'Idaho'],
#  ['Fremont', 'Idaho'],
#  ['Gem', 'Idaho'],
#  ['Gooding', 'Idaho'],
#  ['Idaho', 'Idaho'],
#  ['Jefferson', 'Idaho'],
#  ['Jerome', 'Idaho'],
#  ['Kootenai', 'Idaho'],
#  ['Latah', 'Idaho'],
#  ['Lemhi', 'Idaho'],
#  ['Lewis', 'Idaho'],
#  ['Lincoln', 'Idaho'],
#  ['Madison', 'Idaho'],
#  ['Minidoka', 'Idaho'],
#  ['Nez Perce', 'Idaho'],
#  ['Oneida', 'Idaho'],
#  ['Owyhee', 'Idaho'],
#  ['Payette', 'Idaho'],
#  ['Power', 'Idaho'],
#  ['Shoshone', 'Idaho'],
#  ['Teton', 'Idaho'],
#  ['Twin Falls', 'Idaho'],
#  ['Valley', 'Idaho'],
#  ['Washington', 'Idaho'],
#  ['Adams', 'Illinois'],
#  ['Alexander', 'Illinois'],
#  ['Bond', 'Illinois'],
#  ['Boone', 'Illinois'],
#  ['Brown', 'Illinois'],
#  ['Bureau', 'Illinois'],
#  ['Calhoun', 'Illinois'],
#  ['Carroll', 'Illinois'],
#  ['Cass', 'Illinois'],
#  ['Champaign', 'Illinois'],
#  ['Christian', 'Illinois'],
#  ['Clark', 'Illinois'],
#  ['Clay', 'Illinois'],
#  ['Clinton', 'Illinois'],
#  ['Coles', 'Illinois'],
#  ['Cook', 'Illinois'],
#  ['Crawford', 'Illinois'],
#  ['Cumberland', 'Illinois'],
#  ['De Witt', 'Illinois'],
#  ['DeKalb', 'Illinois'],
#  ['Douglas', 'Illinois'],
#  ['DuPage', 'Illinois'],
#  ['Edgar', 'Illinois'],
#  ['Edwards', 'Illinois'],
#  ['Effingham', 'Illinois'],
#  ['Fayette', 'Illinois'],
#  ['Ford', 'Illinois'],
#  ['Franklin', 'Illinois'],
#  ['Fulton', 'Illinois'],
#  ['Gallatin', 'Illinois'],
#  ['Greene', 'Illinois'],
#  ['Grundy', 'Illinois'],
#  ['Hamilton', 'Illinois'],
#  ['Hancock', 'Illinois'],
#  ['Hardin', 'Illinois'],
#  ['Henderson', 'Illinois'],
#  ['Henry', 'Illinois'],
#  ['Iroquois', 'Illinois'],
#  ['Jackson', 'Illinois'],
#  ['Jasper', 'Illinois'],
#  ['Jefferson', 'Illinois'],
#  ['Jersey', 'Illinois'],
#  ['Jo Daviess', 'Illinois'],
#  ['Johnson', 'Illinois'],
#  ['Kane', 'Illinois'],
#  ['Kankakee', 'Illinois'],
#  ['Kendall', 'Illinois'],
#  ['Knox', 'Illinois'],
#  ['LaSalle', 'Illinois'],
#  ['Lake', 'Illinois'],
#  ['Lawrence', 'Illinois'],
#  ['Lee', 'Illinois'],
#  ['Livingston', 'Illinois'],
#  ['Logan', 'Illinois'],
#  ['Macon', 'Illinois'],
#  ['Macoupin', 'Illinois'],
#  ['Madison', 'Illinois'],
#  ['Marion', 'Illinois'],
#  ['Marshall', 'Illinois'],
#  ['Mason', 'Illinois'],
#  ['Massac', 'Illinois'],
#  ['McDonough', 'Illinois'],
#  ['McHenry', 'Illinois'],
#  ['McLean', 'Illinois'],
#  ['Menard', 'Illinois'],
#  ['Mercer', 'Illinois'],
#  ['Monroe', 'Illinois'],
#  ['Montgomery', 'Illinois'],
#  ['Morgan', 'Illinois'],
#  ['Moultrie', 'Illinois'],
#  ['Ogle', 'Illinois'],
#  ['Peoria', 'Illinois'],
#  ['Perry', 'Illinois'],
#  ['Piatt', 'Illinois'],
#  ['Pike', 'Illinois'],
#  ['Pope', 'Illinois'],
#  ['Pulaski', 'Illinois'],
#  ['Putnam', 'Illinois'],
#  ['Randolph', 'Illinois'],
#  ['Richland', 'Illinois'],
#  ['Rock Island', 'Illinois'],
#  ['Saline', 'Illinois'],
#  ['Sangamon', 'Illinois'],
#  ['Schuyler', 'Illinois'],
#  ['Scott', 'Illinois'],
#  ['Shelby', 'Illinois'],
#  ['St. Clair', 'Illinois'],
#  ['Stark', 'Illinois'],
#  ['Stephenson', 'Illinois'],
#  ['Tazewell', 'Illinois'],
#  ['Union', 'Illinois'],
#  ['Vermilion', 'Illinois'],
#  ['Wabash', 'Illinois'],
#  ['Warren', 'Illinois'],
#  ['Washington', 'Illinois'],
#  ['Wayne', 'Illinois'],
#  ['White', 'Illinois'],
#  ['Whiteside', 'Illinois'],
#  ['Will', 'Illinois'],
#  ['Williamson', 'Illinois'],
#  ['Winnebago', 'Illinois'],
#  ['Woodford', 'Illinois'],
#  ['Adams', 'Indiana'],
#  ['Allen', 'Indiana'],
#  ['Bartholomew', 'Indiana'],
#  ['Benton', 'Indiana'],
#  ['Blackford', 'Indiana'],
#  ['Boone', 'Indiana'],
#  ['Brown', 'Indiana'],
#  ['Carroll', 'Indiana'],
#  ['Cass', 'Indiana'],
#  ['Clark', 'Indiana'],
#  ['Clay', 'Indiana'],
#  ['Clinton', 'Indiana'],
#  ['Crawford', 'Indiana'],
#  ['Daviess', 'Indiana'],
#  ['DeKalb', 'Indiana'],
#  ['Dearborn', 'Indiana'],
#  ['Decatur', 'Indiana'],
#  ['Delaware', 'Indiana'],
#  ['Dubois', 'Indiana'],
#  ['Elkhart', 'Indiana'],
#  ['Fayette', 'Indiana'],
#  ['Floyd', 'Indiana'],
#  ['Fountain', 'Indiana'],
#  ['Franklin', 'Indiana'],
#  ['Fulton', 'Indiana'],
#  ['Gibson', 'Indiana'],
#  ['Grant', 'Indiana'],
#  ['Greene', 'Indiana'],
#  ['Hamilton', 'Indiana'],
#  ['Hancock', 'Indiana'],
#  ['Harrison', 'Indiana'],
#  ['Hendricks', 'Indiana'],
#  ['Henry', 'Indiana'],
#  ['Howard', 'Indiana'],
#  ['Huntington', 'Indiana'],
#  ['Jackson', 'Indiana'],
#  ['Jasper', 'Indiana'],
#  ['Jay', 'Indiana'],
#  ['Jefferson', 'Indiana'],
#  ['Jennings', 'Indiana'],
#  ['Johnson', 'Indiana'],
#  ['Knox', 'Indiana'],
#  ['Kosciusko', 'Indiana'],
#  ['LaGrange', 'Indiana'],
#  ['LaPorte', 'Indiana'],
#  ['Lake', 'Indiana'],
#  ['Lawrence', 'Indiana'],
#  ['Madison', 'Indiana'],
#  ['Marion', 'Indiana'],
#  ['Marshall', 'Indiana'],
#  ['Martin', 'Indiana'],
#  ['Miami', 'Indiana'],
#  ['Monroe', 'Indiana'],
#  ['Montgomery', 'Indiana'],
#  ['Morgan', 'Indiana'],
#  ['Newton', 'Indiana'],
#  ['Noble', 'Indiana'],
#  ['Ohio', 'Indiana'],
#  ['Orange', 'Indiana'],
#  ['Owen', 'Indiana'],
#  ['Parke', 'Indiana'],
#  ['Perry', 'Indiana'],
#  ['Pike', 'Indiana'],
#  ['Porter', 'Indiana'],
#  ['Posey', 'Indiana'],
#  ['Pulaski', 'Indiana'],
#  ['Putnam', 'Indiana'],
#  ['Randolph', 'Indiana'],
#  ['Ripley', 'Indiana'],
#  ['Rush', 'Indiana'],
#  ['Scott', 'Indiana'],
#  ['Shelby', 'Indiana'],
#  ['Spencer', 'Indiana'],
#  ['St. Joseph', 'Indiana'],
#  ['Starke', 'Indiana'],
#  ['Steuben', 'Indiana'],
#  ['Sullivan', 'Indiana'],
#  ['Switzerland', 'Indiana'],
#  ['Tippecanoe', 'Indiana'],
#  ['Tipton', 'Indiana'],
#  ['Union', 'Indiana'],
#  ['Vanderburgh', 'Indiana'],
#  ['Vermillion', 'Indiana'],
#  ['Vigo', 'Indiana'],
#  ['Wabash', 'Indiana'],
#  ['Warren', 'Indiana'],
#  ['Warrick', 'Indiana'],
#  ['Washington', 'Indiana'],
#  ['Wayne', 'Indiana'],
#  ['Wells', 'Indiana'],
#  ['White', 'Indiana'],
#  ['Whitley', 'Indiana'],
#  ['Adair', 'Iowa'],
#  ['Adams', 'Iowa'],
#  ['Allamakee', 'Iowa'],
#  ['Appanoose', 'Iowa'],
#  ['Audubon', 'Iowa'],
#  ['Benton', 'Iowa'],
#  ['Black Hawk', 'Iowa'],
#  ['Boone', 'Iowa'],
#  ['Bremer', 'Iowa'],
#  ['Buchanan', 'Iowa'],
#  ['Buena Vista', 'Iowa'],
#  ['Butler', 'Iowa'],
#  ['Calhoun', 'Iowa'],
#  ['Carroll', 'Iowa'],
#  ['Cass', 'Iowa'],
#  ['Cedar', 'Iowa'],
#  ['Cerro Gordo', 'Iowa'],
#  ['Cherokee', 'Iowa'],
#  ['Chickasaw', 'Iowa'],
#  ['Clarke', 'Iowa'],
#  ['Clay', 'Iowa'],
#  ['Clayton', 'Iowa'],
#  ['Clinton', 'Iowa'],
#  ['Crawford', 'Iowa'],
#  ['Dallas', 'Iowa'],
#  ['Davis', 'Iowa'],
#  ['Decatur', 'Iowa'],
#  ['Delaware', 'Iowa'],
#  ['Des Moines', 'Iowa'],
#  ['Dickinson', 'Iowa'],
#  ['Dubuque', 'Iowa'],
#  ['Emmet', 'Iowa'],
#  ['Fayette', 'Iowa'],
#  ['Floyd', 'Iowa'],
#  ['Franklin', 'Iowa'],
#  ['Fremont', 'Iowa'],
#  ['Greene', 'Iowa'],
#  ['Grundy', 'Iowa'],
#  ['Guthrie', 'Iowa'],
#  ['Hamilton', 'Iowa'],
#  ['Hancock', 'Iowa'],
#  ['Hardin', 'Iowa'],
#  ['Harrison', 'Iowa'],
#  ['Henry', 'Iowa'],
#  ['Howard', 'Iowa'],
#  ['Humboldt', 'Iowa'],
#  ['Ida', 'Iowa'],
#  ['Iowa', 'Iowa'],
#  ['Jackson', 'Iowa'],
#  ['Jasper', 'Iowa'],
#  ['Jefferson', 'Iowa'],
#  ['Johnson', 'Iowa'],
#  ['Jones', 'Iowa'],
#  ['Keokuk', 'Iowa'],
#  ['Kossuth', 'Iowa'],
#  ['Lee', 'Iowa'],
#  ['Linn', 'Iowa'],
#  ['Louisa', 'Iowa'],
#  ['Lucas', 'Iowa'],
#  ['Lyon', 'Iowa'],
#  ['Madison', 'Iowa'],
#  ['Mahaska', 'Iowa'],
#  ['Marion', 'Iowa'],
#  ['Marshall', 'Iowa'],
#  ['Mills', 'Iowa'],
#  ['Mitchell', 'Iowa'],
#  ['Monona', 'Iowa'],
#  ['Monroe', 'Iowa'],
#  ['Montgomery', 'Iowa'],
#  ['Muscatine', 'Iowa'],
#  ["O'Brien", 'Iowa'],
#  ['Osceola', 'Iowa'],
#  ['Page', 'Iowa'],
#  ['Palo Alto', 'Iowa'],
#  ['Plymouth', 'Iowa'],
#  ['Pocahontas', 'Iowa'],
#  ['Polk', 'Iowa'],
#  ['Pottawattamie', 'Iowa'],
#  ['Poweshiek', 'Iowa'],
#  ['Ringgold', 'Iowa'],
#  ['Sac', 'Iowa'],
#  ['Scott', 'Iowa'],
#  ['Shelby', 'Iowa'],
#  ['Sioux', 'Iowa'],
#  ['Story', 'Iowa'],
#  ['Tama', 'Iowa'],
#  ['Taylor', 'Iowa'],
#  ['Union', 'Iowa'],
#  ['Van Buren', 'Iowa'],
#  ['Wapello', 'Iowa'],
#  ['Warren', 'Iowa'],
#  ['Washington', 'Iowa'],
#  ['Wayne', 'Iowa'],
#  ['Webster', 'Iowa'],
#  ['Winnebago', 'Iowa'],
#  ['Winneshiek', 'Iowa'],
#  ['Woodbury', 'Iowa'],
#  ['Worth', 'Iowa'],
#  ['Wright', 'Iowa'],
#  ['Allen', 'Kansas'],
#  ['Anderson', 'Kansas'],
#  ['Atchison', 'Kansas'],
#  ['Barber', 'Kansas'],
#  ['Barton', 'Kansas'],
#  ['Bourbon', 'Kansas'],
#  ['Brown', 'Kansas'],
#  ['Butler', 'Kansas'],
#  ['Chase', 'Kansas'],
#  ['Chautauqua', 'Kansas'],
#  ['Cherokee', 'Kansas'],
#  ['Cheyenne', 'Kansas'],
#  ['Clark', 'Kansas'],
#  ['Clay', 'Kansas'],
#  ['Cloud', 'Kansas'],
#  ['Coffey', 'Kansas'],
#  ['Comanche', 'Kansas'],
#  ['Cowley', 'Kansas'],
#  ['Crawford', 'Kansas'],
#  ['Decatur', 'Kansas'],
#  ['Dickinson', 'Kansas'],
#  ['Doniphan', 'Kansas'],
#  ['Douglas', 'Kansas'],
#  ['Edwards', 'Kansas'],
#  ['Elk', 'Kansas'],
#  ['Ellis', 'Kansas'],
#  ['Ellsworth', 'Kansas'],
#  ['Finney', 'Kansas'],
#  ['Ford', 'Kansas'],
#  ['Franklin', 'Kansas'],
#  ['Geary', 'Kansas'],
#  ['Gove', 'Kansas'],
#  ['Graham', 'Kansas'],
#  ['Grant', 'Kansas'],
#  ['Gray', 'Kansas'],
#  ['Greeley', 'Kansas'],
#  ['Greenwood', 'Kansas'],
#  ['Hamilton', 'Kansas'],
#  ['Harper', 'Kansas'],
#  ['Harvey', 'Kansas'],
#  ['Haskell', 'Kansas'],
#  ['Hodgeman', 'Kansas'],
#  ['Jackson', 'Kansas'],
#  ['Jefferson', 'Kansas'],
#  ['Jewell', 'Kansas'],
#  ['Johnson', 'Kansas'],
#  ['Kearny', 'Kansas'],
#  ['Kingman', 'Kansas'],
#  ['Kiowa', 'Kansas'],
#  ['Labette', 'Kansas'],
#  ['Lane', 'Kansas'],
#  ['Leavenworth', 'Kansas'],
#  ['Lincoln', 'Kansas'],
#  ['Linn', 'Kansas'],
#  ['Logan', 'Kansas'],
#  ['Lyon', 'Kansas'],
#  ['Marion', 'Kansas'],
#  ['Marshall', 'Kansas'],
#  ['McPherson', 'Kansas'],
#  ['Meade', 'Kansas'],
#  ['Miami', 'Kansas'],
#  ['Mitchell', 'Kansas'],
#  ['Montgomery', 'Kansas'],
#  ['Morris', 'Kansas'],
#  ['Morton', 'Kansas'],
#  ['Nemaha', 'Kansas'],
#  ['Neosho', 'Kansas'],
#  ['Ness', 'Kansas'],
#  ['Norton', 'Kansas'],
#  ['Osage', 'Kansas'],
#  ['Osborne', 'Kansas'],
#  ['Ottawa', 'Kansas'],
#  ['Pawnee', 'Kansas'],
#  ['Phillips', 'Kansas'],
#  ['Pottawatomie', 'Kansas'],
#  ['Pratt', 'Kansas'],
#  ['Rawlins', 'Kansas'],
#  ['Reno', 'Kansas'],
#  ['Republic', 'Kansas'],
#  ['Rice', 'Kansas'],
#  ['Riley', 'Kansas'],
#  ['Rooks', 'Kansas'],
#  ['Rush', 'Kansas'],
#  ['Russell', 'Kansas'],
#  ['Saline', 'Kansas'],
#  ['Scott', 'Kansas'],
#  ['Sedgwick', 'Kansas'],
#  ['Seward', 'Kansas'],
#  ['Shawnee', 'Kansas'],
#  ['Sheridan', 'Kansas'],
#  ['Sherman', 'Kansas'],
#  ['Smith', 'Kansas'],
#  ['Stafford', 'Kansas'],
#  ['Stanton', 'Kansas'],
#  ['Stevens', 'Kansas'],
#  ['Sumner', 'Kansas'],
#  ['Thomas', 'Kansas'],
#  ['Trego', 'Kansas'],
#  ['Wabaunsee', 'Kansas'],
#  ['Wallace', 'Kansas'],
#  ['Washington', 'Kansas'],
#  ['Wichita', 'Kansas'],
#  ['Wilson', 'Kansas'],
#  ['Woodson', 'Kansas'],
#  ['Wyandotte', 'Kansas'],
#  ['Adair', 'Kentucky'],
#  ['Allen', 'Kentucky'],
#  ['Anderson', 'Kentucky'],
#  ['Ballard', 'Kentucky'],
#  ['Barren', 'Kentucky'],
#  ['Bath', 'Kentucky'],
#  ['Bell', 'Kentucky'],
#  ...]

# %%
county_state[0]
# Out:
# ['Autauga', 'Alabama']

# %%
states = sorted(list(set([cs[1] for cs in county_state])))
states
# Out:
# ['Alabama',
#  'Alaska',
#  'Arizona',
#  'Arkansas',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'Delaware',
#  'District of Columbia',
#  'Florida',
#  'Georgia',
#  'Hawaii',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Kansas',
#  'Kentucky',
#  'Louisiana',
#  'Maine',
#  'Maryland',
#  'Massachusetts',
#  'Michigan',
#  'Minnesota',
#  'Mississippi',
#  'Missouri',
#  'Montana',
#  'Nebraska',
#  'Nevada',
#  'New Hampshire',
#  'New Jersey',
#  'New Mexico',
#  'New York',
#  'North Carolina',
#  'North Dakota',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Rhode Island',
#  'South Carolina',
#  'South Dakota',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'Vermont',
#  'Virginia',
#  'Washington',
#  'West Virginia',
#  'Wisconsin',
#  'Wyoming']

# %%
len(states)
# Out:
# 51

# %%
len(State.query.all())
# Out:
# 0

# %%
for state in states:
    state_in = State(name=state)
    db.session.add(state_in)
    
db.session.commit()

# %%
alabama = State.query.first()
alabama.counties
alabama

# %%
db_states = State.query.all()

for state in db_states:
    print(state.id, state.name)

# %%
db_states[0].counties

# %%
for cs in county_state:
    state = State.query.filter_by(name=cs[1]).first()
    county_in = County(county_name=cs[0], county_state=state)
    db.session.add(county_in)

db.session.commit()

# %%
len(County.query.all())
# Out:
# 3142

# %%
for county in alabama.counties:
    print(county.county_name, alabama.name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-23206b9364b3> in <module>
# ----> 1 for county in alabama.counties:
#       2     print(county.county_name, alabama.name)
#
# NameError: name 'alabama' is not defined

# %%
autauga = County.query.first()
dir(autauga)

# %%
autauga.county_state.name

# %%
db_counties = County.query.all()

for county in db_counties:
    print(county.id, county.county_name, county.county_state.name)

# %%
for season in ['Winter', 'Spring', 'Summer', 'Fall']:
    seas_in = Season(name=season)
    db.session.add(seas_in)

db.session.commit()

# %%
[season.name for season in Season.query.all()]

# %%
codir(db.session)

# %%
help(db.session.rollback)

# %%
Region.__table__

# %%
# use the keys to find county id
# input region with region as value in dict and region_county as county id

for cs in cs2r:
    county, state = tuple(cs.split(','))
    state_id = State.query.filter_by(name=state).first()
    county_id = County.query.filter_by(county_name=county, county_state=state_id).first()
    reg_in = Region(region=cs2r[cs], region_county=county_id)
    db.session.add(reg_in)

db.session.commit()

# %%
alabama = State.query.first()
County.query.filter_by(county_name='Blount', county_state=alabama).first()

# %%
len(Region.query.all())
# Out:
# 3142

# %%
cs2r

# %%
county_state[:10]

# %%
[cs for cs in cs2r if 'Blount' in cs]

# %%
pd.read_csv('C:/Users/jayja/Desktop/lookup.csv')

# %%
bird = Bird.query.first()

# %%
bird
# Out:
# <Bird 1: Abert's Towhee>

# %%
bird.image_file
# Out:
# 'default.jpg'

# %%
lookup = pd.read_csv("C:/Users/jayja/Desktop/lookup.csv")

# %%
for idx, row in lookup.i
